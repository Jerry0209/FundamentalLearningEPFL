# %% [markdown]
# <a href="https://colab.research.google.com/github/Jerry0209/FundamentalLearningEPFL/blob/main/HW1/crack_the_code_v7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 1: crack Alex's phone code
#
# ### Rules:
#  - You should write the solution in this notebook and upload the completed notebook on Moodle by the deadline.
#  - You are not allowed to work in groups, every student should submit their own notebook. If you submit two highly overlapping notebooks with another student, you will both be penalized.
#  - The bonus questions are optional. They are not needed to get the full grade, but they can help you to get a higher grade.
#
# ### The setting
#
# Your friend Alex wants to hide a secret code in a probability distribution. The probability density function is a piecewise linear distribution with parameters $0<a\le b$, defined as
# $$p(x;a,b) = H(a,b) \begin{cases} \frac{x}{a} & \text{if } 0 \leq x \leq a, \\ \frac{b-x}{b-a} & \text{if } a \leq x \leq b, \\ 0 & \text{otherwise.} \end{cases}$$
# where $H(a,b)$ is a normalization constant. Alex has choosen $a$ and $b$ such that they are the first two and the last two digits of his phone secret code, respectively.
# For example, if their secret code is 1234, then $a=12$ and $b=34$. Alex stores some sample values of the distribution in a file called on their computer, thinking that nobody will be able to understand the distribution without the secret code.
#
# You recently enrolled at EPFL and you are taking the course of _Fundamental of Inference and Learning_, and you want to prove that Alex's phone code is not safe. In this problem, your goal is to discover the secret code by studying the distribution.

# %% [markdown]
# ## Part 1: Properties of the distribution

# %% [markdown]
# The distribution $p(x;a,b)$ is a valid distribution, i.e., it is normalized and it is non-negative. In this part, you will find many properties of the distribution.

# %% [markdown]
#  - **Question 1.** Find the normalization constant $H(a,b)$.
#  - **Q1 Answer**
#     - Since $p(x; a, b)$ is a valid probability density function, its integral over its entire domain must be 1.
#     $$\int_{-\infty}^{\infty} p(x; a, b) dx = 1$$
#
#     - Since PDF only has values in $[0, b]$, the integral can be written as:
#
#     $$\int_{0}^{b} p(x; a, b)dx=\int_{0}^{a} H(a, b) \frac{x}{a} dx + \int_{a}^{b} H(a, b) \frac{b-x}{b-a} dx =H(a, b) \left[ \int_{0}^{a} \frac{x}{a}  dx + \int_{a}^{b} \frac{b-x}{b-a} dx \right]= 1$$
#
#     - These two integrals can be calculated separately:
#       - First integral:
#     $$\int_{0}^{a} \frac{x}{a} dx = \frac{1}{a} \left[ \frac{x^2}{2} \right]_{0}^{a} = \frac{1}{a} \left( \frac{a^2}{2} - 0 \right) = \frac{a}{2}$$
#       - Second integral:
#
#     $$\int_{a}^{b} \frac{b-x}{b-a} dx = \frac{1}{b-a} \left[ bx - \frac{x^2}{2} \right]_{a}^{b}= \frac{1}{b-a} \left[ \left( b^2 - \frac{b^2}{2} \right) - \left( ab - \frac{a^2}{2} \right) \right]= \frac{1}{b-a} \left[ \frac{(b-a)^2}{2} \right] = \frac{b-a}{2}$$
#
#
#       - Substitute these two results back into the original equation:
#
#     $$H(a, b) \left[ \frac{a}{2} + \frac{b-a}{2} \right] = H(a, b) \left[ \frac{b}{2} \right] = 1$$
#       - Solve for $H(a, b)$:
#     $$H(a, b) = \frac{2}{b}$$

# %% [markdown]
# - **Question 2.** Compute the expected value $\mu$ of the distribution.
# - **Q2 Answer**
#
#   - The formula for the expected value $\mu$ ($\mathit{E}[X]$) is:
#   $$\mu = \mathit{E}[X] = \int_{-\infty}^{\infty} x \cdot p(x; a, b) \, dx = \int_{0}^{a} x \left( \frac{2x}{ab} \right) \, dx + \int_{a}^{b} x \left( \frac{2(b-x)}{b(b-a)} \right) \, dx$$
#
#   - Integral of two parts:
#
#
#     - First integral
#   $$\int_{0}^{a} \frac{2x^2}{ab} \, dx = \frac{2}{ab} \int_{0}^{a} x^2 \, dx= \frac{2}{ab} \left[ \frac{x^3}{3} \right]_{0}^{a} = \frac{2}{ab} \left( \frac{a^3}{3} - 0 \right) = \frac{2a^3}{3ab}= \frac{2a^2}{3b}$$
#
#
#     - Second integral
#   $$\int_{a}^{b} \frac{2x(b-x)}{b(b-a)} \, dx = \frac{2}{b(b-a)} \int_{a}^{b} (bx - x^2) \, dx= \frac{2}{b(b-a)} \left[ \frac{bx^2}{2} - \frac{x^3}{3} \right]_{a}^{b}$$
#
#   $$= \frac{2}{b(b-a)} \left[ \left( \frac{b(b^2)}{2} - \frac{b^3}{3} \right) - \left( \frac{b(a^2)}{2} - \frac{a^3}{3} \right) \right]= \frac{b^2 + ab - 2a^2}{3b}$$
#
#
#     - Combine the two results:
#   $$\mu = \frac{2a^2}{3b} + \frac{b^2 + ab - 2a^2}{3b}= \frac{2a^2 + b^2 + ab - 2a^2}{3b}= \frac{a+b}{3}$$
#
#     - Thus the expected value $\mu$ is $\frac{a+b}{3}$.

# %% [markdown]
# - **Question 3.** Compute the _cumulative density function_ $F(t)$ of the distribution.
#
# - **Q3 Answer**
#
#   - The Cumulative Distribution Function (CDF) $F(t)$ is defined as $F(t)  = \int_{-\infty}^{t} p(x;a,b) \, dx$.
#
#   - Since the PDF is piecewise function, CDF should be calculated based on each piecewise function, which depends on different values of $t$:
#
#   - **Case 1: $t < 0$**
#   $$F(t) = \int_{-\infty}^{t} 0 \, dx = 0$$
#
#   - **Case 2: $0 \le t \le a$**
#   $$F(t) = \int_{-\infty}^{0} 0 \, dx + \int_{0}^{t} \frac{2x}{ab} \, dx= \frac{t^2}{ab}$$
#
#
#   - **Case 3: $a \le t \le b$**
#
#   $$F(t) = \int_{0}^{a} p(x) \, dx + \int_{a}^{t} p(x) \, dx = F(a) + \int_{a}^{t} \frac{2(b-x)}{b(b-a)} \, dx = \frac{a}{b} + \frac{2}{b(b-a)} \int_{a}^{t} (b-x) \, dx = \frac{2 b t - a b - t ^ { 2 }}{b(b-a)}$$
#
#   - CDF is the total probability for $x$ on $[0, a]$, and add the probability for $x$ from $a$ to $t$.
#
#   - When $t=a$, $F(a) = 1 - \frac{(b-a)^2}{b(b-a)} = 1 - \frac{b-a}{b} = \frac{a}{b}$. When $t=b$, $F(b) = 1 - 0 = 1$. Both match expectations.)
#
#   - Final CDF is
#   $$F(t) = \begin{cases} \frac{t^2}{ab} & \text{if } 0 \leq t \leq a, \\ \frac{2 b t - a b - t ^ { 2 }}{b(b-a)} & \text{if } a \leq t \leq b, \\ 0 & \text{otherwise} \end{cases}$$

# %% [markdown]
# * **Question 4.** Compute the median $m$ of the distribution. (Be careful, there are some special cases to consider according to the value $a$ and $b$)
#
# - **Q4 Answer**
#
#     - The median $m$ : $F(m) = \frac{1}{2}$. It's required to determine which segment of the CDF contains the $\frac{1}{2}$ probability value.
#
#     - Test the value of the CDF at the breakpoint(peak) $x=a$:
#     $$F(a) = \frac{a^2}{ab} = \frac{a}{b}$$.
#
#
#     - **Case 1: $F(a) \ge \frac{1}{2}\implies\frac{a}{b} \ge \frac{1}{2} \implies 2a \ge b$**
#       - The median $m$ must be in the first interval, $[0, a]$.
#       - Use the CDF formula for this interval:
#       $$F(m) = \frac{m^2}{ab} = \frac{1}{2}$$
#       - Solving for $m$:
#       $$m^2 = \frac{ab}{2}$$
#       $$m = \sqrt{\frac{ab}{2}} \quad \text{(Take the positive root since } m \ge 0 \text{)}$$
#
#   - **Case 2: $F(a) < \frac{1}{2}\implies\frac{a}{b} < \frac{1}{2} \implies 2a < b$**
#     - The median $m$ must be in the second interval, $[a, b]$.
#     - For this interval, we use the CDF formula $F(t) = \frac{2bt - ab - t^2}{b(b-a)}$.
#     - Set $F(m) = \frac{1}{2}$:
#     $$\frac{2bm - ab - m^2}{b(b-a)} = \frac{1}{2}$$
#     - Rearrange it into a quadratic equation:
#     $$2(2bm - ab - m^2) = b(b-a)$$
#     $$2m^2 - 4bm + (ab + b^2) = 0$$
#
#     - Solve this for $m$ using the quadratic formula, $m = \frac{-B \pm \sqrt{B^2 - 4AC}}{2A}$, with: $A = 2$, $B = -4b$, $C = (ab + b^2)$
#
#     $$m = \frac{-(-4b) \pm \sqrt{(-4b)^2 - 4(2)(ab + b^2)}}{2(2)}$$
#     $$m = \frac{4b \pm \sqrt{16b^2 - 8(ab + b^2)}}{4}$$
#
#
#     $$m = b \pm \sqrt{\frac{2b(b-a)}{4}} = b \pm \sqrt{\frac{b(b-a)}{2}}$$
#     - This gives two potential solutions. However, $m$ must be in the interval $[a, b]$, so $m \le b$.
#     - The solution $m = b + \sqrt{\frac{b(b-a)}{2}}$ is "out of range" because it will be greater than $b$.
#     - Therefore, only take the negative sign:
#     $$m = b - \sqrt{\frac{b(b-a)}{2}}$$
#
#     - By combining both cases, the complete solution for the median is:
#   $$m = \begin{cases} \sqrt{\frac{ab}{2}} & \text{if } 2a \ge b \\ b - \sqrt{\frac{b(b-a)}{2}} & \text{if } 2a < b \end{cases}$$

# %% [markdown]
# - **Question 5.** Are the expected value and the median equal? How do the compare with the mode of the distribution? Comment the results.
#
# - **Q5 Answer**
#
#   - The mode is the value of $x$ where the PDF $p(x)$ reaches its maximum.
#     - On $[0, a]$, $p(x) = \frac{2x}{ab}$ is an increasing function.
#     - On $[a, b]$, $p(x) = \frac{2(b-x)}{b(b-a)}$ is a decreasing function.
#     - The PDF reaches its peak at $x=a$, with $p(a) = \frac{2a}{ab} = \frac{2}{b}$.
#     - Therefore, the Mode $= a$.
#
#   - The mean, median, and mode are equal only when the distribution is symmetric ($b=2a$). When the distribution is asymmetric or skewed, they are different. The mean is always pulled in the direction of the long tail, while the mode remains at the peak, and the median lies between the two.
#
#   - Details for each case are in the table below.
#
# | Case | Condition | Distribution Shape | Mode | Mean | Median | Relationship | Commentary |
# |------|-----------|-------------------|------|------|--------|--------------|------------|
# | **Case 1** | $a = \frac{b}{2}$ ($b = 2a$) | Symmetric (isosceles triangle) | $a$ | $\frac{a+b}{3} = a$ | $m = \sqrt{\frac{ab}{2}} = a$ | **Mean = Median = Mode** | All three measures coincide at the peak. This is characteristic of a unimodal symmetric distribution. |
# | **Case 2** | $a > \frac{b}{2}$ ($b < 2a$) | Left-skewed (longer tail on left) | $a$ | $\frac{a+b}{3} < a$ | $m = \sqrt{\frac{ab}{2}}$ | **Mean < Median < Mode** | The mean is pulled toward the longer left tail. The median lies between the mean and mode. |
# | **Case 3** | $a < \frac{b}{2}$ ($b > 2a$) | Right-skewed (longer tail on right) | $a$ | $\frac{a+b}{3} > a$ | $m = b - \sqrt{\frac{b(b-a)}{2}}$ | **Mode < Median < Mean** | The mean is pulled toward the longer right tail. The median lies between the mode and mean. |

# %% [markdown]
# ## Part 2: Discovering the secret code from samples
# You have seen Alex typing the code once, and you know that the last 2 digits are "20", hence $b=20$, and your goal is to estimate the first two digits $a^\star$. In this part, you can work as if you knew the value of $b$, and the distribution depends only on $a$. You also got the file `fixed_b.npy`with samples coming from the distribution $p(x;a=a^\star, b=20)$ that your friend Alex stored in the computer.

# %% [markdown]
# - **Question 6.** Implement a function `pdf(x, a, b=20)` that computes the probability density function $p(x;a,20)$, and plot it for $b=20$ and $a$ of your choice.
#
#   - Samples of values of x in of the distribution
#
# $$p(x;a,20) = \begin{cases} \frac{1}{10} \frac{x}{a} & \text{if } 0 \leq x \leq a, \\ \frac{1}{10} \frac{20-x}{20-a} & \text{if } a < x \leq 20, \\ 0 & \text{otherwise.} \end{cases}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import requests
import io

b = 20

url = 'https://raw.githubusercontent.com/Jerry0209/FundamentalLearningEPFL/main/HW1/fixed_b.npy'

try:
    response = requests.get(url)
    response.raise_for_status()

    data = np.load(io.BytesIO(response.content))
    print(f"Successfully loaded！")
    print(f"Data Shape: {data.shape}")

except Exception as e:
    print(f"Error：{e}")
    data = np.array([])
# Out:
# Successfully loaded！
# Data Shape: (100,)

# %%
# PDF definition
def pdf(x, a, b=b):

    if a <= 0 or a > b:
        # a must be in the range [0, b]
        if isinstance(x, np.ndarray):
            return np.zeros_like(x)
        else:
            return 0.0

    x = np.asarray(x)
    p = np.zeros_like(x, dtype=float)
    H = 2.0 / b

    # Case 1: 0 <= x <= a
    mask1 = (x >= 0) & (x <= a)
    if a > 0:
        p[mask1] = H * (x[mask1] / a)

    # Case 2: a < x <= b
    mask2 = (x > a) & (x <= b)
    if b - a > 0:
        p[mask2] = H * ((b - x[mask2]) / (b - a))
    elif a == b: # a=b
        #  Belongs to case 1
        pass

    return p

# --- Plot ---
a_test = 8 # Randomly choose

x_vals = np.linspace(-5, 25, 300)
y_vals = pdf(x_vals, a=a_test, b=b)

plt.figure(figsize=(10, 6))
plt.plot(x_vals, y_vals, label=f'p(x; a={a_test}, b={b})')
plt.title(f'PDF (a={a_test}, b={b})')
plt.xlabel('x')
plt.ylabel('p(x)')
plt.grid(True, linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# - **Question 7** How many sample points are there in the file? Let us call this number $n$ and plot an histogram of the data

# %%
# Data points
n = len(data)
print(f"Totally {n} data points in the file.")
print(data[:10]) # Slicing to print 0 - 9

# Histogram
plt.figure(figsize=(10, 6))
plt.hist(data, bins='auto', density=True, alpha=0.7, label='fixed_b data points')
plt.title('Histogram')
plt.xlabel('x')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True, linestyle='--')
plt.show()
# Out:
# Totally 100 data points in the file.
# [ 6.69787293 13.41965333 10.0877695  16.90039196 17.38022455 13.29167114
#  10.06390131 16.61769313  8.89947326 13.19370464]

# %% [markdown]
# - **Question 8.** Compute the empirical mean $\bar x$ and the empirical median $\bar m$.

# %%
x_bar = np.mean(data)
m_bar = np.median(data)

print(f"Empirical Mean (x_bar): {x_bar:.4f}")
print(f"Empirical Median (m_bar): {m_bar:.4f}")
# Out:
# Empirical Mean (x_bar): 10.7398
# Empirical Median (m_bar): 10.7005

# %% [markdown]
# - **Question 9.** Use the expression of the expected value you computed above to find an estimator $\hat a_\text{mean}$ of the true parameter $a^\star$, as a function of the empirical mean $\bar x$. Repeat the same for the median, and find $\hat a_\text{median}$ as a function of the empirical median $\bar m$.
#
# - **Q9 Answer**
#
#   - Method of Moments is used. The expected values of empirical mean and median are calculated above. Then the calculated theoretical value (true mean which depends on $a$) equal to our observed empirical value from the data($\bar x$), and then solve for $a$.
#
#
#   - Estimator based on the expected value $\hat a_\text{mean}$
#
#     $$\mu = \mathbb{E}[X] = \frac{a+b}{3}$$
#   - Let $\mu = \bar x$, and replace $a$ with $\hat a_\text{mean}$
#
#     $$\bar x = \frac{\hat a_\text{mean} + b}{3}$$
#
#   - Solve for $\hat a_\text{mean}$：
#
#     $$3\bar x = \hat a_\text{mean} + b$$
#     $$\hat a_\text{mean} = 3\bar x - 20$$
#
#
#
#   - Same for the median
#
#   $$m = \begin{cases} \sqrt{\frac{ab}{2}} & \text{if } 2a \ge b \\ b - \sqrt{\frac{b(b-a)}{2}} & \text{if } 2a < b \end{cases}$$
#
#   - To find the estimator based on the median, again use the Method of Moments by setting the theoretical median $m$ equal to our empirical median $\bar m$. However, the formula for the theoretical median is piecewise, depending on whether $a$ is greater or less than $b/2$. This means our resulting estimator, $\hat a_\text{median}$, will also have a piecewise definition based on the value of $\bar m$.
#
#   - First consider the case where $\bar m \ge b/2$, which corresponds to the theoretical condition $a \ge b/2$. In this scenario, the formula is $m = \sqrt{ab/2}$. By substituting $\bar m$ for $m$ and $\hat a_\text{median}$ for $a$, we get $\bar m = \sqrt{\hat a_\text{median} b/2}$. To solve for $\hat a_\text{median}$, we square both sides ($\bar m^2 = \hat a_\text{median} b/2$) and rearrange, giving the estimator $\hat a_\text{median} = 2\bar m^2 / b$.
#
#   - Conversely, if we observe that $\bar m < b/2$, we use the other part of the median formula: $m = b - \sqrt{b(b-a)/2}$. Substituting our values gives $\bar m = b - \sqrt{b(b-\hat a_\text{median})/2}$. Solving this for $\hat a_\text{median}$ gives the estimator $\hat a_\text{median} = b - 2(b-\bar m)^2 / b$.
#
#
#   - Final median estimator (with b=20):
#   $$\hat a_\text{median} = \begin{cases} \frac{2\bar m^2}{20} = \frac{\bar m^2}{10} & \text{if } \bar m \ge 10 \\ 20 - \frac{2(20-\bar m)^2}{20} = 20 - \frac{(20-\bar m)^2}{10} & \text{if } \bar m < 10 \end{cases}$$

# %% [markdown]
# - **Question 10.** Implement a function `est_a_mean(x_bar, b=20)` and `est_a_median(m_bar, b=20)` that code the estimators you found above. What are the vaules of $\hat a_\text{mean}$ and $\hat a_\text{median}$ for the data you have in the file `fixed_b.npy`?

# %%
def est_a_mean(x_bar, b=b):

    return 3 * x_bar - b

def est_a_median(m_bar, b=b):

    if m_bar >= b / 2.0:
        return 2 * (m_bar**2) / b
    else:
        return b - 2 * ((b - m_bar)**2) / b

a_hat_mean = est_a_mean(x_bar, b=b)
a_hat_median = est_a_median(m_bar, b=b)

print(f"Estimate based on mean (a_hat_mean):    {a_hat_mean:.4f}")
print(f"Estimate based on median (a_hat_median): {a_hat_median:.4f}")
# Out:
# Estimate based on mean (a_hat_mean):    12.2193
# Estimate based on median (a_hat_median): 11.4501

# %% [markdown]
#  - **Question 11.** Consider the log-likelihood function $\mathbb{L}(a;\{x_i\}_{i\in[1,n]},b=20)$. Plot the log-likelihood function as a function of $a$ for the data in the file `fixed_b.npy`.
#
#  $$\widehat{\lambda}_{ML}=argmax_{\lambda}\prod_i P(x_i|\lambda)=argmax_{\lambda}\left(\sum_i\log(P(x_i|\lambda))\right)$$

# %%
def loglh(a, data, b=b):
    # the same mehthod in TP2
    if a <= 0 or a >= b:
        return -np.inf

    logl = 0.0
    for x_i in data:
        p_i = pdf(x_i, a, b)

        # dataset is impossible
        if p_i == 0:
            return -np.inf

        logl += np.log(p_i)
    return logl

a_vals = np.linspace(1, 19.9, 1000)
ll_vals = [loglh(a, data, b=b) for a in a_vals]

plt.figure(figsize=(10, 6))
plt.plot(a_vals, ll_vals, label='$\mathcal{L}(a)$')
plt.title('Log-Likelihood Function $\mathcal{L}(a)$ (b=20)')
plt.xlabel('Paramter a')
plt.ylabel('Log likelihood')
plt.grid(True, linestyle='--')
plt.legend()
plt.show()
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:22: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:22: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-2351785290.py:21: SyntaxWarning: invalid escape sequence '\m'
#   plt.plot(a_vals, ll_vals, label='$\mathcal{L}(a)$')
# /tmp/ipython-input-2351785290.py:22: SyntaxWarning: invalid escape sequence '\m'
#   plt.title('Log-Likelihood Function $\mathcal{L}(a)$ (b=20)')

# %% [markdown]
#  - **Question 12.** What is the maximum likelihood estimator $\hat a_\text{MLE}$?

# %%
from scipy.optimize import minimize

# Method 1
# Find the index of the maximum value in ll_vals
max_ll_index = np.argmax(ll_vals)

# Find the corresponding a value
a_hat_mle = a_vals[max_ll_index]

print(f"Maximum Likelihood Estimate (a_hat_mle): {a_hat_mle:.4f}")

# Method 2 : optimizer
def negative_log_likelihood(a_single_value, data, b):
    a = float(a_single_value)

    ll = loglh(a, data, b)

    # Return negative value
    return -ll


# Scipy

initial_guess = a_hat_median
epsilon = 1e-9
bounds = [(epsilon, b - epsilon)]

result = minimize(
    negative_log_likelihood,
    x0=initial_guess,
    args=(data, b),
    bounds=bounds,
    method='L-BFGS-B'
)

if result.success:
    a_hat_mle_optimized = result.x[0]
    print(f"a_MLE (From optimizer): {a_hat_mle_optimized:.8f}")
else:
    print("\n optimization failed！")
    print(result.message)

# Plot the estimated PDF
plt.plot(x_vals, pdf(x_vals, a_hat_mle, b), 'r-', lw=2, label=f'MLE PDF (a={a_hat_mle:.2f})')
plt.axvline(a_hat_mean, color='g', linestyle='--', label=f'a_hat_mean = {a_hat_mean:.2f}')
plt.axvline(a_hat_median, color='b', linestyle='--', label=f'a_hat_median = {a_hat_median:.2f}')
plt.axvline(a_hat_mle, color='r', linestyle='--', label=f'a_hat_mle = {a_hat_mle:.2f}')

plt.title('Histogram with Three Estimates')
plt.xlabel('x')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# Maximum Likelihood Estimate (a_hat_mle): 11.3676
# a_MLE (From optimizer): 11.36579655
# /tmp/ipython-input-55131911.py:14: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   a = float(a_single_value)

# %% [markdown]
# - **Question 13.** Use bootstrapping to compute the 95% confidence interval for all the three $a$ estimators computed above.

# %%
def est_a_median_vectorized(m_bar, b=b):
    return np.where(
        m_bar >= b / 2.0, # calculates for all elements
        2 * (m_bar**2) / b,
        b - 2 * ((b - m_bar)**2) / b
    )

n_bootstraps = 10000
boot_data = [] # Store different Bootstrap samples from 'data'
boot_a_mean = []
boot_a_median = []
boot_a_mle = []

n = len(data)

np.random.seed(233)

print(f"Start {n_bootstraps} Bootstrap iterations")

boot_data = np.random.choice(data, (n_bootstraps,n))

# x_mean
x_bar_boot = np.mean(boot_data, axis=1)
boot_a_mean = est_a_mean(x_bar_boot, b)

# x_median
m_bar_boot = np.median(boot_data, axis=1)
boot_a_median = est_a_median_vectorized(m_bar_boot, b)


# MLE (Minimum Distance Estimation)
boot_data_sorted = np.sort(boot_data, axis=1)

# Pre-compute the target k/n values. Shape: (n,)
k_vals = np.arange(1, n + 1)
target_vals = b * k_vals / n

# Find differences.
diffs = np.abs(boot_data_sorted - target_vals)

best_k_idx = np.argmin(diffs, axis=1)
row_indices = np.arange(n_bootstraps) # [0, 1, 2, ..., 4999]
boot_a_mle = boot_data_sorted[row_indices, best_k_idx]

print("Bootstrap complete!")

# Calculate confidence intervals
ci_mean = np.percentile(boot_a_mean, [2.5, 97.5])
ci_median = np.percentile(boot_a_median, [2.5, 97.5])
ci_mle = np.percentile(boot_a_mle, [2.5, 97.5])

print(f"--- 95% Confidence Intervals ---")
print(f"a_hat_mean:   {a_hat_mean:.4f}, CI: [{ci_mean[0]:.4f}, {ci_mean[1]:.4f}]")
print(f"a_hat_median: {a_hat_median:.4f}, CI: [{ci_median[0]:.4f}, {ci_median[1]:.4f}]")
print(f"a_hat_mle:    {a_hat_mle:.4f}, CI: [{ci_mle[0]:.4f}, {ci_mle[1]:.4f}]")
# Out:
# Start 10000 Bootstrap iterations
# Bootstrap complete!
# --- 95% Confidence Intervals ---
# a_hat_mean:   12.2193, CI: [9.8339, 14.5827]
# a_hat_median: 11.4501, CI: [9.9208, 13.2877]
# a_hat_mle:    11.3676, CI: [9.6153, 13.9666]

# %% [markdown]
# - **Question 14.** Compute the Fisher information of $a$ under the distribution $p(x;a,b=20)$.
#
# - **Q14 Answer**
#   $$
#   S(x,\lambda)=\partial_\lambda L(x|\lambda),
#   $$
#
#   $$
#   I(\lambda)=\mathbb{E}_{\lambda}[S(x|\lambda)^2].
#   $$
#
#     - In this problem
#   $$I(a) = \mathbb{E} \left[ \left( \frac{\partial \log p(X; a)}{\partial a} \right)^2 \right]$$
#
#     - Log-Likelihood:
#   $$\log p(x; a, b) = \log(H) + \begin{cases} \log(x/a) & \text{if } 0 \le x \le a \\ \log((b-x)/(b-a)) & \text{if } a < x \le b \end{cases}$$
#
#
#   - Derivative of the PDF:
#   $$\frac{\partial \log p(x; a)}{\partial a} = \begin{cases} -1/a & \text{if } 0 \le x \le a \\ 1/(b-a) & \text{if } a < x \le b \end{cases}$$
#
#
#   $$\left( \frac{\partial \log p}{\partial a} \right)^2 = \begin{cases} 1/a^2 & \text{if } 0 \le x \le a \\ 1/(b-a)^2 & \text{if } a < x \le b \end{cases}$$
#
#   - Calculate the Expectation $I(a):
#   $$I(a) = \int_{0}^{b} \left( \frac{\partial \log p}{\partial a} \right)^2 p(x; a, b) \, dx$
#
#   $$I(a) = \int_{0}^{a} \left( \frac{1}{a^2} \right) p(x) \, dx + \int_{a}^{b} \left( \frac{1}{(b-a)^2} \right) p(x) \, dx$$
#
#   - This can be seen as:
#     $$I(a) = \frac{1}{a^2} \cdot F(a) + \frac{1}{(b-a)^2} \cdot (1 - F(a))$$
#
#       * $F(a) = \frac{a^2}{ab} = \frac{a}{b}$.(the CDF from Question 3)
#       * $1 - F(a) = 1 - \frac{a}{b} = \frac{b-a}{b}$.
#
#   - After substitution:
#     $$I(a) = \frac{1}{a^2} \left( \frac{a}{b} \right) + \frac{1}{(b-a)^2} \left( \frac{b-a}{b} \right)=\frac{1}{a(b-a)}$$
#
#
#   - For $n$ independent and identically distributed (i.i.d.) samples, the total Fisher information is $I_n(a) = n \cdot I(a) = \frac{n}{a(b-a)}$. When $b=20$:
# $$I_n(a) = \frac{n}{a(20-a)}$$

# %% [markdown]
# - **Question 15.** Can you compute the maximum likelihood estimator using the Jeffrey Posterior $\hat a_\text{jeff}$? Provide also the confidence intervals.
#
# - **Q15 Answer**
#
#
#   $$P(a) \propto \sqrt{\frac{1}{a(b-a)}} = \frac{1}{\sqrt{a(b-a)}}$$
#
#   - Prior
#
#   $$\log(P(a)) \propto \log\left(\frac{1}{\sqrt{a(b-a)}}\right) = -\frac{1}{2}\log(a(b-a)) = -\frac{1}{2}\log(a) - \frac{1}{2}\log(b-a)$$
#
#   - logPosterior
#   $$\text{Posterior}(a) = \mathbb{L}(a) - \frac{1}{2}\log(a) - \frac{1}{2}\log(b-a)$$

# %%
from scipy.integrate import cumulative_trapezoid, trapezoid
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt

# b=20

# Calculate the log-posterior
log_prior_vals = -0.5 * np.log(a_vals) - 0.5 * np.log(b - a_vals)
log_posterior_vals = ll_vals + log_prior_vals

# Find the posterior estimate
a_hat_jeff = a_vals[np.argmax(log_posterior_vals)]

print(f"Jeffreys Posterior Estimate (a_hat_jeff): {a_hat_jeff:.4f}")

# Calculate the credible interval

posterior_pdf_unnorm = np.exp(log_posterior_vals - np.max(log_posterior_vals))

area = trapezoid(posterior_pdf_unnorm, a_vals)
posterior_pdf = posterior_pdf_unnorm / area

# Calculate the posterior CDF
posterior_cdf = cumulative_trapezoid(posterior_pdf, a_vals, initial=0)
posterior_cdf = posterior_cdf / posterior_cdf[-1] # Ensure the CDF ends at 1

inv_cdf_func = interp1d(posterior_cdf, a_vals)
ci_jeff_low = inv_cdf_func(0.025)
ci_jeff_high = inv_cdf_func(0.975)

print(f"Jeffreys 95% Credible Interval: [{ci_jeff_low:.4f}, {ci_jeff_high:.4f}]")

# Plot
plt.figure(figsize=(12, 7))
plt.plot(a_vals, posterior_pdf, 'b-', label='Jeffreys Posterior PDF')
plt.axvline(a_hat_jeff, color='b', linestyle='--', label=f'a_hat_jeff = {a_hat_jeff:.2f}')
plt.fill_between(a_vals, posterior_pdf,
                 where=(a_vals >= ci_jeff_low) & (a_vals <= ci_jeff_high),
                 color='blue', alpha=0.2, label='95% Credible Interval')
plt.title('Jeffreys Posterior Distribution (b=20)')
plt.xlabel('a')
plt.ylabel('Posterior')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Jeffreys Posterior Estimate (a_hat_jeff): 11.3676
# Jeffreys 95% Credible Interval: [9.7409, 13.9478]

# %% [markdown]
# All the estimation you derived couldn't find the secret code with absolute certainty. The confidence intervals you computed are too large to produce one single code. Moreover your friend is a bit paranoid and changes the code every week, so the information you have is not valid anymore. You need to find a better way to estimate the code.

# %% [markdown]
# ### Test the estimators
# You are still trying to sneak into your friend's computer to get new samples of the distribution. In the meanwhile, you want to test the estimators you derived on a synthetic dataset. Florent gave you this Python function to sample the distribution $p(x;a,b)$:

# %%
import numpy as np
import matplotlib.pyplot as plt

def sample(a: float, b: float, size: int=1) -> np.array:
    def sample_single(a: float, b: float) -> float:
        u = 0
        v = b
        while not((u <= a and v <= 2/(a*b)*u) or (u > a and v <= 2/b *(b-u)/(b-a))):
            u = np.random.uniform(0, b)
            v = np.random.uniform(0, 2/b)
        return u
    return np.array([sample_single(a, b) for _ in range(size)])

# %% [markdown]
# - **Bonus question 1** The sampling function is not efficient. Can you provide a more efficient way to sample the distribution?
#
# - Answer:
#
#     - The `sample` function is very slow because it uses a `for` loop with a nested `while` loop inside, generating only one sample at a time.
#
#     - To complete the simulation in reasonable time (10 * 300 * 1000 = 3,000,000 samples), we need to use numpy vectorization.
#
#     - The idea is to generate many candidate points (u, v) at once (for example, 2000 points), then use numpy array operations to compute all p(u) values simultaneously, and finally filter for all u where v < p(u). We repeat this process until we collect enough samples.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize_scalar
from tqdm.notebook import tqdm # To show a progress bar

def sample_optimized(a: float, b: float, size: int=1) -> np.array:
    """
    A vectorized (fast) rejection sampler for the distribution p(x; a, b).
    """
    samples = np.array([])

    # We expect about 50% acceptance rate since Area(PDF)=1 and Area(Box)=2
    # We will oversample in each batch to be efficient

    # Handle the degenerate cases to avoid division by zero
    b_sq = b * b
    if a == 0:
        denom1 = 1.0 # Will not be used
        denom2 = b_sq
    elif a == b:
        denom1 = b_sq
        denom2 = 1.0 # Will not be used
    else:
        denom1 = a * b
        denom2 = b * (b - a)

    while len(samples) < size:
        needed = size - len(samples)

        # Calculate how many to try: oversample by 2.1x (for 50% rate) + 100 buffer
        n_try = int(needed * 2.1) + 100

        u = np.random.uniform(0, b, size=n_try)
        v = np.random.uniform(0, 2/b, size=n_try)

        p_u = np.zeros_like(u)

        mask1 = (u <= a)
        mask2 = (u > a)

        # Calculate PDF values p(u) in a vectorized way
        if a > 0: # Avoid calculation if a=0
            p_u[mask1] = 2 * u[mask1] / denom1
        if a < b: # Avoid calculation if a=b
            p_u[mask2] = 2 * (b - u[mask2]) / denom2

        # Get the accepted samples
        accepted_mask = (v <= p_u)
        new_samples = u[accepted_mask]

        samples = np.concatenate((samples, new_samples))

    # Return exactly the number of samples requested
    return samples[:size]

# %% [markdown]
# Stick with the case where $b=20$, and sample $N=1000$ points from the distribution $p(x;a,b)$ for 10 values of $a\in[0,20]$.
# - **Question 16.** Compute and plot the mean squared error of the 4 estimators for $\hat a_\text{mean}, \hat a_\text{median}, \hat a_\text{ML}$ and $\hat a_\text{Jeff}$, as well as the Cramér-Rao lower bound. Which one is the best? [Hint: to have a good estimate of the mean squared error, you can repeat the sampling 300 times and compute the average of the squared error, for each value of $a$; be patient, this will take some time to compute]
#
#
# - **Q16 Answer**
#
#   - For **unbiased estimators**, as for example the maximum likelihood one, the CRB tells us that for each parameter $\lambda_i$ we have
#
#   $$MSE(\widehat{\lambda_i}_{ML};\lambda_i) \geq \{[I_N(\mathbf{\lambda})]^{-1}\}_{ii}$$
#
#   - where $I_N(\mathbf{\lambda})$ is the Fisher information.
#
#   $$\text{CRLB}=\frac{1}{I_n(a)}=\frac{a(b-a)}{n}$$
#
#
#   - Based on the graph, the **Maximum Likelihood Estimator ($\hat{a}_{\text{ML}}$)** and the **Jeffreys MAP estimator ($\hat{a}_{\text{Jeff}}$)** are tied for being the best. Their curves (the green star and red dotted line) are the lowest on the plot, meaning they consistently have the smallest Mean Squared Error (MSE) regardless of the true value of $a$.
#
#   - What makes them truly stand out is that their MSE lines almost perfectly trace the **Cramér-Rao Bound (CRLB)**, which is the dashed black line. The CRLB represents the theoretical *minimum possible error* any unbiased estimator can achieve. Since the MLE and Jeffreys estimators nearly reach this "perfect" performance limit, they are considered **statistically efficient**.
#
#   - In contrast, the other two methods are far worse. The Method of Moments estimator ($\hat{a}_{\text{mean}}$) has a significantly higher error, and the Median-based estimator ($\hat{a}_{\text{median}}$) performs the poorest by a large margin, especially when the true $a$ is near the boundaries (like $a=2.5$ or $a=17.5$). Since the distribution is heavily skewed in those situations, where the estimator value is pulled by the long tail.

# %%
# Vectorized function to calculate neg log, much faster than using for loop
def neg_log_likelihood(a: float, samples: np.array, b: float) -> float:

    epsilon = 1e-9
    if a <= epsilon or a >= b - epsilon:
        return np.inf

    # Split samples
    samples_le_a = samples[samples <= a]
    samples_gt_a = samples[samples > a]

    n1 = len(samples_le_a)
    n2 = len(samples_gt_a)

    # Calculate log-likelihood for each part, for x <= a and x>=a
    logL_1 = n1 * (np.log(2) - np.log(a) - np.log(b)) + \
             np.sum(np.log(samples_le_a + epsilon))

    logL_2 = n2 * (np.log(2) - np.log(b) - np.log(b - a)) + \
             np.sum(np.log(b - samples_gt_a + epsilon))

    return -(logL_1 + logL_2)

def neg_log_posterior_jeff(a: float, samples: np.array, b: float) -> float:
    # minimize negative Jeffreys prior equals to maximize Jeffreys prior
    epsilon = 1e-9
    if a <= epsilon or a >= b - epsilon:
        return np.inf

    nll = neg_log_likelihood(a, samples, b)

    # Add negative log-prior as before
    neg_log_prior = 0.5 * np.log(a) + 0.5 * np.log(b - a)

    return nll + neg_log_prior


def find_mle(samples: np.array, b: float) -> float: # by minimizing the negative log-likelihood
    res = minimize_scalar(
        neg_log_likelihood,
        args=(samples, b),
        bounds=(1e-6, b - 1e-6),
        method='bounded'
    )
    return res.x

def find_map_jeff(samples: np.array, b: float) -> float: # Jeffreys prior
    res = minimize_scalar(
        neg_log_posterior_jeff,
        args=(samples, b),
        bounds=(1e-6, b - 1e-6),
        method='bounded'
    )
    return res.x


# Simulation
b_fixed = 20.0
N_samples = 1000
M_repetitions = 300 # As per the hint

# Test 10 values
a_values = np.linspace(1, 19, 10)

# Arrays to store the Mean Squared Error (MSE) results
mse_mean = np.zeros_like(a_values)
mse_median = np.zeros_like(a_values)
mse_ml = np.zeros_like(a_values)
mse_jeff = np.zeros_like(a_values)
crlb_values = np.zeros_like(a_values)

# --- Run the Simulation ---
# Using tqdm for a progress bar, as this will take a few minutes
for i, a_true in enumerate(tqdm(a_values, desc='Simulating')):

    # Store squared errors for this 'a'
    sq_err_mean = []
    sq_err_median = []
    sq_err_ml = []
    sq_err_jeff = []

    # Calculate CRLB for this 'a'
    crlb_values[i] = (a_true * (b_fixed - a_true)) / N_samples

    for _ in range(M_repetitions):
        # 1. Get N samples
        samples = sample_optimized(a_true, b_fixed, size=N_samples)

        # 2. Calculate estimators
        # Estimator 1: Mean (MoM)
        x_bar = np.mean(samples)
        # a_hat_mean = 3 * x_bar - b_fixed
        a_hat_mean = est_a_mean(x_bar, b=b)

        # Estimator 2: Median
        m_s = np.median(samples)
        a_hat_median = est_a_median(m_s, b=b)

        # Estimator 3: ML
        a_hat_ml = find_mle(samples, b_fixed)
        # a_hat_ml = find_mle_with_minimize(samples, b_fixed)

        # Estimator 4: Jeffreys
        a_hat_jeff = find_map_jeff(samples, b_fixed)

        # Difference between ML and Jefferys
        # if i == 0:
        print(f"  Difference = {a_hat_mle - a_hat_jeff:.10f}")

        # Clip the MoM-based estimators, as they can go out of bounds
        a_hat_mean = np.clip(a_hat_mean, 0, b_fixed)
        a_hat_median = np.clip(a_hat_median, 0, b_fixed)

        # Store squared errors
        sq_err_mean.append((a_hat_mean - a_true)**2)
        sq_err_median.append((a_hat_median - a_true)**2)
        sq_err_ml.append((a_hat_ml - a_true)**2)
        sq_err_jeff.append((a_hat_jeff - a_true)**2)

    # Calculate average MSE for this certain 'a'
    mse_mean[i] = np.mean(sq_err_mean)
    mse_median[i] = np.mean(sq_err_median)
    mse_ml[i] = np.mean(sq_err_ml)
    mse_jeff[i] = np.mean(sq_err_jeff)

print("Simulation complete.")


# Plot the Results
plt.figure(figsize=(15, 8))

plt.plot(a_values, mse_mean, label=r'$\hat{a}_{\text{mean}}$ (MoM)', marker='o')
plt.plot(a_values, mse_median, label=r'$\hat{a}_{\text{median}}$ (Median)', marker='s')
plt.plot(a_values, mse_ml, label=r'$\hat{a}_{\text{ML}}$ (MLE)', marker='^', linestyle='-')
plt.plot(a_values, mse_jeff, label=r'$\hat{a}_{\text{Jeff}}$ (Jeffreys MAP)', marker='x', linestyle=':')
plt.plot(a_values, crlb_values, label='Cramér-Rao Bound (CRLB)', color='black', linestyle='--')

plt.title(f'Estimator Mean Squared Error (MSE) vs. True $a$ (N={N_samples}, M={M_repetitions})')
plt.xlabel('True parameter $a$')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.grid(True, linestyle=':')
plt.show()
# Out:
# Simulating:   0%|          | 0/10 [00:00<?, ?it/s]
#   Difference = 10.2481889019
#   Difference = 10.5288173433
#   Difference = 10.1129768604
#   Difference = 10.3358687721
#   Difference = 10.3247580214
#   Difference = 10.4081664348
#   Difference = 10.2881422911
#   Difference = 10.3896914880
#   Difference = 10.5870638168
#   Difference = 10.4139990329
#   Difference = 10.2080657962
#   Difference = 10.3729161137
#   Difference = 10.2447986671
#   Difference = 10.6848189773
#   Difference = 10.7759149283
#   Difference = 10.4014129602
#   Difference = 10.3486132815
#   Difference = 10.4084836178
#   Difference = 10.3938007469
#   Difference = 10.3573932023
#   Difference = 10.2239922954
#   Difference = 10.2536712669
#   Difference = 10.1877256619
#   Difference = 10.2936351398
#   Difference = 10.5889633862
#   Difference = 10.1818379788
#   Difference = 10.4660663833
#   Difference = 10.4536016740
#   Difference = 10.2628362256
#   Difference = 10.3775600567
#   Difference = 10.6530135798
#   Difference = 10.3305657011
#   Difference = 10.3099763405
#   Difference = 10.5722325431
#   Difference = 10.6414728700
#   Difference = 10.7054959616
#   Difference = 10.2241968342
#   Difference = 10.6137349595
#   Difference = 10.4932704166
#   Difference = 10.2903975949
#   Difference = 10.1919459682
#   Difference = 10.4659088026
#   Difference = 10.1896469170
#   Difference = 10.3038396660
#   Difference = 10.2444932738
#   Difference = 10.2541709403
#   Difference = 10.4676414594
#   Difference = 10.4445588528
#   Difference = 10.7544364600
#   Difference = 10.2119611446
#   Difference = 10.3668487926
#   Difference = 10.2618670848
#   Difference = 10.6457448318
#   Difference = 10.4731445722
#   Difference = 10.3054441391
#   Difference = 10.3912627400
#   Difference = 10.3602502192
#   Difference = 10.4273550624
#   Difference = 10.3239760398
#   Difference = 10.4924418276
#   Difference = 10.3738792436
#   Difference = 10.5867371890
#   Difference = 10.5272906020
#   Difference = 10.4404443757
#   Difference = 10.4493213740
#   Difference = 10.3856707879
#   Difference = 10.3209204260
#   Difference = 10.3036046434
#   Difference = 10.3078318885
#   Difference = 10.4352979326
#   Difference = 10.2167558657
#   Difference = 10.4633238657
#   Difference = 10.4296484694
#   Difference = 10.4094829688
#   Difference = 10.4015636986
#   Difference = 10.1696892436
#   Difference = 10.3379077330
#   Difference = 10.2892590043
#   Difference = 10.2255380769
#   Difference = 10.2730188568
#   Difference = 10.1313168970
#   Difference = 10.5047493546
#   Difference = 10.5702503033
#   Difference = 10.3494404777
#   Difference = 10.4304861904
#   Difference = 10.5176059984
#   Difference = 10.2872543520
#   Difference = 10.4510178647
#   Difference = 10.5488219046
#   Difference = 9.9580691722
#   Difference = 10.2655957974
#   Difference = 10.6645841710
#   Difference = 10.3977008532
#   Difference = 10.4053309227
#   Difference = 10.4621309177
#   Difference = 10.7887498602
#   Difference = 10.3126901611
#   Difference = 10.4261343518
#   Difference = 10.3127832690
#   Difference = 10.3867756953
#   Difference = 10.6760809865
#   Difference = 10.2908086570
#   Difference = 10.2663351693
#   Difference = 10.6481346764
#   Difference = 10.1942771223
#   Difference = 10.3726258296
#   Difference = 10.2696776446
#   Difference = 10.4438738368
#   Difference = 10.5116471860
#   Difference = 10.3752033566
#   Difference = 10.5722760868
#   Difference = 10.2809160264
#   Difference = 10.1417678889
#   Difference = 10.7105649427
#   Difference = 10.2856804909
#   Difference = 10.1532721902
#   Difference = 10.5453703697
#   Difference = 10.4899483715
#   Difference = 10.2612501543
#   Difference = 10.2035237094
#   Difference = 10.2534969863
#   Difference = 10.1229509420
#   Difference = 10.5433022737
#   Difference = 10.3862432037
#   Difference = 10.5796678633
#   Difference = 10.1931573391
#   Difference = 10.7164039741
#   Difference = 10.2218038942
#   Difference = 10.5731370425
#   Difference = 10.5248652228
#   Difference = 10.4627240692
#   Difference = 10.2516501566
#   Difference = 10.3880023587
#   Difference = 10.5471714018
#   Difference = 10.4660559505
#   Difference = 10.3105952281
#   Difference = 10.4757204213
#   Difference = 10.4725597065
#   Difference = 10.1305078151
#   Difference = 10.2325382109
#   Difference = 10.3516914275
#   Difference = 10.2433231861
#   Difference = 10.3619666939
#   Difference = 10.4236578077
#   Difference = 10.0865955101
#   Difference = 10.3846595355
#   Difference = 10.4286124287
#   Difference = 10.3823789027
#   Difference = 10.1561778806
#   Difference = 10.5266492449
#   Difference = 10.5108088434
#   Difference = 10.2511384515
#   Difference = 10.4893683944
#   Difference = 10.4462622999
#   Difference = 10.4922568573
#   Difference = 10.0693917318
#   Difference = 10.4162003004
#   Difference = 10.4292362909
#   Difference = 10.1491715572
#   Difference = 10.4496005253
#   Difference = 10.1692896290
#   Difference = 10.0934211637
#   Difference = 10.3938354399
#   Difference = 10.4053536082
#   Difference = 10.1949946081
#   Difference = 10.7117396987
#   Difference = 10.5265286137
#   Difference = 10.2264489315
#   Difference = 10.3897416986
#   Difference = 10.5069167647
#   Difference = 10.2115387351
#   Difference = 10.2894300586
#   Difference = 10.3940827663
#   Difference = 10.5555053408
#   Difference = 10.5566392470
#   Difference = 10.1285057710
#   Difference = 10.4088407458
#   Difference = 10.5429179400
#   Difference = 10.7470135129
#   Difference = 10.2052453931
#   Difference = 10.2523268916
#   Difference = 10.5236814150
#   Difference = 10.4534282903
#   Difference = 10.2949371485
#   Difference = 10.2278414209
#   Difference = 10.4243837501
#   Difference = 9.9706847131
#   Difference = 10.4267682706
#   Difference = 10.3115171582
#   Difference = 10.2046682941
#   Difference = 10.4228914254
#   Difference = 10.5286122878
#   Difference = 10.3714182587
#   Difference = 10.2752222546
#   Difference = 10.3965579758
#   Difference = 10.4511685064
#   Difference = 10.4317343644
#   Difference = 10.2808359937
#   Difference = 10.5362753789
#   Difference = 10.4117697563
#   Difference = 10.6872128167
#   Difference = 10.2503096500
#   Difference = 10.2428774910
#   Difference = 10.3022139960
#   Difference = 10.2856890024
#   Difference = 10.3940669673
#   Difference = 10.8300268547
#   Difference = 10.4542059158
#   Difference = 10.3283504469
#   Difference = 10.3681002846
#   Difference = 10.3857520692
#   Difference = 10.3051549007
#   Difference = 10.5946056387
#   Difference = 10.1222895989
#   Difference = 10.4000360870
#   Difference = 10.1295868917
#   Difference = 10.0799032989
#   Difference = 10.2099968577
#   Difference = 10.4947701892
#   Difference = 10.5697587258
#   Difference = 10.6527237313
#   Difference = 10.2892046652
#   Difference = 10.4487996275
#   Difference = 10.2808888728
#   Difference = 10.5912006676
#   Difference = 10.6727654162
#   Difference = 10.2498699524
#   Difference = 10.3085898281
#   Difference = 10.4915203555
#   Difference = 10.4125312568
#   Difference = 10.3348634953
#   Difference = 10.5839511915
#   Difference = 10.3915666784
#   Difference = 10.3933823725
#   Difference = 10.6618548018
#   Difference = 10.5057015512
#   Difference = 9.9894892246
#   Difference = 10.2931769057
#   Difference = 10.2367519814
#   Difference = 10.3918312897
#   Difference = 10.0708169701
#   Difference = 10.4287371107
#   Difference = 10.4463090317
#   Difference = 10.4538974983
#   Difference = 10.2915143112
#   Difference = 10.4497713371
#   Difference = 10.3608431908
#   Difference = 10.2367241674
#   Difference = 10.5347190601
#   Difference = 10.3704668434
#   Difference = 10.2031837527
#   Difference = 10.2887874591
#   Difference = 10.2404845952
#   Difference = 10.3729112615
#   Difference = 10.3321837890
#   Difference = 10.3961943948
#   Difference = 10.4404786685
#   Difference = 10.3330151824
#   Difference = 10.2724584338
#   Difference = 10.4841902572
#   Difference = 10.3941347551
#   Difference = 10.4528917913
#   Difference = 10.3712933589
#   Difference = 10.3681749822
#   Difference = 10.5040769018
#   Difference = 10.3120148450
#   Difference = 10.6475831939
#   Difference = 10.3343378583
#   Difference = 10.6208119686
#   Difference = 10.4245886658
#   Difference = 10.5665708195
#   Difference = 9.6899446612
#   Difference = 10.1488299052
#   Difference = 10.1454817842
#   Difference = 10.4227257449
#   Difference = 10.3961598062
#   Difference = 10.2327008047
#   Difference = 10.6734294811
#   Difference = 10.5749840983
#   Difference = 10.5330981711
#   Difference = 10.2327433844
#   Difference = 10.1420456731
#   Difference = 10.7128195015
#   Difference = 10.4528430135
#   Difference = 10.4250297311
#   Difference = 10.5580790750
#   Difference = 10.4415298558
#   Difference = 10.2602953689
#   Difference = 10.3865684921
#   Difference = 10.1225773527
#   Difference = 10.2697237522
#   Difference = 10.5975512554
#   Difference = 10.3923288291
#   Difference = 10.2173606513
#   Difference = 10.6102214452
#   Difference = 10.3002325753
#   Difference = 10.2714292187
#   Difference = 10.3454249542
#   Difference = 10.7497309119
#   Difference = 10.2868048449
#   Difference = 7.9334455727
#   Difference = 8.3432443202
#   Difference = 8.2742863217
#   Difference = 8.8103859467
#   Difference = 7.9256417317
#   Difference = 8.2922779088
#   Difference = 8.9021182705
#   Difference = 7.9528367781
#   Difference = 8.9166353204
#   Difference = 8.5274574071
#   Difference = 8.2571709651
#   Difference = 8.5585425498
#   Difference = 8.0310637730
#   Difference = 8.0312032316
#   Difference = 8.3230206931
#   Difference = 8.5690996176
#   Difference = 8.1627556073
#   Difference = 8.2118110291
#   Difference = 8.6527736932
#   Difference = 7.8733918052
#   Difference = 8.3705790689
#   Difference = 8.1629455656
#   Difference = 8.2256150502
#   Difference = 8.4064169794
#   Difference = 8.3045946000
#   Difference = 8.7520131442
#   Difference = 8.4710895937
#   Difference = 7.6583523389
#   Difference = 8.5319213497
#   Difference = 8.6188819984
#   Difference = 8.4872384573
#   Difference = 8.1933849740
#   Difference = 8.6790598147
#   Difference = 8.6896872931
#   Difference = 8.7565654463
#   Difference = 8.2717759866
#   Difference = 8.4436559635
#   Difference = 8.3838293801
#   Difference = 8.1864192864
#   Difference = 8.4168015077
#   Difference = 8.1272055024
#   Difference = 8.5138344581
#   Difference = 8.5567524550
#   Difference = 8.4873000275
#   Difference = 8.3339545897
#   Difference = 7.8292879571
#   Difference = 8.1909251375
#   Difference = 8.6634138938
#   Difference = 8.2779465010
#   Difference = 8.1837287777
#   Difference = 8.7109518275
#   Difference = 8.4946796540
#   Difference = 8.3111970924
#   Difference = 8.4021753066
#   Difference = 8.2337353150
#   Difference = 7.8845791881
#   Difference = 8.2457295447
#   Difference = 8.1919157065
#   Difference = 8.5115525278
#   Difference = 8.0943605232
#   Difference = 8.3554064314
#   Difference = 8.1724401129
#   Difference = 8.6452450804
#   Difference = 8.2068875394
#   Difference = 8.3993601567
#   Difference = 8.2499744714
#   Difference = 8.5150667759
#   Difference = 8.1098565768
#   Difference = 8.2929660881
#   Difference = 8.5540698184
#   Difference = 8.2241092672
#   Difference = 8.6980258562
#   Difference = 8.5948120738
#   Difference = 8.1860700491
#   Difference = 8.6075200463
#   Difference = 8.1726975071
#   Difference = 8.3232954090
#   Difference = 8.4492304735
#   Difference = 8.3088316815
#   Difference = 8.3645056678
#   Difference = 8.0643987728
#   Difference = 8.0917339445
#   Difference = 8.5452507402
#   Difference = 8.5445610778
#   Difference = 8.5648677412
#   Difference = 8.7048692345
#   Difference = 8.4690159508
#   Difference = 8.3530515963
#   Difference = 8.1739696719
#   Difference = 8.5949632093
#   Difference = 8.5476849594
#   Difference = 8.5136019883
#   Difference = 8.2353835586
#   Difference = 7.8146825790
#   Difference = 7.9650405891
#   Difference = 8.5890488792
#   Difference = 8.0646352009
#   Difference = 8.1627015131
#   Difference = 8.6317281227
#   Difference = 8.4729254265
#   Difference = 8.2754846603
#   Difference = 8.4837426625
#   Difference = 8.5940331596
#   Difference = 8.1543275649
#   Difference = 8.3133434039
#   Difference = 8.5315718112
#   Difference = 8.1834022199
#   Difference = 8.2902590540
#   Difference = 8.3357534021
#   Difference = 8.6367907456
#   Difference = 8.4286165152
#   Difference = 8.5706805862
#   Difference = 7.8157053983
#   Difference = 8.0884619550
#   Difference = 8.1522348526
#   Difference = 8.1134982345
#   Difference = 8.1956666847
#   Difference = 8.5093313158
#   Difference = 8.3059204128
#   Difference = 8.4855511783
#   Difference = 8.1931533947
#   Difference = 8.2981832239
#   Difference = 8.3240022309
#   Difference = 8.0725400598
#   Difference = 8.4352905374
#   Difference = 8.5225022912
#   Difference = 8.3531231432
#   Difference = 8.2322878916
#   Difference = 8.4113902808
#   Difference = 8.2952104647
#   Difference = 8.3698500567
#   Difference = 8.7066248581
#   Difference = 8.1848369526
#   Difference = 8.4482383413
#   Difference = 8.7443900355
#   Difference = 7.8664500822
#   Difference = 8.3319448107
#   Difference = 8.2505094927
#   Difference = 8.9959745064
#   Difference = 8.3359790308
#   Difference = 8.2681067216
#   Difference = 8.3686855757
#   Difference = 7.8363267102
#   Difference = 8.1902055018
#   Difference = 8.0322603064
#   Difference = 8.7106586296
#   Difference = 8.2677210232
#   Difference = 8.4501145702
#   Difference = 8.2744675709
#   Difference = 8.3727690312
#   Difference = 8.1324922062
#   Difference = 8.1515769516
#   Difference = 8.2480038161
#   Difference = 8.0917944997
#   Difference = 8.1912157017
#   Difference = 7.8461807808
#   Difference = 8.2733154662
#   Difference = 8.1419947800
#   Difference = 8.2906312137
#   Difference = 8.1953851548
#   Difference = 8.3454537018
#   Difference = 8.2291291798
#   Difference = 8.4288062901
#   Difference = 8.3669645384
#   Difference = 8.4162529168
#   Difference = 8.6420048900
#   Difference = 8.4374740690
#   Difference = 8.8467082382
#   Difference = 8.5013744184
#   Difference = 8.4855770413
#   Difference = 8.5208942409
#   Difference = 8.5956524922
#   Difference = 8.1421523436
#   Difference = 8.1876922534
#   Difference = 8.2921935554
#   Difference = 8.1919333438
#   Difference = 7.7487850232
#   Difference = 8.6836115565
#   Difference = 8.5378963548
#   Difference = 8.3289530342
#   Difference = 7.6452721739
#   Difference = 8.5766761018
#   Difference = 7.5977088121
#   Difference = 8.5225468065
#   Difference = 8.3733639421
#   Difference = 8.3326190638
#   Difference = 8.5716149855
#   Difference = 7.9328428236
#   Difference = 7.9890251452
#   Difference = 8.4706035674
#   Difference = 8.6215641231
#   Difference = 8.8131167724
#   Difference = 8.3731425108
#   Difference = 8.3694896937
#   Difference = 8.0368245507
#   Difference = 8.4835858758
#   Difference = 8.3169335894
#   Difference = 8.6054765297
#   Difference = 8.4303540174
#   Difference = 8.6948286459
#   Difference = 8.3328332960
#   Difference = 8.0570561536
#   Difference = 8.4452491087
#   Difference = 8.0782621605
#   Difference = 8.6553135886
#   Difference = 8.4322793162
#   Difference = 8.3741010411
#   Difference = 8.3486949656
#   Difference = 8.5243113427
#   Difference = 8.2862909091
#   Difference = 8.2551600091
#   Difference = 8.1371273156
#   Difference = 8.3307541119
#   Difference = 8.4523539187
#   Difference = 8.0575199844
#   Difference = 8.3094139119
#   Difference = 8.0561416591
#   Difference = 8.6619903211
#   Difference = 8.4988480422
#   Difference = 8.2783793435
#   Difference = 8.4937975941
#   Difference = 8.4162051804
#   Difference = 8.9820152375
#   Difference = 8.5244263892
#   Difference = 8.3966793902
#   Difference = 8.4577167069
#   Difference = 8.5335072221
#   Difference = 8.3900134697
#   Difference = 8.4633047229
#   Difference = 8.6457758644
#   Difference = 8.3701845355
#   Difference = 8.3649900729
#   Difference = 8.4740188544
#   Difference = 8.6105230891
#   Difference = 8.5261408347
#   Difference = 7.9591049373
#   Difference = 8.2131572541
#   Difference = 8.2043204094
#   Difference = 8.5876564928
#   Difference = 8.2618816711
#   Difference = 8.4431026908
#   Difference = 8.0541599359
#   Difference = 8.6779764523
#   Difference = 8.7244913151
#   Difference = 8.5593082567
#   Difference = 8.4760639816
#   Difference = 8.2563693550
#   Difference = 8.0948219940
#   Difference = 8.3319932096
#   Difference = 8.1841743486
#   Difference = 7.7270471660
#   Difference = 8.6104535741
#   Difference = 8.5901172363
#   Difference = 8.0167271340
#   Difference = 8.4097772911
#   Difference = 8.1545575300
#   Difference = 8.2526343330
#   Difference = 8.3697965059
#   Difference = 8.4122183571
#   Difference = 7.9534669839
#   Difference = 8.5031101979
#   Difference = 8.5973160750
#   Difference = 8.5011826870
#   Difference = 8.5943601387
#   Difference = 7.8993444197
#   Difference = 8.1703833591
#   Difference = 8.3953471838
#   Difference = 8.3594581523
#   Difference = 8.6115051997
#   Difference = 8.6586235674
#   Difference = 8.1323626754
#   Difference = 8.4920722301
#   Difference = 8.4547498545
#   Difference = 8.2565086596
#   Difference = 8.3519284652
#   Difference = 8.2687619289
#   Difference = 8.5712492899
#   Difference = 8.1037392557
#   Difference = 8.7947106376
#   Difference = 8.7754289244
#   Difference = 8.3848031872
#   Difference = 8.7267853501
#   Difference = 8.3345578975
#   Difference = 8.3348426314
#   Difference = 8.4152600484
#   Difference = 8.2901320833
#   Difference = 8.3172653066
#   Difference = 8.1343746410
#   Difference = 7.9862101624
#   Difference = 8.8088552520
#   Difference = 8.2703768881
#   Difference = 8.6483899410
#   Difference = 8.3327084239
#   Difference = 8.1581754404
#   Difference = 8.4052092158
#   Difference = 8.2426211180
#   Difference = 8.3563150969
#   Difference = 8.4635067155
#   Difference = 8.4932888045
#   Difference = 8.2288510882
#   Difference = 5.8642366882
#   Difference = 6.0971604975
#   Difference = 6.5519944598
#   Difference = 5.7220885015
#   Difference = 6.3183343637
#   Difference = 6.4341706325
#   Difference = 6.0577239940
#   Difference = 6.4469337201
#   Difference = 6.8212467708
#   Difference = 6.4008469845
#   Difference = 6.0659846994
#   Difference = 6.1283393163
#   Difference = 6.5935335209
#   Difference = 6.2662699222
#   Difference = 6.1366005637
#   Difference = 5.9183563578
#   Difference = 5.8657800757
#   Difference = 6.5709685430
#   Difference = 5.7895387349
#   Difference = 6.2691193314
#   Difference = 6.3138478528
#   Difference = 6.3604075573
#   Difference = 6.7922079888
#   Difference = 6.3127672552
#   Difference = 5.9983640188
#   Difference = 5.9823102626
#   Difference = 6.6656604220
#   Difference = 6.1907854194
#   Difference = 6.3759319849
#   Difference = 6.2387342791
#   Difference = 6.2268650420
#   Difference = 6.1909425972
#   Difference = 6.1702967110
#   Difference = 6.5291434997
#   Difference = 6.3919584720
#   Difference = 6.4299218771
#   Difference = 6.0308162297
#   Difference = 6.1663365745
#   Difference = 6.8759452963
#   Difference = 6.7138663016
#   Difference = 6.4478558086
#   Difference = 6.7894990034
#   Difference = 6.2483051075
#   Difference = 6.1984691265
#   Difference = 6.3496698990
#   Difference = 6.3198238963
#   Difference = 6.6351743026
#   Difference = 6.1114539867
#   Difference = 6.1784039440
#   Difference = 7.0140378828
#   Difference = 6.4566258912
#   Difference = 6.3407663982
#   Difference = 6.0493620723
#   Difference = 6.9351573679
#   Difference = 6.7887515615
#   Difference = 6.0285061556
#   Difference = 6.0972396810
#   Difference = 6.2855983214
#   Difference = 6.4267513908
#   Difference = 6.1356422248
#   Difference = 6.5566574859
#   Difference = 6.6000575952
#   Difference = 6.5476865339
#   Difference = 6.5374331201
#   Difference = 6.4761840508
#   Difference = 5.8189276910
#   Difference = 6.5912300809
#   Difference = 6.3599234094
#   Difference = 6.2643582194
#   Difference = 5.8067890140
#   Difference = 6.3116636577
#   Difference = 6.2700237949
#   Difference = 6.3483652182
#   Difference = 6.2283043526
#   Difference = 6.5074122141
#   Difference = 6.1619086239
#   Difference = 6.2505906312
#   Difference = 6.1343330968
#   Difference = 6.7407201785
#   Difference = 7.0527579622
#   Difference = 6.5694154908
#   Difference = 6.7545433922
#   Difference = 6.7923694926
#   Difference = 6.0884987145
#   Difference = 6.9671271573
#   Difference = 6.2237041954
#   Difference = 6.6744404109
#   Difference = 5.9003905497
#   Difference = 6.9088114620
#   Difference = 6.4074606066
#   Difference = 6.6569711504
#   Difference = 6.0363903604
#   Difference = 6.6469329605
#   Difference = 7.1318641942
#   Difference = 6.0977455071
#   Difference = 6.0686934126
#   Difference = 6.3008728604
#   Difference = 6.8376629706
#   Difference = 5.9890059772
#   Difference = 6.3403003156
#   Difference = 6.8198474330
#   Difference = 6.4334372903
#   Difference = 6.0755160845
#   Difference = 6.7105501755
#   Difference = 6.4061234080
#   Difference = 6.2115406902
#   Difference = 6.2979263324
#   Difference = 6.1365955215
#   Difference = 6.8296185871
#   Difference = 6.4160536932
#   Difference = 6.1206246502
#   Difference = 6.2722747796
#   Difference = 6.2710793225
#   Difference = 6.1867793113
#   Difference = 6.3582107947
#   Difference = 6.2591287845
#   Difference = 5.9700122136
#   Difference = 6.3871947973
#   Difference = 6.4112527682
#   Difference = 5.6943081801
#   Difference = 6.0108980680
#   Difference = 6.4512364420
#   Difference = 6.2103946846
#   Difference = 6.1762942562
#   Difference = 6.0983255792
#   Difference = 6.1906869261
#   Difference = 6.3951159208
#   Difference = 5.7538819096
#   Difference = 6.2384130052
#   Difference = 5.9121375838
#   Difference = 6.8703758347
#   Difference = 6.4123718026
#   Difference = 6.0488926018
#   Difference = 6.0573540218
#   Difference = 6.9727264516
#   Difference = 7.0007777482
#   Difference = 6.2539754169
#   Difference = 6.6127166094
#   Difference = 6.4533579851
#   Difference = 6.3491068570
#   Difference = 6.4920226173
#   Difference = 6.8589151493
#   Difference = 5.8448204615
#   Difference = 6.4148408549
#   Difference = 6.1547421252
#   Difference = 6.4462625871
#   Difference = 6.5362111194
#   Difference = 6.2490657364
#   Difference = 6.2368873374
#   Difference = 6.6917310724
#   Difference = 6.4906111911
#   Difference = 6.1300629281
#   Difference = 6.5143343808
#   Difference = 6.2894185163
#   Difference = 6.9585045630
#   Difference = 6.4883013530
#   Difference = 6.1904308810
#   Difference = 6.3731150094
#   Difference = 6.6752434522
#   Difference = 6.2479089870
#   Difference = 6.6297532305
#   Difference = 6.4059291327
#   Difference = 5.9779430092
#   Difference = 6.3381746344
#   Difference = 6.3520682663
#   Difference = 6.1265871084
#   Difference = 6.3139363612
#   Difference = 6.2125731810
#   Difference = 6.6187535411
#   Difference = 6.5783703461
#   Difference = 6.0359558731
#   Difference = 6.0668101661
#   Difference = 6.7764947010
#   Difference = 6.2906131450
#   Difference = 6.2681833639
#   Difference = 6.1464299779
#   Difference = 6.8845447473
#   Difference = 6.1660002117
#   Difference = 6.5463320951
#   Difference = 6.4948049744
#   Difference = 5.9394744073
#   Difference = 6.0332508228
#   Difference = 6.3374419845
#   Difference = 6.1684529779
#   Difference = 6.4757013007
#   Difference = 6.4524492509
#   Difference = 6.4589380515
#   Difference = 6.8120124055
#   Difference = 6.5248726749
#   Difference = 6.2970883119
#   Difference = 6.8338871385
#   Difference = 5.8670640592
#   Difference = 6.2089298465
#   Difference = 6.3591131997
#   Difference = 6.1779396340
#   Difference = 6.4687989692
#   Difference = 6.2692795108
#   Difference = 6.0927142949
#   Difference = 5.9929182158
#   Difference = 6.2288510005
#   Difference = 6.3925564066
#   Difference = 6.5345431466
#   Difference = 6.3836996348
#   Difference = 5.8693121977
#   Difference = 6.5124070440
#   Difference = 6.1677829644
#   Difference = 6.5354697780
#   Difference = 6.4124703316
#   Difference = 6.6094468836
#   Difference = 6.2169629623
#   Difference = 6.0772904750
#   Difference = 6.5188495366
#   Difference = 6.3097227677
#   Difference = 6.3505635915
#   Difference = 6.8757512020
#   Difference = 6.1168462865
#   Difference = 6.1463930058
#   Difference = 6.5169910557
#   Difference = 6.0421453100
#   Difference = 6.4267721752
#   Difference = 6.4465845272
#   Difference = 6.8013258058
#   Difference = 6.1907332692
#   Difference = 6.2689274000
#   Difference = 6.5920835630
#   Difference = 6.7100477069
#   Difference = 6.4357470165
#   Difference = 7.2984380033
#   Difference = 5.9921865052
#   Difference = 6.7486918425
#   Difference = 6.0379931424
#   Difference = 5.6937262203
#   Difference = 6.6533407313
#   Difference = 6.6091822635
#   Difference = 5.9275327578
#   Difference = 6.2485469392
#   Difference = 6.5546743571
#   Difference = 6.3576722816
#   Difference = 6.5489273299
#   Difference = 6.5351875303
#   Difference = 6.5585032830
#   Difference = 6.9141530475
#   Difference = 6.2797549732
#   Difference = 5.3714305438
#   Difference = 6.1846549130
#   Difference = 6.4119483837
#   Difference = 6.4719503883
#   Difference = 6.2469924827
#   Difference = 6.5856790097
#   Difference = 6.1350181793
#   Difference = 6.7631714865
#   Difference = 6.4581456590
#   Difference = 6.5577286609
#   Difference = 6.3716390446
#   Difference = 6.0379539631
#   Difference = 6.2000755933
#   Difference = 6.7490884862
#   Difference = 6.3605029601
#   Difference = 5.9985980403
#   Difference = 6.6754607983
#   Difference = 6.5343413127
#   Difference = 6.5705387276
#   Difference = 6.0720758983
#   Difference = 6.3260566491
#   Difference = 6.3705948396
#   Difference = 6.1171318322
#   Difference = 6.0744571993
#   Difference = 6.1320204767
#   Difference = 6.2935190038
#   Difference = 5.7919180039
#   Difference = 6.1677334388
#   Difference = 6.2760162246
#   Difference = 6.1739419230
#   Difference = 6.3311291611
#   Difference = 6.2878645497
#   Difference = 5.3364294911
#   Difference = 6.1087423006
#   Difference = 6.0000849597
#   Difference = 6.2721274196
#   Difference = 6.9112434852
#   Difference = 6.3235986724
#   Difference = 6.2475132562
#   Difference = 6.4375762549
#   Difference = 6.5923444251
#   Difference = 6.4436171647
#   Difference = 6.0494422190
#   Difference = 6.2937491210
#   Difference = 7.0504062082
#   Difference = 6.2410534679
#   Difference = 6.4676916836
#   Difference = 6.1891544372
#   Difference = 6.5313572043
#   Difference = 6.9575752002
#   Difference = 6.4862689554
#   Difference = 6.3349356494
#   Difference = 6.3664941845
#   Difference = 6.4433104700
#   Difference = 6.3077552472
#   Difference = 6.5539188341
#   Difference = 6.3955214793
#   Difference = 5.1896149316
#   Difference = 4.3010609134
#   Difference = 3.9183417394
#   Difference = 5.1320534896
#   Difference = 4.5116845807
#   Difference = 4.5159747243
#   Difference = 4.5684188536
#   Difference = 4.6340629507
#   Difference = 4.3109737510
#   Difference = 4.4375010847
#   Difference = 3.8311851960
#   Difference = 4.5103114528
#   Difference = 4.3739317429
#   Difference = 4.1293770158
#   Difference = 4.2964922758
#   Difference = 4.0890711693
#   Difference = 5.0375656534
#   Difference = 4.6367824413
#   Difference = 5.2228463484
#   Difference = 4.5115777965
#   Difference = 4.6571630540
#   Difference = 4.2225918620
#   Difference = 3.8757528937
#   Difference = 4.3773373229
#   Difference = 4.8583836837
#   Difference = 4.5312606178
#   Difference = 4.7798328310
#   Difference = 4.4268356576
#   Difference = 4.0539590505
#   Difference = 4.5134643390
#   Difference = 4.3816025496
#   Difference = 4.6094448031
#   Difference = 4.7595744224
#   Difference = 4.3268430789
#   Difference = 4.3866560721
#   Difference = 4.2866109769
#   Difference = 4.0914012928
#   Difference = 3.9290692141
#   Difference = 4.1746217341
#   Difference = 3.8349120780
#   Difference = 4.4358172586
#   Difference = 4.7700364789
#   Difference = 4.3263505179
#   Difference = 4.7476874979
#   Difference = 4.3715658595
#   Difference = 4.5747008296
#   Difference = 4.7775514686
#   Difference = 4.4307097299
#   Difference = 4.1704828298
#   Difference = 4.9555877037
#   Difference = 5.2382073577
#   Difference = 3.6538644586
#   Difference = 4.3770255287
#   Difference = 4.3097969627
#   Difference = 4.4348747108
#   Difference = 4.4619259589
#   Difference = 3.8971809661
#   Difference = 4.2421880388
#   Difference = 4.6231564588
#   Difference = 4.4361007526
#   Difference = 3.5773898880
#   Difference = 4.8345064524
#   Difference = 4.3132524002
#   Difference = 4.5449429990
#   Difference = 4.1930610637
#   Difference = 4.1754243930
#   Difference = 4.5751234744
#   Difference = 4.0330611671
#   Difference = 4.7220890933
#   Difference = 4.5748779550
#   Difference = 4.4596331804
#   Difference = 4.4595735796
#   Difference = 4.2439076433
#   Difference = 4.5460092170
#   Difference = 4.1374825460
#   Difference = 3.9275999147
#   Difference = 4.2292712531
#   Difference = 4.6163555038
#   Difference = 4.0272069543
#   Difference = 4.2361495079
#   Difference = 4.6176751279
#   Difference = 4.5881558349
#   Difference = 4.3950223329
#   Difference = 4.1286537914
#   Difference = 4.4401425939
#   Difference = 4.5161877070
#   Difference = 4.4874928816
#   Difference = 3.7339489475
#   Difference = 4.6810272148
#   Difference = 4.5120904757
#   Difference = 4.3534701749
#   Difference = 4.2359643626
#   Difference = 4.1581765774
#   Difference = 4.2194592683
#   Difference = 4.1349795735
#   Difference = 4.7902318326
#   Difference = 3.9302996859
#   Difference = 4.8919455186
#   Difference = 4.6921480620
#   Difference = 4.6221389322
#   Difference = 4.1400630568
#   Difference = 4.2411483707
#   Difference = 4.3345327306
#   Difference = 4.7553222302
#   Difference = 4.3537075118
#   Difference = 4.3809631036
#   Difference = 4.3604923753
#   Difference = 4.7690457885
#   Difference = 3.8098456294
#   Difference = 4.4339223100
#   Difference = 4.4971171058
#   Difference = 4.4518645038
#   Difference = 4.2555214133
#   Difference = 4.1941416721
#   Difference = 4.4679263280
#   Difference = 4.1693409533
#   Difference = 4.3552024430
#   Difference = 4.4082781248
#   Difference = 4.1935050726
#   Difference = 4.8919666385
#   Difference = 4.2954026127
#   Difference = 4.3318776515
#   Difference = 4.7065815835
#   Difference = 4.2892508155
#   Difference = 4.5487353158
#   Difference = 4.6797633068
#   Difference = 4.4807310237
#   Difference = 4.0401183537
#   Difference = 4.0566082403
#   Difference = 4.6663592000
#   Difference = 3.7835774445
#   Difference = 4.1877851847
#   Difference = 4.4482890499
#   Difference = 5.0772575195
#   Difference = 4.1767346289
#   Difference = 3.6249893977
#   Difference = 4.5358806816
#   Difference = 4.5316430316
#   Difference = 4.3964658815
#   Difference = 4.2433962658
#   Difference = 4.1313088647
#   Difference = 3.9117328841
#   Difference = 4.1393196211
#   Difference = 4.6285026534
#   Difference = 3.8773300937
#   Difference = 4.5897113188
#   Difference = 3.9539054230
#   Difference = 4.4969356124
#   Difference = 3.9776462471
#   Difference = 3.8374269315
#   Difference = 5.0909645300
#   Difference = 4.2131240616
#   Difference = 4.4189806166
#   Difference = 4.7976748862
#   Difference = 4.8392076929
#   Difference = 3.9556925799
#   Difference = 4.0938852327
#   Difference = 4.3340531048
#   Difference = 4.7921345550
#   Difference = 4.6712689898
#   Difference = 3.5985086999
#   Difference = 4.2676885972
#   Difference = 4.3563682834
#   Difference = 3.6924567264
#   Difference = 4.1720055918
#   Difference = 4.4119888531
#   Difference = 4.7866935652
#   Difference = 5.0266765995
#   Difference = 4.4492275141
#   Difference = 4.8229024793
#   Difference = 3.7425710215
#   Difference = 4.3728310063
#   Difference = 4.5359851459
#   Difference = 4.6354018274
#   Difference = 4.2810298757
#   Difference = 4.3021583098
#   Difference = 4.6335587746
#   Difference = 4.6315818077
#   Difference = 4.3745752102
#   Difference = 4.3912290056
#   Difference = 4.2205197510
#   Difference = 4.0002579392
#   Difference = 4.2027361302
#   Difference = 4.6393244909
#   Difference = 4.2957554696
#   Difference = 4.4997267728
#   Difference = 4.2201711061
#   Difference = 4.5145842008
#   Difference = 4.4033159254
#   Difference = 4.4202905112
#   Difference = 4.1492168750
#   Difference = 4.2515276164
#   Difference = 4.0706379921
#   Difference = 4.5530882869
#   Difference = 4.6752150419
#   Difference = 4.3607398337
#   Difference = 4.1410571310
#   Difference = 4.3179027596
#   Difference = 4.3705952788
#   Difference = 4.6804061487
#   Difference = 4.4909725385
#   Difference = 4.5811568605
#   Difference = 4.6496376230
#   Difference = 4.0977654222
#   Difference = 4.5670288383
#   Difference = 4.1583470377
#   Difference = 4.3578192865
#   Difference = 4.2709859392
#   Difference = 3.9772521683
#   Difference = 3.8395455151
#   Difference = 4.5381820812
#   Difference = 4.9491515329
#   Difference = 3.8129033525
#   Difference = 4.1123884940
#   Difference = 4.2724560224
#   Difference = 4.6267742548
#   Difference = 4.4165716645
#   Difference = 4.7552393605
#   Difference = 4.8973649867
#   Difference = 4.3970234239
#   Difference = 4.1181926724
#   Difference = 3.6224001535
#   Difference = 4.8991436297
#   Difference = 4.2772444055
#   Difference = 4.1968132347
#   Difference = 4.2708565541
#   Difference = 4.1193831015
#   Difference = 5.1401357062
#   Difference = 3.8884462332
#   Difference = 4.5787937806
#   Difference = 4.3210259798
#   Difference = 4.0713313595
#   Difference = 4.5081269550
#   Difference = 3.5348384573
#   Difference = 4.7192750462
#   Difference = 4.6251365844
#   Difference = 4.5814872657
#   Difference = 4.5008551527
#   Difference = 4.4871938829
#   Difference = 4.9370925172
#   Difference = 4.2191703054
#   Difference = 4.0966255934
#   Difference = 4.1435643078
#   Difference = 4.6187506869
#   Difference = 4.1672472501
#   Difference = 3.9113719427
#   Difference = 4.5902613669
#   Difference = 4.6888617438
#   Difference = 4.3089596074
#   Difference = 3.9917219743
#   Difference = 4.2412700243
#   Difference = 4.5143457691
#   Difference = 4.9162121042
#   Difference = 4.5520119001
#   Difference = 4.4532264632
#   Difference = 3.9361657548
#   Difference = 4.5552085432
#   Difference = 4.4688598364
#   Difference = 4.0929332809
#   Difference = 4.2201563422
#   Difference = 4.2150257331
#   Difference = 4.3517772881
#   Difference = 3.9787921780
#   Difference = 4.4166273222
#   Difference = 4.3111777650
#   Difference = 4.4717674766
#   Difference = 4.4762213218
#   Difference = 4.4916324442
#   Difference = 4.0721911654
#   Difference = 3.9713076927
#   Difference = 4.3284040421
#   Difference = 3.5976878971
#   Difference = 3.8163991477
#   Difference = 4.3750496611
#   Difference = 4.6802430306
#   Difference = 4.1196948735
#   Difference = 4.0141186081
#   Difference = 4.6967701673
#   Difference = 4.5689332449
#   Difference = 4.2427625147
#   Difference = 4.5529902381
#   Difference = 4.0764891715
#   Difference = 4.2499153410
#   Difference = 4.7274429291
#   Difference = 3.7790933552
#   Difference = 3.5017868467
#   Difference = 4.6229082797
#   Difference = 4.8332304782
#   Difference = 4.1187241711
#   Difference = 4.5740576207
#   Difference = 3.9904344504
#   Difference = 3.8549678077
#   Difference = 3.9991384573
#   Difference = 4.0799288605
#   Difference = 4.5494232548
#   Difference = 4.5754497231
#   Difference = 4.0893107941
#   Difference = 4.9768990359
#   Difference = 4.9278570584
#   Difference = 4.0372260565
#   Difference = 2.1831379604
#   Difference = 2.1113562576
#   Difference = 2.7148752791
#   Difference = 2.4431122445
#   Difference = 2.1992303048
#   Difference = 2.8463926911
#   Difference = 2.5031902116
#   Difference = 2.6153438992
#   Difference = 2.3909301965
#   Difference = 1.6392254437
#   Difference = 2.3201769221
#   Difference = 2.5197170524
#   Difference = 2.4826706385
#   Difference = 2.3556354802
#   Difference = 1.8793128812
#   Difference = 2.3575620591
#   Difference = 2.4569133976
#   Difference = 2.5602570153
#   Difference = 2.8759945963
#   Difference = 2.0608360361
#   Difference = 2.2369685260
#   Difference = 2.6738892455
#   Difference = 1.8547662185
#   Difference = 2.2619481592
#   Difference = 2.9092512775
#   Difference = 1.6606645873
#   Difference = 1.8911715919
#   Difference = 2.5434311485
#   Difference = 2.6976286301
#   Difference = 2.1301004292
#   Difference = 2.9210168937
#   Difference = 2.3329211920
#   Difference = 2.0699261867
#   Difference = 2.3316529535
#   Difference = 2.6311636397
#   Difference = 2.2412801213
#   Difference = 2.4836871943
#   Difference = 1.8893205312
#   Difference = 2.1243227605
#   Difference = 2.5021992320
#   Difference = 2.9238684776
#   Difference = 2.8430497795
#   Difference = 2.4755901923
#   Difference = 2.8228770729
#   Difference = 1.3331493088
#   Difference = 2.4632906300
#   Difference = 2.6790666666
#   Difference = 3.0573859835
#   Difference = 1.9802768568
#   Difference = 1.9746191859
#   Difference = 2.5741077237
#   Difference = 1.7054822299
#   Difference = 2.2719865319
#   Difference = 2.2037613144
#   Difference = 3.0723544377
#   Difference = 2.0034148466
#   Difference = 2.4582728223
#   Difference = 2.4408956309
#   Difference = 2.5601105277
#   Difference = 2.5214126385
#   Difference = 1.9557068470
#   Difference = 2.1920992699
#   Difference = 2.5156914436
#   Difference = 2.8114759774
#   Difference = 1.9832125582
#   Difference = 2.4952800406
#   Difference = 2.2986627460
#   Difference = 1.9607217162
#   Difference = 2.6045275963
#   Difference = 2.2980329533
#   Difference = 2.0123531294
#   Difference = 2.1613522844
#   Difference = 2.6831776617
#   Difference = 1.8051739053
#   Difference = 2.4380321026
#   Difference = 2.6496156070
#   Difference = 2.0230830024
#   Difference = 2.6022034447
#   Difference = 2.4948522632
#   Difference = 2.5775548840
#   Difference = 2.7398347683
#   Difference = 2.8993091200
#   Difference = 2.3009615093
#   Difference = 2.0725598099
#   Difference = 2.5912012605
#   Difference = 1.8015073918
#   Difference = 2.7511903741
#   Difference = 2.2090848676
#   Difference = 2.0537925250
#   Difference = 2.2598789030
#   Difference = 2.6182567099
#   Difference = 2.0338185239
#   Difference = 2.0741116970
#   Difference = 2.4809147666
#   Difference = 2.1858585955
#   Difference = 2.4780213617
#   Difference = 2.6806696013
#   Difference = 2.5456829137
#   Difference = 2.0951506135
#   Difference = 2.4982027638
#   Difference = 2.1942589705
#   Difference = 2.2992113592
#   Difference = 1.6559550902
#   Difference = 2.5361592965
#   Difference = 2.7527528955
#   Difference = 2.4827192630
#   Difference = 1.5905661055
#   Difference = 2.3107824921
#   Difference = 2.1762407537
#   Difference = 1.4001986167
#   Difference = 1.9942624254
#   Difference = 2.6702928052
#   Difference = 2.3524435978
#   Difference = 2.4279769654
#   Difference = 2.4443307482
#   Difference = 2.6844525046
#   Difference = 2.4999190360
#   Difference = 2.1838617066
#   Difference = 2.3168084759
#   Difference = 2.8976014041
#   Difference = 2.3619768505
#   Difference = 2.4573517664
#   Difference = 2.6179527547
#   Difference = 2.2850823258
#   Difference = 2.7015589626
#   Difference = 2.0382733184
#   Difference = 2.1437628326
#   Difference = 1.9558728507
#   Difference = 2.0716736196
#   Difference = 1.5622606223
#   Difference = 2.3120418676
#   Difference = 2.4557936455
#   Difference = 2.5954219638
#   Difference = 2.2994809633
#   Difference = 2.1537021729
#   Difference = 2.4966399049
#   Difference = 2.3309562831
#   Difference = 3.1003080865
#   Difference = 2.2017740354
#   Difference = 2.2757488613
#   Difference = 2.3114379066
#   Difference = 2.9024292469
#   Difference = 2.0421887503
#   Difference = 2.8050446922
#   Difference = 2.1154923131
#   Difference = 2.1649063462
#   Difference = 2.7113653220
#   Difference = 2.1982393723
#   Difference = 2.2801518549
#   Difference = 2.6091757068
#   Difference = 2.0724823828
#   Difference = 2.3522391517
#   Difference = 3.0007485767
#   Difference = 2.4397647023
#   Difference = 2.2934471802
#   Difference = 2.3095019684
#   Difference = 2.1793754559
#   Difference = 2.3986164076
#   Difference = 2.2001939865
#   Difference = 2.7717695241
#   Difference = 2.3781585484
#   Difference = 2.1364059297
#   Difference = 2.1287771162
#   Difference = 2.6022430440
#   Difference = 2.2776362414
#   Difference = 2.5317715953
#   Difference = 1.7835865238
#   Difference = 2.1788153096
#   Difference = 1.7769258868
#   Difference = 1.9725973715
#   Difference = 2.1975042969
#   Difference = 2.1212351853
#   Difference = 2.5772345399
#   Difference = 2.3138230011
#   Difference = 2.6914323646
#   Difference = 2.0176698596
#   Difference = 2.8593942636
#   Difference = 2.0761734601
#   Difference = 2.1784377590
#   Difference = 2.0512967990
#   Difference = 2.6641347298
#   Difference = 2.9620968721
#   Difference = 2.3765073693
#   Difference = 2.4626388751
#   Difference = 2.4315705406
#   Difference = 2.7198940905
#   Difference = 2.3925309250
#   Difference = 2.9219865958
#   Difference = 2.0563671012
#   Difference = 2.7414139774
#   Difference = 2.1349709001
#   Difference = 2.5532297888
#   Difference = 3.1705722508
#   Difference = 2.2832780610
#   Difference = 2.5769973688
#   Difference = 2.7205848446
#   Difference = 2.2240297111
#   Difference = 1.9574361909
#   Difference = 1.9548287380
#   Difference = 2.8311073548
#   Difference = 2.2981417610
#   Difference = 2.5109296460
#   Difference = 1.8294213752
#   Difference = 2.5221329887
#   Difference = 2.3551197680
#   Difference = 1.9820038106
#   Difference = 2.5494346989
#   Difference = 1.9578383847
#   Difference = 2.9006617912
#   Difference = 2.1334889231
#   Difference = 2.4440817907
#   Difference = 2.4889386043
#   Difference = 2.4487973460
#   Difference = 2.1759287181
#   Difference = 2.4151612194
#   Difference = 3.0158763079
#   Difference = 1.6961996662
#   Difference = 1.8239033612
#   Difference = 1.9447837803
#   Difference = 2.8045582551
#   Difference = 2.2721396667
#   Difference = 2.6249404448
#   Difference = 2.5758667228
#   Difference = 2.4027581255
#   Difference = 2.5618775166
#   Difference = 2.9143407855
#   Difference = 2.3366216483
#   Difference = 2.2522510306
#   Difference = 2.3509192561
#   Difference = 2.3322669684
#   Difference = 1.3293814048
#   Difference = 2.0900867937
#   Difference = 2.4602114592
#   Difference = 2.0257314109
#   Difference = 2.2942557916
#   Difference = 2.9014886094
#   Difference = 2.8330312876
#   Difference = 2.7434886866
#   Difference = 2.0761381517
#   Difference = 2.0358058497
#   Difference = 2.2027301432
#   Difference = 2.8473283070
#   Difference = 2.3107016727
#   Difference = 2.5559414345
#   Difference = 2.8750582774
#   Difference = 2.3711978240
#   Difference = 2.2713611218
#   Difference = 2.5896128241
#   Difference = 2.6104276594
#   Difference = 2.3361715699
#   Difference = 2.0920909304
#   Difference = 2.1440843739
#   Difference = 2.3005108164
#   Difference = 2.0768102915
#   Difference = 1.9504395266
#   Difference = 2.2974946687
#   Difference = 2.4174496477
#   Difference = 2.5354551191
#   Difference = 2.4587710190
#   Difference = 2.7081279990
#   Difference = 2.5145750348
#   Difference = 2.0985413141
#   Difference = 2.4188519050
#   Difference = 2.5111998302
#   Difference = 3.3732086854
#   Difference = 2.2312729561
#   Difference = 2.3948365142
#   Difference = 2.5402074105
#   Difference = 2.3897419784
#   Difference = 1.5346161327
#   Difference = 2.3597846290
#   Difference = 2.7303114354
#   Difference = 2.2807134227
#   Difference = 2.0763401771
#   Difference = 2.3077734732
#   Difference = 2.1506026531
#   Difference = 2.0378216471
#   Difference = 2.9721283787
#   Difference = 2.1900438891
#   Difference = 2.4561439112
#   Difference = 2.3834746352
#   Difference = 1.5434654993
#   Difference = 2.3317960993
#   Difference = 2.5192139054
#   Difference = 1.9250792846
#   Difference = 2.4833331713
#   Difference = 2.5046515542
#   Difference = 2.3492755168
#   Difference = 2.6483748879
#   Difference = 2.7800100135
#   Difference = 2.0428885258
#   Difference = 2.0048925031
#   Difference = 2.6603616711
#   Difference = 2.7905559747
#   Difference = 2.6323558870
#   Difference = 2.2530297451
#   Difference = 2.3436905645
#   Difference = 1.7874434853
#   Difference = 2.6650850095
#   Difference = 2.1716724235
#   Difference = 0.2193539855
#   Difference = 0.1371923258
#   Difference = 0.8382170408
#   Difference = 1.2049628792
#   Difference = 0.3802561197
#   Difference = 0.4216103260
#   Difference = 0.1585420509
#   Difference = 0.6397778372
#   Difference = 0.2645675408
#   Difference = 0.1981059375
#   Difference = 0.4151939551
#   Difference = 0.8221337443
#   Difference = 0.5789295717
#   Difference = 0.4958835717
#   Difference = 0.8273515826
#   Difference = 0.1637986090
#   Difference = 0.6603133653
#   Difference = 0.8229661318
#   Difference = 0.5022982347
#   Difference = 0.6367861876
#   Difference = 0.3002361160
#   Difference = 0.4791020406
#   Difference = 0.3553117231
#   Difference = 0.0542375298
#   Difference = 0.0719518712
#   Difference = 0.8843593707
#   Difference = 0.7017622024
#   Difference = 0.7930395057
#   Difference = 0.5430054019
#   Difference = -0.4039091104
#   Difference = -0.3554284362
#   Difference = 0.1526344846
#   Difference = 0.7627356141
#   Difference = 0.7562224100
#   Difference = 0.2207109903
#   Difference = 0.2977071029
#   Difference = 0.3701729967
#   Difference = 0.7196346478
#   Difference = 0.6601223809
#   Difference = 0.2719392266
#   Difference = 0.4265987123
#   Difference = 0.3447602329
#   Difference = 0.2212842234
#   Difference = 0.3999439349
#   Difference = 0.0071238272
#   Difference = 0.7407233512
#   Difference = 0.5378795557
#   Difference = 0.1966622561
#   Difference = -0.2010297433
#   Difference = 0.5556412905
#   Difference = 0.0360445173
#   Difference = 0.6765204588
#   Difference = 0.5013022533
#   Difference = 0.5719952413
#   Difference = 0.8399450815
#   Difference = 0.9899562521
#   Difference = -0.1672718990
#   Difference = 0.3107744831
#   Difference = 0.8016679878
#   Difference = -0.0363245938
#   Difference = 0.3255086840
#   Difference = 0.3810371542
#   Difference = -0.2208240115
#   Difference = -0.3423071587
#   Difference = 0.2454007880
#   Difference = 0.1658081683
#   Difference = 0.0294447792
#   Difference = 0.3212760871
#   Difference = 0.5353576824
#   Difference = -0.0086615295
#   Difference = 0.9152738908
#   Difference = 0.2710407099
#   Difference = 0.1756145800
#   Difference = -0.1880951279
#   Difference = 0.0115172474
#   Difference = 0.5552649207
#   Difference = 0.1795667737
#   Difference = 0.1638633295
#   Difference = -0.0420211020
#   Difference = 1.0972660954
#   Difference = -0.0141367240
#   Difference = 0.3939790688
#   Difference = 0.0970011450
#   Difference = 0.1967849124
#   Difference = -0.0872397333
#   Difference = 0.3923931391
#   Difference = 0.3573130367
#   Difference = 0.2951165915
#   Difference = -0.0964758797
#   Difference = 0.2176013223
#   Difference = 0.7359054938
#   Difference = 0.2524611583
#   Difference = 0.9015946421
#   Difference = 0.2775859350
#   Difference = 0.3352035309
#   Difference = 0.5452800818
#   Difference = 0.9008393906
#   Difference = 0.5716103334
#   Difference = 0.4018885402
#   Difference = 0.1330765051
#   Difference = 0.1507456249
#   Difference = 0.0425110015
#   Difference = 0.5837677744
#   Difference = 0.9851094880
#   Difference = 0.6538104978
#   Difference = 0.4828815660
#   Difference = 1.1037319843
#   Difference = 0.3864400486
#   Difference = 0.0363133385
#   Difference = 0.9008583339
#   Difference = 0.5051744086
#   Difference = 0.3790169727
#   Difference = 0.4035493883
#   Difference = 0.2381598438
#   Difference = 0.3422485581
#   Difference = 0.1928252848
#   Difference = 0.1922259324
#   Difference = 0.3157413572
#   Difference = 0.7447073730
#   Difference = 0.2452778069
#   Difference = 0.1430611250
#   Difference = 0.8535238027
#   Difference = -0.0173077592
#   Difference = 0.1118311846
#   Difference = 0.1764597200
#   Difference = 0.5390688735
#   Difference = 0.5010880570
#   Difference = 0.4764535956
#   Difference = 0.5141597309
#   Difference = 0.4406753457
#   Difference = 1.0703250890
#   Difference = -0.0878759459
#   Difference = 0.4022685973
#   Difference = 0.2799848864
#   Difference = 0.4939371958
#   Difference = 0.8555942035
#   Difference = 0.4065070751
#   Difference = 0.4216387904
#   Difference = 0.2640700816
#   Difference = 0.2617741714
#   Difference = 0.8356805439
#   Difference = 0.2821482074
#   Difference = 0.8408479063
#   Difference = 0.3563016440
#   Difference = -0.2493241952
#   Difference = 0.5855453653
#   Difference = 0.7608636090
#   Difference = -0.0732179314
#   Difference = 1.1850244349
#   Difference = 0.6615660021
#   Difference = 0.6528554894
#   Difference = 0.1027422182
#   Difference = 0.5900369821
#   Difference = 0.4415715477
#   Difference = 0.5367108002
#   Difference = 0.7615064818
#   Difference = 0.3544890979
#   Difference = -0.0159341643
#   Difference = 0.5141079075
#   Difference = 0.6814540102
#   Difference = 0.2730486442
#   Difference = 0.1030435233
#   Difference = 0.1361942220
#   Difference = 0.4713186053
#   Difference = 0.3109404232
#   Difference = -0.0041236929
#   Difference = 0.3590566903
#   Difference = 0.5194635891
#   Difference = 0.4157040666
#   Difference = 0.1831732226
#   Difference = 0.4814412709
#   Difference = 0.0388979503
#   Difference = -0.1540277927
#   Difference = 0.7126149211
#   Difference = 0.4313402468
#   Difference = 0.0793803157
#   Difference = 0.0738523300
#   Difference = 0.6385131520
#   Difference = 0.5217671174
#   Difference = 0.2639957380
#   Difference = 0.0926846931
#   Difference = 1.5809403723
#   Difference = -0.2774372564
#   Difference = 0.8201746870
#   Difference = 0.0860827876
#   Difference = 0.2372756108
#   Difference = -0.0647383906
#   Difference = 0.2170142526
#   Difference = 0.4272988508
#   Difference = 0.6294125758
#   Difference = 0.6738082238
#   Difference = 0.3663519144
#   Difference = 0.0176642634
#   Difference = 0.2009294477
#   Difference = -0.0280656667
#   Difference = 0.5332919228
#   Difference = -0.7011329813
#   Difference = -0.1936342637
#   Difference = 0.2771100530
#   Difference = -0.1791992641
# ...
#   Difference = -5.6896325496
#   Difference = -5.7181438613
#   Difference = -4.9308622774
#   Difference = -5.6716485920
#   Difference = -5.5528732445
#   Difference = -5.7901329968
#   Difference = -6.1020471620
#   Difference = -5.3208265443
#   Difference = -5.6955970993
#   Difference = -5.5965354310
#   Difference = -5.6196119498
#   Difference = -5.2771940193
#   Difference = -5.9365785356
#   Difference = -5.7169765946
#   Difference = -5.9102658537
#   Difference = -5.7884073605
#   Difference = -5.7395763486
#   Difference = -5.6723005953
#   Difference = -5.3714762628
#   Difference = -5.5681963881
#   Difference = -5.5878250506
#   Difference = -5.9301977319
#   Difference = -5.3562694328
#   Difference = -5.7701493225
#   Difference = -5.4792077781
#   Difference = -5.6576866819
#   Difference = -5.2192546626
#   Difference = -5.7770067889
#   Difference = -5.6210571605
#   Difference = -5.4951262771
#   Difference = -5.7887544892
#   Difference = -5.3534190138
#   Difference = -6.0012088586
#   Difference = -5.5375794047
#   Difference = -5.7752660367
#   Difference = -5.2043385728
#   Difference = -5.5503907454
#   Difference = -5.7543307136
#   Difference = -6.1542794339
#   Difference = -5.4372730221
#   Difference = -5.8488640202
#   Difference = -5.6529298720
#   Difference = -5.6540759447
#   Difference = -5.5980730241
#   Difference = -6.0795263086
#   Difference = -5.9068866895
#   Difference = -5.6870138625
#   Difference = -5.6731032818
#   Difference = -5.5972070480
#   Difference = -5.4520770468
#   Difference = -5.9735152797
#   Difference = -5.5646299745
#   Difference = -5.9365943461
#   Difference = -5.5501837475
#   Difference = -5.6677140313
#   Difference = -5.7907381389
#   Difference = -5.5975301316
#   Difference = -5.5250831020
#   Difference = -5.7094731916
#   Difference = -5.6814042989
#   Difference = -5.3545913455
#   Difference = -5.8375590868
#   Difference = -5.8169208035
#   Difference = -5.3745374966
#   Difference = -5.8390567194
#   Difference = -5.8799374255
#   Difference = -5.7331832181
#   Difference = -5.5279796458
#   Difference = -5.2556744644
#   Difference = -5.8577778442
#   Difference = -5.2149191326
#   Difference = -5.7818153864
#   Difference = -5.7512768840
#   Difference = -5.4734436054
#   Difference = -5.3427585688
#   Difference = -6.3353255003
#   Difference = -5.6136920481
#   Difference = -5.6604397238
#   Difference = -5.6913290182
#   Difference = -5.4312736209
#   Difference = -5.5088892631
#   Difference = -5.9426327684
#   Difference = -5.6445958793
#   Difference = -5.7798139288
#   Difference = -5.8685110061
#   Difference = -5.7947520533
#   Difference = -5.2786299920
#   Difference = -5.3170790223
#   Difference = -5.4007374393
#   Difference = -5.6603972135
#   Difference = -6.0095166995
#   Difference = -5.6061081752
#   Difference = -5.3431136953
#   Difference = -5.5990004885
#   Difference = -5.4375335135
#   Difference = -6.0203650681
#   Difference = -5.7571541448
#   Difference = -5.7904408328
#   Difference = -5.8347541364
#   Difference = -5.6481848812
#   Difference = -6.1361356860
#   Difference = -5.6513736261
#   Difference = -5.8558970341
#   Difference = -5.7019814025
#   Difference = -5.6926021878
#   Difference = -5.8524125532
#   Difference = -5.9996675132
#   Difference = -5.7157863304
#   Difference = -5.3685370772
#   Difference = -5.5727110981
#   Difference = -5.7144018937
#   Difference = -5.2920800441
#   Difference = -5.6702671977
#   Difference = -5.6015201715
#   Difference = -5.2765241628
#   Difference = -5.0134190610
#   Difference = -5.0539971502
#   Difference = -5.7338228162
#   Difference = -5.9766404328
#   Difference = -6.0773627214
#   Difference = -5.7438162955
#   Difference = -5.4317506861
#   Difference = -5.6590846834
#   Difference = -5.5564219579
#   Difference = -5.6947836162
#   Difference = -5.7189581462
#   Difference = -5.4951403907
#   Difference = -5.7170327076
#   Difference = -5.6122558598
#   Difference = -5.3754140217
#   Difference = -5.6018471940
#   Difference = -5.5631213016
#   Difference = -5.5690263631
#   Difference = -5.7806226089
#   Difference = -5.5154678717
#   Difference = -5.5305527816
#   Difference = -5.9329585358
#   Difference = -5.4001981705
#   Difference = -5.7120897248
#   Difference = -5.7720362180
#   Difference = -6.2073690891
#   Difference = -5.3979959127
#   Difference = -5.6190747306
#   Difference = -5.8755326964
#   Difference = -6.2020632288
#   Difference = -5.7510611660
#   Difference = -5.3955378358
#   Difference = -5.7592926142
#   Difference = -6.0418382374
#   Difference = -5.2383911159
#   Difference = -5.7560217281
#   Difference = -5.4424755675
#   Difference = -5.6959751983
#   Difference = -5.6364035538
#   Difference = -5.4097216250
#   Difference = -6.0300082689
#   Difference = -5.6623768719
#   Difference = -5.9187044124
#   Difference = -5.2905082486
#   Difference = -5.8713669095
#   Difference = -5.7658411794
#   Difference = -5.7197033776
#   Difference = -5.8801717359
#   Difference = -5.6529626633
#   Difference = -5.4606009642
#   Difference = -6.0755189130
#   Difference = -5.2140456794
#   Difference = -5.5273694367
#   Difference = -5.4309871656
#   Difference = -5.5575009755
#   Difference = -5.8199292788
#   Difference = -5.6626945300
#   Difference = -5.7791594653
#   Difference = -5.8014213852
#   Difference = -5.6565609408
#   Difference = -5.6553179999
#   Difference = -5.0794839419
#   Difference = -5.7338269472
#   Difference = -5.6117974160
#   Difference = -5.7032041523
#   Difference = -5.8691953740
#   Difference = -5.5885174953
#   Difference = -5.7981819659
#   Difference = -5.6094128715
#   Difference = -5.4713333267
#   Difference = -5.8775490547
#   Difference = -5.4199563340
#   Difference = -5.4810013508
#   Difference = -5.4952457641
#   Difference = -5.6023014025
#   Difference = -5.7206944664
#   Difference = -5.6543300203
#   Difference = -5.1908472477
#   Difference = -5.9179236173
#   Difference = -5.4048986950
#   Difference = -5.6804205549
#   Difference = -5.6549083634
#   Difference = -5.3150541649
#   Difference = -5.4957651012
#   Difference = -5.8355872734
#   Difference = -5.6334939142
#   Difference = -5.8598313586
#   Difference = -5.9912650127
#   Difference = -5.8725170988
#   Difference = -5.3612543091
#   Difference = -5.1545354871
#   Difference = -5.7139117646
#   Difference = -5.7877249832
#   Difference = -5.3364355230
#   Difference = -5.6438736342
#   Difference = -6.1788119176
#   Difference = -6.1513597776
#   Difference = -5.6197035637
#   Difference = -5.4182377861
#   Difference = -5.7905811634
#   Difference = -5.2172305278
#   Difference = -5.9441658706
#   Difference = -5.8096704545
#   Difference = -5.5896773881
#   Difference = -5.4598995845
#   Difference = -5.9613479255
#   Difference = -5.5731396985
#   Difference = -5.5916023698
#   Difference = -5.6219346693
#   Difference = -5.7781177924
#   Difference = -5.3165135812
#   Difference = -6.0497638953
#   Difference = -5.9781263764
#   Difference = -5.7138260826
#   Difference = -5.7922128315
#   Difference = -5.9589213756
#   Difference = -5.6538285012
#   Difference = -5.8155388214
#   Difference = -5.5193557313
#   Difference = -5.5774476034
#   Difference = -5.5819279208
#   Difference = -5.9928189183
#   Difference = -5.6786932492
#   Difference = -5.5346439789
#   Difference = -5.3693396671
#   Difference = -5.4273853779
#   Difference = -5.7145237411
#   Difference = -5.8021852895
#   Difference = -5.7110490386
#   Difference = -5.5984410925
#   Difference = -5.1796565582
#   Difference = -5.5438337626
#   Difference = -5.8128894210
#   Difference = -5.9105148377
#   Difference = -5.6113539391
#   Difference = -5.8710790367
#   Difference = -7.7942790812
#   Difference = -7.5466748854
#   Difference = -7.5719618882
#   Difference = -7.4529291011
#   Difference = -7.4969897354
#   Difference = -7.9542923616
#   Difference = -7.8090535007
#   Difference = -7.7671652854
#   Difference = -7.8937433077
#   Difference = -7.5775411613
#   Difference = -7.7698287814
#   Difference = -7.7681379675
#   Difference = -7.7936639934
#   Difference = -7.4724866524
#   Difference = -7.6999537631
#   Difference = -7.6253944807
#   Difference = -7.5721053721
#   Difference = -7.5888302766
#   Difference = -7.5562399551
#   Difference = -7.4112074049
#   Difference = -7.6492303063
#   Difference = -7.5560238109
#   Difference = -7.9385702724
#   Difference = -7.6518995447
#   Difference = -7.3507515634
#   Difference = -7.6179023560
#   Difference = -7.6593093555
#   Difference = -7.5367229040
#   Difference = -7.6778017334
#   Difference = -7.3189595825
#   Difference = -7.5682266584
#   Difference = -7.6688467785
#   Difference = -7.7813137543
#   Difference = -7.5269073955
#   Difference = -7.5532647407
#   Difference = -7.5591743270
#   Difference = -7.4881908636
#   Difference = -7.9074803682
#   Difference = -7.5330207803
#   Difference = -7.7958171521
#   Difference = -7.3481717327
#   Difference = -7.5190484263
#   Difference = -7.7151855468
#   Difference = -7.5322645979
#   Difference = -7.7008857930
#   Difference = -7.7344988547
#   Difference = -7.5153796060
#   Difference = -7.7798457887
#   Difference = -7.5668773134
#   Difference = -7.7663157741
#   Difference = -7.3306434740
#   Difference = -7.6956950787
#   Difference = -7.7363915436
#   Difference = -7.6294179923
#   Difference = -7.8108799955
#   Difference = -7.5186229387
#   Difference = -7.6129383206
#   Difference = -7.4595668450
#   Difference = -7.7336756289
#   Difference = -7.7406252307
#   Difference = -7.7407984849
#   Difference = -7.6495883229
#   Difference = -7.4980479073
#   Difference = -7.8680120269
#   Difference = -7.2678313062
#   Difference = -7.7913949293
#   Difference = -7.5994128357
#   Difference = -7.7054009701
#   Difference = -7.5886135450
#   Difference = -7.8196817297
#   Difference = -7.7208858066
#   Difference = -7.3711994719
#   Difference = -7.7734548680
#   Difference = -7.4601525012
#   Difference = -7.6205899160
#   Difference = -7.5081478628
#   Difference = -7.6520856207
#   Difference = -7.6603428425
#   Difference = -7.5323747849
#   Difference = -7.7532464137
#   Difference = -7.6914904645
#   Difference = -7.5890500683
#   Difference = -7.5124209280
#   Difference = -7.7526190538
#   Difference = -7.6174547382
#   Difference = -7.7166867094
#   Difference = -7.7304465715
#   Difference = -7.7298991120
#   Difference = -7.4491061819
#   Difference = -7.6174764776
#   Difference = -7.6747699801
#   Difference = -7.4959122927
#   Difference = -7.6594931322
#   Difference = -7.5982184713
#   Difference = -8.0588724509
#   Difference = -7.6461210683
#   Difference = -7.6104822323
#   Difference = -7.7001567576
#   Difference = -7.6758594327
#   Difference = -7.5397378180
#   Difference = -7.6693150524
#   Difference = -7.2305747698
#   Difference = -7.7247131746
#   Difference = -7.7524265785
#   Difference = -7.7665667764
#   Difference = -7.4195057241
#   Difference = -7.8077552198
#   Difference = -7.8263540344
#   Difference = -7.8917331016
#   Difference = -7.7141844272
#   Difference = -7.6312295033
#   Difference = -7.6317590633
#   Difference = -7.7298322176
#   Difference = -7.7801318814
#   Difference = -7.7166897395
#   Difference = -7.8284586651
#   Difference = -7.6859877368
#   Difference = -7.6961350345
#   Difference = -7.3330235883
#   Difference = -7.4362760851
#   Difference = -7.6350988263
#   Difference = -7.7503146116
#   Difference = -7.7159187289
#   Difference = -7.7786459883
#   Difference = -7.5408421012
#   Difference = -7.6194214951
#   Difference = -7.7378428806
#   Difference = -7.8287387624
#   Difference = -7.3990200205
#   Difference = -7.5703708371
#   Difference = -7.8504906739
#   Difference = -7.3760151717
#   Difference = -7.5613678724
#   Difference = -7.6479673931
#   Difference = -7.6208809220
#   Difference = -7.7512075026
#   Difference = -7.5554437608
#   Difference = -7.5364320880
#   Difference = -7.6307089006
#   Difference = -7.3795343287
#   Difference = -7.3970152412
#   Difference = -7.4906029629
#   Difference = -7.9501077207
#   Difference = -7.6353661598
#   Difference = -7.8455567938
#   Difference = -7.6576136368
#   Difference = -7.6077862537
#   Difference = -7.5956922908
#   Difference = -7.8274440922
#   Difference = -7.8553835189
#   Difference = -7.4659442694
#   Difference = -7.4998248768
#   Difference = -7.6250598255
#   Difference = -7.5086680512
#   Difference = -7.4929521622
#   Difference = -7.5885647900
#   Difference = -7.7710475203
#   Difference = -7.4175249818
#   Difference = -7.5012317347
#   Difference = -7.3157818533
#   Difference = -7.6888717844
#   Difference = -7.6683676050
#   Difference = -7.6963996582
#   Difference = -7.9478145482
#   Difference = -7.6335324253
#   Difference = -7.5198301395
#   Difference = -7.7437565596
#   Difference = -7.6866930506
#   Difference = -7.6496279705
#   Difference = -7.4653764762
#   Difference = -7.4949271861
#   Difference = -7.6084092105
#   Difference = -7.5025408189
#   Difference = -7.6788744028
#   Difference = -7.6268163240
#   Difference = -7.5010656980
#   Difference = -7.6192315545
#   Difference = -7.6258531944
#   Difference = -7.6247494937
#   Difference = -7.4977327722
#   Difference = -7.4368846124
#   Difference = -7.7852430266
#   Difference = -7.7710252871
#   Difference = -7.7497179834
#   Difference = -7.7580670598
#   Difference = -7.5758243502
#   Difference = -7.7134863526
#   Difference = -7.6569700787
#   Difference = -7.7342855590
#   Difference = -7.4461414156
#   Difference = -7.6292565329
#   Difference = -7.3899521444
#   Difference = -7.6147513496
#   Difference = -7.5896211102
#   Difference = -7.3081598419
#   Difference = -7.6423824600
#   Difference = -7.6587745583
#   Difference = -7.4918756470
#   Difference = -7.5906618284
#   Difference = -7.6494817053
#   Difference = -7.6334320335
#   Difference = -7.6554771043
#   Difference = -7.7286999197
#   Difference = -7.7959669091
#   Difference = -7.7810283234
#   Difference = -7.9354470724
#   Difference = -7.8106628635
#   Difference = -7.8491501413
#   Difference = -7.8679014278
#   Difference = -7.7725411063
#   Difference = -7.6312764176
#   Difference = -7.7776857561
#   Difference = -7.7252126913
#   Difference = -7.7801114174
#   Difference = -7.6307827487
#   Difference = -7.4694804252
#   Difference = -7.5169499513
#   Difference = -7.6689688261
#   Difference = -7.7213715358
#   Difference = -7.6495422939
#   Difference = -7.6379178922
#   Difference = -7.4971337694
#   Difference = -7.3141614897
#   Difference = -7.7671655316
#   Difference = -7.6491466582
#   Difference = -7.4519257403
#   Difference = -7.7939434379
#   Difference = -7.7800813107
#   Difference = -7.6062734352
#   Difference = -7.7916945358
#   Difference = -7.6074312481
#   Difference = -7.8109248432
#   Difference = -7.6976672864
#   Difference = -7.8051278747
#   Difference = -7.3994144755
#   Difference = -7.6524814384
#   Difference = -7.7519600626
#   Difference = -7.7099826004
#   Difference = -7.5349639859
#   Difference = -7.6505333586
#   Difference = -7.7304470814
#   Difference = -7.4284186290
#   Difference = -7.5755067573
#   Difference = -7.5728167235
#   Difference = -7.4495252148
#   Difference = -7.6548121347
#   Difference = -7.4541564384
#   Difference = -7.6104767952
#   Difference = -7.6797727755
#   Difference = -7.6379566019
#   Difference = -7.8733763454
#   Difference = -7.8421068819
#   Difference = -7.7385916677
#   Difference = -7.6136563086
#   Difference = -7.6330629628
#   Difference = -7.6898901571
#   Difference = -7.5119183400
#   Difference = -7.7389801235
#   Difference = -7.6933657619
#   Difference = -7.5651236437
#   Difference = -7.4851998989
#   Difference = -7.6693558453
#   Difference = -7.6888377505
#   Difference = -7.6121526877
#   Difference = -7.8129560933
#   Difference = -7.7515872270
#   Difference = -7.5670431503
#   Difference = -7.6124859283
#   Difference = -7.6159562734
#   Difference = -7.5531324196
#   Difference = -7.8606141159
#   Difference = -7.6684762327
#   Difference = -7.4277336519
#   Difference = -7.8314914910
#   Difference = -7.5506563250
#   Difference = -7.6926505276
#   Difference = -7.7960311425
#   Difference = -7.7784947190
#   Difference = -7.7137921168
#   Difference = -7.6964263798
#   Difference = -7.5169789135
#   Difference = -7.5944882072
#   Difference = -7.4098966792
#   Difference = -7.5748484567
#   Difference = -7.7520729369
#   Difference = -7.7357599897
#   Difference = -7.2190171762
#   Difference = -7.5481932005
#   Difference = -7.7071905343
#   Difference = -7.4503660933
#   Difference = -7.6822468017
#   Difference = -7.6784188554
#   Difference = -7.6115679272
#   Difference = -7.6764852597
#   Difference = -7.4295946849
#   Difference = -7.6327437301
#   Difference = -7.5544229943
#   Difference = -7.7108688684
#   Difference = -7.3934438650
#   Difference = -7.7422802671
# Simulation complete.

# %% [markdown]
# - **Bonus Question 2.** Why is the Jeffrey's prior estimator so bad? Can you provide a better bound for the variance of the estimator? [Hint: you might need `np.gradient` to solve this question, and increase the number of different values of $a$ to get a finer plot]

# %% [markdown]
# ### Joint estimation case
# You finally managed to get the file `full.npy` with the samples of the distribution $p(x;a,b)$ your friend Alex stored in the computer. You don't know the value of $b$, and you need to estimate both $a^\star$ and $b^\star$. (BE CAREFUL: $a^\star$ is different from the previous case).

# %% [markdown]
# - **Question 17.** How many sample points are there in the file? Let us call this number $n$ and plot an histogram of the data.

# %%
import numpy as np
import matplotlib.pyplot as plt
import requests
import io

b = 20

url = 'https://raw.githubusercontent.com/Jerry0209/FundamentalLearningEPFL/main/HW1/full.npy'

try:
    response = requests.get(url)
    response.raise_for_status()
    data_full = np.load(io.BytesIO(response.content))
    n_full = len(data_full)

    print(f"full.py successfully loaded！")
    # print(f"Data Shape: {data.shape}")

    print(f"There are n = {n_full} sample points in the file.")

    # Plot the histogram
    plt.figure(figsize=(10, 6))
    plt.hist(data_full, bins='auto', density=True, alpha=0.7, label='Data Histogram')
    plt.title('Histogram of full.npy (Both a and b unknown)')
    plt.xlabel('x value')
    plt.ylabel('Density')
    plt.grid(True, linestyle='--')
    plt.legend()
    plt.show()

except Exception as e:
    print(f"Error：{e}")
    data = np.array([])
# Out:
# Successfully loaded！
# Data Shape: (10000,)
# There are n = 10000 sample points in the file.

# %% [markdown]
# - **Question 18.** Compute the maximum likelihood estimators $\hat a_\text{ML}$ and $\hat b_\text{ML}$ for the data in the file `full.npy`.

# %%
from scipy.optimize import minimize
import numpy as np

# Re-define pdf because there are two varibles a and b
def pdf(x, a, b):
    x = np.asarray(x)
    p = np.zeros_like(x, dtype=float)


    if not (0 < a < b and b > 0): # a must be strictly between 0 and b
        return p # Return 0 for invalid parameters

    H = 2.0 / b

    # Left
    mask_left = (x >= 0) & (x <= a)
    if a > 0: # Avoid division by zero if a were 0
        p[mask_left] = H * (x[mask_left] / a)

    # Right
    mask_right = (x > a) & (x <= b)
    if b - a > 0: # Avoid division by zero if a were b
        p[mask_right] = H * ((b - x[mask_right]) / (b - a))

    return p


# Joint Log
def log_likelihood_joint(params, data):
    a, b = params

    # a must be between 0 and b
    if not (0 < a < b):
        return -np.inf

    if b <= np.max(data):
        return -np.inf

    logl = 0.0
    for x_i in data:
        p_i = pdf(x_i, a, b)


        if p_i <= 0: # catch potential float errors
            return -np.inf

        logl += np.log(p_i)
    return logl

# neg log likelihood
def negative_log_likelihood_joint(params, data):
    return -log_likelihood_joint(params, data)


# Initialize simulation (use minimizer)
initial_guess_b = np.max(data_full) * 1.05
initial_guess_a = initial_guess_b / 3 # randomly choose at 1/3
initial_params = [initial_guess_a, initial_guess_b]

# Boundary
epsilon = 1e-6
bounds = [
    (epsilon, initial_guess_b - epsilon),
    (np.max(data_full) + epsilon, None)
]

print(f"Starting optimization for a and b...")
print(f"Initial guess for [a, b]: {initial_params}")

result = minimize(
    negative_log_likelihood_joint,
    x0=initial_params,
    args=(data_full,),
    bounds=bounds,
    method='L-BFGS-B'
)

if result.success:
    a_hat_ml_optimized, b_hat_ml_optimized = result.x
    print("\nOptimization successful!")
    print(f"Maximum Likelihood Estimators:")
    print(f"  a_hat_ml = {a_hat_ml_optimized:.4f}")
    print(f"  b_hat_ml = {b_hat_ml_optimized:.4f}")
else:
    print("\nOptimization failed!")
    print(result.message)

# Plot
plt.figure(figsize=(10, 6))
plt.hist(data_full, bins='auto', density=True, alpha=0.7, label='Data Histogram')
x_plot = np.linspace(0, b_hat_ml_optimized * 1.05, 400) # Extend plot slightly beyond b
plt.plot(x_plot, pdf(x_plot, a_hat_ml_optimized, b_hat_ml_optimized), 'r-', lw=2,
         label=f'Fitted MLE PDF (a={a_hat_ml_optimized:.2f}, b={b_hat_ml_optimized:.2f})')
plt.axvline(a_hat_ml_optimized, color='r', linestyle='--', label=f'a_hat_ml = {a_hat_ml_optimized:.2f}')
plt.axvline(b_hat_ml_optimized, color='k', linestyle='--', label=f'b_hat_ml = {b_hat_ml_optimized:.2f}')
plt.title('Data Histogram with Joint Fitted MLE PDF')
plt.xlabel('x')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# Starting optimization for a and b...
# Initial guess for [a, b]: [np.float64(29.953151333669595), np.float64(89.85945400100879)]
#
# Optimization successful!
# Maximum Likelihood Estimators:
#   a_hat_ml = 62.9929
#   b_hat_ml = 85.8962

# %% [markdown]
# - **Question 19.** Can you provide the confidence intervals for the estimators? Can you guess the secret code of your friend?

# %%
import time

n_bootstraps = 300
boot_a_ml = []
boot_b_ml = []

# Use the result from Q18 as a smart initial guess for all iterations
initial_guess_from_q18 = [a_hat_ml_optimized, b_hat_ml_optimized]

print(f"Starting Bootstrap")
print(f"Running {n_bootstraps} iterations. ")
start_time = time.time()

for i in range(n_bootstraps):
    # Resampled dataset
    resample = np.random.choice(data_full, size=n_full, replace=True)


    max_resample = np.max(resample)
    epsilon = 1e-9

    bounds_boot = [
        (epsilon, None),                # Bound for a
        (max_resample + epsilon, None)  # Bound for b
    ]

    # Re-run the optimization
    res_boot = minimize(
        negative_log_likelihood_joint,
        x0=initial_guess_from_q18,
        args=(resample,),
        bounds=bounds_boot,
        method='L-BFGS-B'
    )

    # Store the result
    if res_boot.success:
        boot_a_ml.append(res_boot.x[0])
        boot_b_ml.append(res_boot.x[1])

    # Print progress
    if (i + 1) % 50 == 0:
        print(f"  ... completed {i+1} / {n_bootstraps} iterations")

end_time = time.time()
print(f"Bootstrap complete in {end_time - start_time:.2f} seconds.")

# Compute the 95% Confidence Intervals
ci_a = np.percentile(boot_a_ml, [2.5, 97.5])
ci_b = np.percentile(boot_b_ml, [2.5, 97.5])

print(f"\n--- 95% Confidence Intervals (Bootstrap) ---")
print(f"a_hat_ml: {a_hat_ml_optimized:.4f},  95% CI: [{ci_a[0]:.4f}, {ci_a[1]:.4f}]")
print(f"b_hat_ml: {b_hat_ml_optimized:.4f},  95% CI: [{ci_b[0]:.4f}, {ci_b[1]:.4f}]")


# Guessing
print("\n--- Guessing the Secret Code ---")

# Round to Integer
a_guess = round(a_hat_ml_optimized)
b_guess = round(b_hat_ml_optimized)

print(f"The MLE estimates rounded to the nearest integer are: a = {a_guess}, b = {b_guess}")
a_in_ci = (ci_a[0] <= a_guess <= ci_a[1])
b_in_ci = (ci_b[0] <= b_guess <= ci_b[1])

print(f"Is the integer {a_guess} within the 95% CI for 'a'?  {a_in_ci}")
print(f"Is the integer {b_guess} within the 95% CI for 'b'?  {b_in_ci}")

if a_in_ci and b_in_ci:
    print("\nConclusion: The integer estimates fall within the CIs.")
    print(f"There is a highly confident that the secret code is a={a_guess}, b={b_guess}.")
    print(f"The phone code guessed is: {a_guess}{b_guess}")
else:
    print("\nWarning: The integer estimates are outside the CIs.")
    print("The guess is less certain.")
# Out:
# --- Starting Bootstrap for Q19 ---
# Running 300 iterations. This will be SLOW (est. 2-5 mins)...
#   ... completed 50 / 300 iterations
#   ... completed 100 / 300 iterations
#   ... completed 150 / 300 iterations
#   ... completed 200 / 300 iterations
#   ... completed 250 / 300 iterations
#   ... completed 300 / 300 iterations
# Bootstrap complete in 2499.05 seconds.
#
# --- 95% Confidence Intervals (Bootstrap) ---
# a_hat_ml (from Q18): 62.9929,  95% CI: [62.4007, 63.8068]
# b_hat_ml (from Q18): 85.8962,  95% CI: [85.6308, 86.1042]
#
# --- Guessing the Secret Code ---
# The MLE estimates rounded to the nearest integer are: a = 63, b = 86
# Is the integer 63 within the 95% CI for 'a'?  True
# Is the integer 86 within the 95% CI for 'b'?  True
#
# Conclusion: The integer estimates fall comfortably within the CIs.
# We are highly confident that Alex's secret code is a=63, b=86.
# The phone code is: 6386

# %% [markdown]
# - **Bonus Question 3.** Can you find some estimators for $a$ and $b$ that are based on mean and median? Do you expect them to work well? Why?
