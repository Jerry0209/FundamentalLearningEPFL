# %% [markdown]
# # Homework 1: crack Alex's phone code
#
# ### Rules:
#  - You should write the solution in this notebook and upload the completed notebook on Moodle by the deadline.
#  - You are not allowed to work in groups, every student should submit their own notebook. If you submit two highly overlapping notebooks with another student, you will both be penalized.
#  - The bonus questions are optional. They are not needed to get the full grade, but they can help you to get a higher grade.
#
# ### The setting
#
# Your friend Alex wants to hide a secret code in a probability distribution. The probability density function is a piecewise linear distribution with parameters $0<a\le b$, defined as
# $$p(x;a,b) = H(a,b) \begin{cases} \frac{x}{a} & \text{if } 0 \leq x \leq a, \\ \frac{b-x}{b-a} & \text{if } a \leq x \leq b, \\ 0 & \text{otherwise.} \end{cases}$$
# where $H(a,b)$ is a normalization constant. Alex has choosen $a$ and $b$ such that they are the first two and the last two digits of his phone secret code, respectively.
# For example, if their secret code is 1234, then $a=12$ and $b=34$. Alex stores some sample values of the distribution in a file called on their computer, thinking that nobody will be able to understand the distribution without the secret code.
#
# You recently enrolled at EPFL and you are taking the course of _Fundamental of Inference and Learning_, and you want to prove that Alex's phone code is not safe. In this problem, your goal is to discover the secret code by studying the distribution.

# %% [markdown]
# ## Part 1: Properties of the distribution

# %% [markdown]
# The distribution $p(x;a,b)$ is a valid distribution, i.e., it is normalized and it is non-negative. In this part, you will find many properties of the distribution.

# %% [markdown]
#  - **Question 1.** Find the normalization constant $H(a,b)$.
#  - **Q1 Answer**
#     - Since $p(x; a, b)$ is a valid probability density function, its integral over its entire domain must be 1.
#     $$\int_{-\infty}^{\infty} p(x; a, b) dx = 1$$
#
#     - Since PDF only has values in $[0, b]$, the integral can be written as:
#
#     $$\int_{0}^{b} p(x; a, b)dx=\int_{0}^{a} H(a, b) \frac{x}{a} dx + \int_{a}^{b} H(a, b) \frac{b-x}{b-a} dx =H(a, b) \left[ \int_{0}^{a} \frac{x}{a}  dx + \int_{a}^{b} \frac{b-x}{b-a} dx \right]= 1$$
#
#     - These two integrals can be calculated separately:
#       - First integral:
#     $$\int_{0}^{a} \frac{x}{a} dx = \frac{1}{a} \left[ \frac{x^2}{2} \right]_{0}^{a} = \frac{1}{a} \left( \frac{a^2}{2} - 0 \right) = \frac{a}{2}$$
#       - Second integral:
#
#     $$\int_{a}^{b} \frac{b-x}{b-a} dx = \frac{1}{b-a} \left[ bx - \frac{x^2}{2} \right]_{a}^{b}= \frac{1}{b-a} \left[ \left( b^2 - \frac{b^2}{2} \right) - \left( ab - \frac{a^2}{2} \right) \right]= \frac{1}{b-a} \left[ \frac{(b-a)^2}{2} \right] = \frac{b-a}{2}$$
#
#
#       - Substitute these two results back into the original equation:
#
#     $$H(a, b) \left[ \frac{a}{2} + \frac{b-a}{2} \right] = H(a, b) \left[ \frac{b}{2} \right] = 1$$
#       - Solve for $H(a, b)$:
#     $$H(a, b) = \frac{2}{b}$$

# %% [markdown]
# - **Question 2.** Compute the expected value $\mu$ of the distribution.
# - **Q2 Answer**
#
#   - The formula for the expected value $\mu$ ($\mathit{E}[X]$) is:
#   $$\mu = \mathit{E}[X] = \int_{-\infty}^{\infty} x \cdot p(x; a, b) \, dx = \int_{0}^{a} x \left( \frac{2x}{ab} \right) \, dx + \int_{a}^{b} x \left( \frac{2(b-x)}{b(b-a)} \right) \, dx$$
#
#   - Integral of two parts:
#
#
#     - First integral
#   $$\int_{0}^{a} \frac{2x^2}{ab} \, dx = \frac{2}{ab} \int_{0}^{a} x^2 \, dx= \frac{2}{ab} \left[ \frac{x^3}{3} \right]_{0}^{a} = \frac{2}{ab} \left( \frac{a^3}{3} - 0 \right) = \frac{2a^3}{3ab}= \frac{2a^2}{3b}$$
#
#
#     - Second integral
#   $$\int_{a}^{b} \frac{2x(b-x)}{b(b-a)} \, dx = \frac{2}{b(b-a)} \int_{a}^{b} (bx - x^2) \, dx= \frac{2}{b(b-a)} \left[ \frac{bx^2}{2} - \frac{x^3}{3} \right]_{a}^{b}$$
#
#   $$= \frac{2}{b(b-a)} \left[ \left( \frac{b(b^2)}{2} - \frac{b^3}{3} \right) - \left( \frac{b(a^2)}{2} - \frac{a^3}{3} \right) \right]= \frac{b^2 + ab - 2a^2}{3b}$$
#
#
#     - Combine the two results:
#   $$\mu = \frac{2a^2}{3b} + \frac{b^2 + ab - 2a^2}{3b}= \frac{2a^2 + b^2 + ab - 2a^2}{3b}= \frac{a+b}{3}$$
#
#     - Thus the expected value $\mu$ is $\frac{a+b}{3}$.

# %% [markdown]
# - **Question 3.** Compute the _cumulative density function_ $F(t)$ of the distribution.
#
# - **Q3 Answer**
#
#   - The Cumulative Distribution Function (CDF) $F(t)$ is defined as $F(t)  = \int_{-\infty}^{t} p(x;a,b) \, dx$.
#
#   - Since the PDF is piecewise function, CDF should be calculated based on each piecewise function, which depends on different values of $t$:
#
#   - **Case 1: $t < 0$**
#   $$F(t) = \int_{-\infty}^{t} 0 \, dx = 0$$
#
#   - **Case 2: $0 \le t \le a$**
#   $$F(t) = \int_{-\infty}^{0} 0 \, dx + \int_{0}^{t} \frac{2x}{ab} \, dx= \frac{t^2}{ab}$$
#
#
#   - **Case 3: $a \le t \le b$**
#
#   $$F(t) = \int_{0}^{a} p(x) \, dx + \int_{a}^{t} p(x) \, dx = F(a) + \int_{a}^{t} \frac{2(b-x)}{b(b-a)} \, dx = \frac{a}{b} + \frac{2}{b(b-a)} \int_{a}^{t} (b-x) \, dx = \frac{2 b t - a b - t ^ { 2 }}{b(b-a)}$$
#
#   - CDF is the total probability for $x$ on $[0, a]$, and add the probability for $x$ from $a$ to $t$.
#
#   - When $t=a$, $F(a) = 1 - \frac{(b-a)^2}{b(b-a)} = 1 - \frac{b-a}{b} = \frac{a}{b}$. When $t=b$, $F(b) = 1 - 0 = 1$. Both match expectations.)
#
#   - Final CDF is
#   $$F(t) = \begin{cases} \frac{t^2}{ab} & \text{if } 0 \leq t \leq a, \\ \frac{2 b t - a b - t ^ { 2 }}{b(b-a)} & \text{if } a \leq t \leq b, \\ 0 & \text{otherwise} \end{cases}$$

# %% [markdown]
# * **Question 4.** Compute the median $m$ of the distribution. (Be careful, there are some special cases to consider according to the value $a$ and $b$)
#
# - **Q4 Answer**
#
#     - The median $m$ : $F(m) = \frac{1}{2}$. It's required to determine which segment of the CDF contains the $\frac{1}{2}$ probability value.
#
#     - Test the value of the CDF at the breakpoint(peak) $x=a$:
#
#       $$F(a) = \frac{a^2}{ab} = \frac{a}{b}$$
#
#
#     - **Case 1: $F(a) \ge \frac{1}{2}\implies\frac{a}{b} \ge \frac{1}{2} \implies 2a \ge b$**
#       - The median $m$ must be in the first interval, $[0, a]$.
#       - Use the CDF formula for this interval:
#       $$F(m) = \frac{m^2}{ab} = \frac{1}{2}$$
#       - Solving for $m$:
#       $$m^2 = \frac{ab}{2}$$
#       $$m = \sqrt{\frac{ab}{2}} \quad \text{(Take the positive root since } m \ge 0 \text{)}$$
#
#   - **Case 2: $F(a) < \frac{1}{2}\implies\frac{a}{b} < \frac{1}{2} \implies 2a < b$**
#     - The median $m$ must be in the second interval, $[a, b]$.
#     - For this interval, we use the CDF formula $F(t) = \frac{2bt - ab - t^2}{b(b-a)}$.
#     - Set $F(m) = \frac{1}{2}$:
#     $$\frac{2bm - ab - m^2}{b(b-a)} = \frac{1}{2}$$
#     - Rearrange it into a quadratic equation:
#     $$2(2bm - ab - m^2) = b(b-a)$$
#     $$2m^2 - 4bm + (ab + b^2) = 0$$
#
#     - Solve this for $m$ using the quadratic formula, $m = \frac{-B \pm \sqrt{B^2 - 4AC}}{2A}$, with: $A = 2$, $B = -4b$, $C = (ab + b^2)$
#
#     $$m = \frac{-(-4b) \pm \sqrt{(-4b)^2 - 4(2)(ab + b^2)}}{2(2)}$$
#     $$m = \frac{4b \pm \sqrt{16b^2 - 8(ab + b^2)}}{4}$$
#
#
#     $$m = b \pm \sqrt{\frac{2b(b-a)}{4}} = b \pm \sqrt{\frac{b(b-a)}{2}}$$
#     - This gives two potential solutions. However, $m$ must be in the interval $[a, b]$, so $m \le b$.
#     - The solution $m = b + \sqrt{\frac{b(b-a)}{2}}$ is "out of range" because it will be greater than $b$.
#     - Therefore, only take the negative sign:
#     $$m = b - \sqrt{\frac{b(b-a)}{2}}$$
#
#     - By combining both cases, the complete solution for the median is:
#   $$m = \begin{cases} \sqrt{\frac{ab}{2}} & \text{if } 2a \ge b \\ b - \sqrt{\frac{b(b-a)}{2}} & \text{if } 2a < b \end{cases}$$

# %% [markdown]
# - **Question 5.** Are the expected value and the median equal? How do the compare with the mode of the distribution? Comment the results.
#
# - **Q5 Answer**
#
#   - The mode is the value of $x$ where the PDF $p(x)$ reaches its maximum.
#     - On $[0, a]$, $p(x) = \frac{2x}{ab}$ is an increasing function.
#     - On $[a, b]$, $p(x) = \frac{2(b-x)}{b(b-a)}$ is a decreasing function.
#     - The PDF reaches its peak at $x=a$, with $p(a) = \frac{2a}{ab} = \frac{2}{b}$.
#     - Therefore, the Mode $= a$.
#
#   - The mean, median, and mode are equal only when the distribution is symmetric ($b=2a$). When the distribution is asymmetric or skewed, they are different. The mean is always pulled in the direction of the long tail, while the mode remains at the peak, and the median lies between the two.
#
#   - Details for each case are in the table below.
#
# | Case | Condition | Distribution Shape | Mode | Mean | Median | Relationship | Commentary |
# |------|-----------|-------------------|------|------|--------|--------------|------------|
# | **Case 1** | $a = \frac{b}{2}$ ($b = 2a$) | Symmetric (isosceles triangle) | $a$ | $\frac{a+b}{3} = a$ | $m = \sqrt{\frac{ab}{2}} = a$ | **Mean = Median = Mode** | All three measures coincide at the peak. This is characteristic of a unimodal symmetric distribution. |
# | **Case 2** | $a > \frac{b}{2}$ ($b < 2a$) | Left-skewed (longer tail on left) | $a$ | $\frac{a+b}{3} < a$ | $m = \sqrt{\frac{ab}{2}}$ | **Mean < Median < Mode** | The mean is pulled toward the longer left tail. The median lies between the mean and mode. |
# | **Case 3** | $a < \frac{b}{2}$ ($b > 2a$) | Right-skewed (longer tail on right) | $a$ | $\frac{a+b}{3} > a$ | $m = b - \sqrt{\frac{b(b-a)}{2}}$ | **Mode < Median < Mean** | The mean is pulled toward the longer right tail. The median lies between the mode and mean. |

# %% [markdown]
# ## Part 2: Discovering the secret code from samples
# You have seen Alex typing the code once, and you know that the last 2 digits are "20", hence $b=20$, and your goal is to estimate the first two digits $a^\star$. In this part, you can work as if you knew the value of $b$, and the distribution depends only on $a$. You also got the file `fixed_b.npy`with samples coming from the distribution $p(x;a=a^\star, b=20)$ that your friend Alex stored in the computer.

# %% [markdown]
# - **Question 6.** Implement a function `pdf(x, a, b=20)` that computes the probability density function $p(x;a,20)$, and plot it for $b=20$ and $a$ of your choice.
#
#   - Samples of values of x in of the distribution
#
# $$p(x;a,20) = \begin{cases} \frac{1}{10} \frac{x}{a} & \text{if } 0 \leq x \leq a, \\ \frac{1}{10} \frac{20-x}{20-a} & \text{if } a < x \leq 20, \\ 0 & \text{otherwise.} \end{cases}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import requests
import io

b = 20

url = 'https://raw.githubusercontent.com/Jerry0209/FundamentalLearningEPFL/main/HW1/fixed_b.npy'

try:
    response = requests.get(url)
    response.raise_for_status()

    data = np.load(io.BytesIO(response.content))
    print(f"Successfully loaded！")
    print(f"Data Shape: {data.shape}")

except Exception as e:
    print(f"Error：{e}")
    data = np.array([])
# Out:
# Successfully loaded！
# Data Shape: (100,)

# %%
# PDF definition
def pdf(x, a, b=b):

    if a <= 0 or a > b:
        # a must be in the range [0, b]
        if isinstance(x, np.ndarray):
            return np.zeros_like(x)
        else:
            return 0.0

    x = np.asarray(x)
    p = np.zeros_like(x, dtype=float)
    H = 2.0 / b

    # Case 1: 0 <= x <= a
    mask1 = (x >= 0) & (x <= a)
    if a > 0:
        p[mask1] = H * (x[mask1] / a)

    # Case 2: a < x <= b
    mask2 = (x > a) & (x <= b)
    if b - a > 0:
        p[mask2] = H * ((b - x[mask2]) / (b - a))
    elif a == b: # a=b
        #  Belongs to case 1
        pass

    return p

# --- Plot ---
a_test = 8 # Randomly choose

x_vals = np.linspace(-5, 25, 300)
y_vals = pdf(x_vals, a=a_test, b=b)

plt.figure(figsize=(10, 6))
plt.plot(x_vals, y_vals, label=f'p(x; a={a_test}, b={b})')
plt.title(f'PDF (a={a_test}, b={b})')
plt.xlabel('x')
plt.ylabel('p(x)')
plt.grid(True, linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# - **Question 7** How many sample points are there in the file? Let us call this number $n$ and plot an histogram of the data

# %%
# Data points
n = len(data)
print(f"Totally {n} data points in the file.")
print(data[:10]) # Slicing to print 0 - 9

# Histogram
plt.figure(figsize=(10, 6))
plt.hist(data, bins='auto', density=True, alpha=0.7, label='fixed_b data points')
plt.title('Histogram')
plt.xlabel('x')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True, linestyle='--')
plt.show()
# Out:
# Totally 100 data points in the file.
# [ 6.69787293 13.41965333 10.0877695  16.90039196 17.38022455 13.29167114
#  10.06390131 16.61769313  8.89947326 13.19370464]

# %% [markdown]
# - **Question 8.** Compute the empirical mean $\bar x$ and the empirical median $\bar m$.

# %%
x_bar = np.mean(data)
m_bar = np.median(data)

print(f"Empirical Mean (x_bar): {x_bar:.4f}")
print(f"Empirical Median (m_bar): {m_bar:.4f}")
# Out:
# Empirical Mean (x_bar): 10.7398
# Empirical Median (m_bar): 10.7005

# %% [markdown]
# - **Question 9.** Use the expression of the expected value you computed above to find an estimator $\hat a_\text{mean}$ of the true parameter $a^\star$, as a function of the empirical mean $\bar x$. Repeat the same for the median, and find $\hat a_\text{median}$ as a function of the empirical median $\bar m$.
#
# - **Q9 Answer**
#
#   - Method of Moments is used. The expected values of empirical mean and median are calculated above. Then the calculated theoretical value (true mean which depends on $a$) equal to our observed empirical value from the data($\bar x$), and then solve for $a$.
#
#
#   - Estimator based on the expected value $\hat a_\text{mean}$
#
#     $$\mu = \mathbb{E}[X] = \frac{a+b}{3}$$
#   - Let $\mu = \bar x$, and replace $a$ with $\hat a_\text{mean}$
#
#     $$\bar x = \frac{\hat a_\text{mean} + b}{3}$$
#
#   - Solve for $\hat a_\text{mean}$：
#
#     $$3\bar x = \hat a_\text{mean} + b$$
#     $$\hat a_\text{mean} = 3\bar x - 20$$
#
#
#
#   - Same for the median
#
#   $$m = \begin{cases} \sqrt{\frac{ab}{2}} & \text{if } 2a \ge b \\ b - \sqrt{\frac{b(b-a)}{2}} & \text{if } 2a < b \end{cases}$$
#
#   - To find the estimator based on the median, again use the Method of Moments by setting the theoretical median $m$ equal to our empirical median $\bar m$. However, the formula for the theoretical median is piecewise, depending on whether $a$ is greater or less than $b/2$. This means our resulting estimator, $\hat a_\text{median}$, will also have a piecewise definition based on the value of $\bar m$.
#
#   - First consider the case where $\bar m \ge b/2$, which corresponds to the theoretical condition $a \ge b/2$. In this scenario, the formula is $m = \sqrt{ab/2}$. By substituting $\bar m$ for $m$ and $\hat a_\text{median}$ for $a$, we get $\bar m = \sqrt{\hat a_\text{median} b/2}$. To solve for $\hat a_\text{median}$, we square both sides ($\bar m^2 = \hat a_\text{median} b/2$) and rearrange, giving the estimator $\hat a_\text{median} = 2\bar m^2 / b$.
#
#   - Conversely, if we observe that $\bar m < b/2$, we use the other part of the median formula: $m = b - \sqrt{b(b-a)/2}$. Substituting our values gives $\bar m = b - \sqrt{b(b-\hat a_\text{median})/2}$. Solving this for $\hat a_\text{median}$ gives the estimator $\hat a_\text{median} = b - 2(b-\bar m)^2 / b$.
#
#
#   - Final median estimator (with b=20):
#   $$\hat a_\text{median} = \begin{cases} \frac{2\bar m^2}{20} = \frac{\bar m^2}{10} & \text{if } \bar m \ge 10 \\ 20 - \frac{2(20-\bar m)^2}{20} = 20 - \frac{(20-\bar m)^2}{10} & \text{if } \bar m < 10 \end{cases}$$

# %% [markdown]
# - **Question 10.** Implement a function `est_a_mean(x_bar, b=20)` and `est_a_median(m_bar, b=20)` that code the estimators you found above. What are the vaules of $\hat a_\text{mean}$ and $\hat a_\text{median}$ for the data you have in the file `fixed_b.npy`?

# %%
def est_a_mean(x_bar, b=b):

    return 3 * x_bar - b

def est_a_median(m_bar, b=b):

    if m_bar >= b / 2.0:
        return 2 * (m_bar**2) / b
    else:
        return b - 2 * ((b - m_bar)**2) / b

a_hat_mean = est_a_mean(x_bar, b=b)
a_hat_median = est_a_median(m_bar, b=b)

print(f"Estimate based on mean (a_hat_mean):    {a_hat_mean:.4f}")
print(f"Estimate based on median (a_hat_median): {a_hat_median:.4f}")
# Out:
# Estimate based on mean (a_hat_mean):    12.2193
# Estimate based on median (a_hat_median): 11.4501

# %% [markdown]
#  - **Question 11.** Consider the log-likelihood function $\mathbb{L}(a;\{x_i\}_{i\in[1,n]},b=20)$. Plot the log-likelihood function as a function of $a$ for the data in the file `fixed_b.npy`.
#
#  $$\widehat{\lambda}_{ML}=argmax_{\lambda}\prod_i P(x_i|\lambda)=argmax_{\lambda}\left(\sum_i\log(P(x_i|\lambda))\right)$$

# %%
def loglh(a, data, b=b):
    # the same mehthod in TP2
    if a <= 0 or a >= b:
        return -np.inf

    logl = 0.0
    for x_i in data:
        p_i = pdf(x_i, a, b)

        # dataset is impossible
        if p_i == 0:
            return -np.inf

        logl += np.log(p_i)
    return logl

a_vals = np.linspace(1, 19.9, 1000)
ll_vals = [loglh(a, data, b=b) for a in a_vals]

plt.figure(figsize=(10, 6))
plt.plot(a_vals, ll_vals, label='$\mathcal{L}(a)$')
plt.title('Log-Likelihood Function $\mathcal{L}(a)$ (b=20)')
plt.xlabel('Paramter a')
plt.ylabel('Log likelihood')
plt.grid(True, linestyle='--')
plt.legend()
plt.show()
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:22: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:22: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-2351785290.py:21: SyntaxWarning: invalid escape sequence '\m'
#   plt.plot(a_vals, ll_vals, label='$\mathcal{L}(a)$')
# /tmp/ipython-input-2351785290.py:22: SyntaxWarning: invalid escape sequence '\m'
#   plt.title('Log-Likelihood Function $\mathcal{L}(a)$ (b=20)')

# %% [markdown]
#  - **Question 12.** What is the maximum likelihood estimator $\hat a_\text{MLE}$?

# %%
from scipy.optimize import minimize
# Find the x value which maximizes the likelihood function

# Method 1
# Find the index of the maximum value in ll_vals
max_ll_index = np.argmax(ll_vals)

# Find the corresponding a value
a_hat_mle = a_vals[max_ll_index]

print(f"Maximum Likelihood Estimate (a_hat_mle): {a_hat_mle:.4f}")

# Method 2 : optimizer
def negative_log_likelihood(a_single_value, data, b):
    a = float(a_single_value)

    ll = loglh(a, data, b)

    # Return negative value
    return -ll


# Scipy

initial_guess = a_hat_median
epsilon = 1e-9
bounds = [(epsilon, b - epsilon)]

result = minimize(
    negative_log_likelihood,
    x0=initial_guess,
    args=(data, b),
    bounds=bounds,
    method='L-BFGS-B'
)

if result.success:
    a_hat_mle_optimized = result.x[0]
    print(f"a_MLE (From optimizer): {a_hat_mle_optimized:.8f}")
else:
    print("\n optimization failed！")
    print(result.message)

# Plot the estimated PDF
plt.plot(x_vals, pdf(x_vals, a_hat_mle, b), 'r-', lw=2, label=f'MLE PDF (a={a_hat_mle:.2f})')
plt.axvline(a_hat_mean, color='g', linestyle='--', label=f'a_hat_mean = {a_hat_mean:.2f}')
plt.axvline(a_hat_median, color='b', linestyle='--', label=f'a_hat_median = {a_hat_median:.2f}')
plt.axvline(a_hat_mle, color='r', linestyle='--', label=f'a_hat_mle = {a_hat_mle:.2f}')

plt.title('Histogram with Three Estimates')
plt.xlabel('x')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# Maximum Likelihood Estimate (a_hat_mle): 11.3676
# a_MLE (From optimizer): 11.36579655
# /tmp/ipython-input-55131911.py:14: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   a = float(a_single_value)

# %% [markdown]
# - **Question 13.** Use bootstrapping to compute the 95% confidence interval for all the three $a$ estimators computed above.

# %%
# Since bootstrapping requires a lot of data samples, it's better to use the np arrary instead of for loop
def est_a_median_vectorized(m_bar, b=b):
    return np.where(
        m_bar >= b / 2.0, # calculates for all elements
        2 * (m_bar**2) / b,
        b - 2 * ((b - m_bar)**2) / b
    )

n_bootstraps = 10000
boot_data = [] # Store different Bootstrap samples from 'data'
boot_a_mean = []
boot_a_median = []
boot_a_mle = []

n = len(data)

np.random.seed(233)

print(f"Start {n_bootstraps} Bootstrap iterations")

boot_data = np.random.choice(data, (n_bootstraps,n))

# x_mean
x_bar_boot = np.mean(boot_data, axis=1)
boot_a_mean = est_a_mean(x_bar_boot, b)

# x_median
m_bar_boot = np.median(boot_data, axis=1)
boot_a_median = est_a_median_vectorized(m_bar_boot, b)


# MLE (Minimum Distance Estimation)
boot_data_sorted = np.sort(boot_data, axis=1)

# Pre-compute the target k/n values. Shape: (n,)
k_vals = np.arange(1, n + 1)
target_vals = b * k_vals / n

# Find differences.
diffs = np.abs(boot_data_sorted - target_vals)

best_k_idx = np.argmin(diffs, axis=1)
row_indices = np.arange(n_bootstraps) # [0, 1, 2, ..., 4999]
boot_a_mle = boot_data_sorted[row_indices, best_k_idx]

print("Bootstrap complete!")

# Calculate confidence intervals
ci_mean = np.percentile(boot_a_mean, [2.5, 97.5])
ci_median = np.percentile(boot_a_median, [2.5, 97.5])
ci_mle = np.percentile(boot_a_mle, [2.5, 97.5])

print(f"--- 95% Confidence Intervals ---")
print(f"a_hat_mean:   {a_hat_mean:.4f}, CI: [{ci_mean[0]:.4f}, {ci_mean[1]:.4f}]")
print(f"a_hat_median: {a_hat_median:.4f}, CI: [{ci_median[0]:.4f}, {ci_median[1]:.4f}]")
print(f"a_hat_mle:    {a_hat_mle:.4f}, CI: [{ci_mle[0]:.4f}, {ci_mle[1]:.4f}]")
# Out:
# Start 10000 Bootstrap iterations
# Bootstrap complete!
# --- 95% Confidence Intervals ---
# a_hat_mean:   12.2193, CI: [9.8339, 14.5827]
# a_hat_median: 11.4501, CI: [9.9208, 13.2877]
# a_hat_mle:    11.3676, CI: [9.6153, 13.9666]

# %% [markdown]
# - **Question 14.** Compute the Fisher information of $a$ under the distribution $p(x;a,b=20)$.
#
# - **Q14 Answer**
#   $$
#   S(x,\lambda)=\partial_\lambda L(x|\lambda),
#   $$
#
#   $$
#   I(\lambda)=\mathbb{E}_{\lambda}[S(x|\lambda)^2].
#   $$
#
#     - In this problem
#   $$I(a) = \mathbb{E} \left[ \left( \frac{\partial \log p(X; a)}{\partial a} \right)^2 \right]$$
#
#     - Log-Likelihood:
#   $$\log p(x; a, b) = \log(H) + \begin{cases} \log(x/a) & \text{if } 0 \le x \le a \\ \log((b-x)/(b-a)) & \text{if } a < x \le b \end{cases}$$
#
#
#   - Derivative of the PDF:
#   $$\frac{\partial \log p(x; a)}{\partial a} = \begin{cases} -1/a & \text{if } 0 \le x \le a \\ 1/(b-a) & \text{if } a < x \le b \end{cases}$$
#
#
#   $$\left( \frac{\partial \log p}{\partial a} \right)^2 = \begin{cases} 1/a^2 & \text{if } 0 \le x \le a \\ 1/(b-a)^2 & \text{if } a < x \le b \end{cases}$$
#
#   - Calculate the Expectation $I(a)$:
#   $$I(a) = \int_{0}^{b} \left( \frac{\partial \log p}{\partial a} \right)^2 p(x; a, b) \, dx$$
#
#   $$I(a) = \int_{0}^{a} \left( \frac{1}{a^2} \right) p(x) \, dx + \int_{a}^{b} \left( \frac{1}{(b-a)^2} \right) p(x) \, dx$$
#
#   - This can be seen as:
#     $$I(a) = \frac{1}{a^2} \cdot F(a) + \frac{1}{(b-a)^2} \cdot (1 - F(a))$$
#
#       * $F(a) = \frac{a^2}{ab} = \frac{a}{b}$.(the CDF from Question 3)
#       * $1 - F(a) = 1 - \frac{a}{b} = \frac{b-a}{b}$.
#
#   - After substitution:
#     $$I(a) = \frac{1}{a^2} \left( \frac{a}{b} \right) + \frac{1}{(b-a)^2} \left( \frac{b-a}{b} \right)=\frac{1}{a(b-a)}$$
#
#
#   - For $n$ independent and identically distributed (i.i.d.) samples, the total Fisher information is $I_n(a) = n \cdot I(a) = \frac{n}{a(b-a)}$. When $b=20$:
# $$I_n(a) = \frac{n}{a(20-a)}$$

# %% [markdown]
# - **Question 15.** Can you compute the maximum likelihood estimator using the Jeffrey Posterior $\hat a_\text{jeff}$? Provide also the confidence intervals.
#
# - **Q15 Answer**
#
#
#   $$P(a) \propto \sqrt{\frac{1}{a(b-a)}} = \frac{1}{\sqrt{a(b-a)}}$$
#
#   - Prior
#
#   $$\log(P(a)) \propto \log\left(\frac{1}{\sqrt{a(b-a)}}\right) = -\frac{1}{2}\log(a(b-a)) = -\frac{1}{2}\log(a) - \frac{1}{2}\log(b-a)$$
#
#   - logPosterior
#   $$\text{Posterior}(a) = \mathbb{L}(a) - \frac{1}{2}\log(a) - \frac{1}{2}\log(b-a)$$

# %%
from scipy.integrate import cumulative_trapezoid, trapezoid
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt

# b=20

# Calculate the log-posterior
log_prior_vals = -0.5 * np.log(a_vals) - 0.5 * np.log(b - a_vals)
log_posterior_vals = ll_vals + log_prior_vals

# Find the posterior estimate
a_hat_jeff = a_vals[np.argmax(log_posterior_vals)]

print(f"Jeffreys Posterior Estimate (a_hat_jeff): {a_hat_jeff:.4f}")

# Calculate the credible interval

posterior_pdf_unnorm = np.exp(log_posterior_vals - np.max(log_posterior_vals))

area = trapezoid(posterior_pdf_unnorm, a_vals)
posterior_pdf = posterior_pdf_unnorm / area

# Calculate the posterior CDF
posterior_cdf = cumulative_trapezoid(posterior_pdf, a_vals, initial=0)
posterior_cdf = posterior_cdf / posterior_cdf[-1] # Ensure the CDF ends at 1

inv_cdf_func = interp1d(posterior_cdf, a_vals)
ci_jeff_low = inv_cdf_func(0.025)
ci_jeff_high = inv_cdf_func(0.975)

print(f"Jeffreys 95% Credible Interval: [{ci_jeff_low:.4f}, {ci_jeff_high:.4f}]")

# Plot
plt.figure(figsize=(12, 7))
plt.plot(a_vals, posterior_pdf, 'b-', label='Jeffreys Posterior PDF')
plt.axvline(a_hat_jeff, color='b', linestyle='--', label=f'a_hat_jeff = {a_hat_jeff:.2f}')
plt.fill_between(a_vals, posterior_pdf,
                 where=(a_vals >= ci_jeff_low) & (a_vals <= ci_jeff_high),
                 color='blue', alpha=0.2, label='95% Credible Interval')
plt.title('Jeffreys Posterior Distribution (b=20)')
plt.xlabel('a')
plt.ylabel('Posterior')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Jeffreys Posterior Estimate (a_hat_jeff): 11.3676
# Jeffreys 95% Credible Interval: [9.7409, 13.9478]

# %% [markdown]
# All the estimation you derived couldn't find the secret code with absolute certainty. The confidence intervals you computed are too large to produce one single code. Moreover your friend is a bit paranoid and changes the code every week, so the information you have is not valid anymore. You need to find a better way to estimate the code.

# %% [markdown]
# ### Test the estimators
# You are still trying to sneak into your friend's computer to get new samples of the distribution. In the meanwhile, you want to test the estimators you derived on a synthetic dataset. Florent gave you this Python function to sample the distribution $p(x;a,b)$:

# %%
import numpy as np
import matplotlib.pyplot as plt

def sample(a: float, b: float, size: int=1) -> np.array:
    def sample_single(a: float, b: float) -> float:
        u = 0
        v = b
        while not((u <= a and v <= 2/(a*b)*u) or (u > a and v <= 2/b *(b-u)/(b-a))):
            u = np.random.uniform(0, b)
            v = np.random.uniform(0, 2/b)
        return u
    return np.array([sample_single(a, b) for _ in range(size)])

# %% [markdown]
# - **Bonus question 1** The sampling function is not efficient. Can you provide a more efficient way to sample the distribution?
#
# - **BQ1 Answer**
#
#     - The `sample` function is very slow because it uses a `for` loop with a nested `while` loop inside, generating only one sample at a time.
#
#     - To complete the simulation in reasonable time (10 * 300 * 1000 = 3,000,000 samples), we need to use numpy vectorization.
#
#     - The idea is to generate many candidate points (u, v) at once (for example, 2000 points), then use numpy array operations to compute all p(u) values simultaneously, and finally filter for all u where v < p(u). We repeat this process until we collect enough samples.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize_scalar
from tqdm.notebook import tqdm # To show a progress bar

def sample_optimized(a: float, b: float, size: int=1) -> np.array:
    samples = np.array([])

    # Handle the degenerate cases to avoid division by zero
    b_sq = b * b
    if a == 0:
        denom1 = 1.0 # Will not be used
        denom2 = b_sq
    elif a == b:
        denom1 = b_sq
        denom2 = 1.0 # Will not be used
    else:
        denom1 = a * b
        denom2 = b * (b - a)

    while len(samples) < size:
        needed = size - len(samples)

        # Number of attemps to get a random value
        n_try = int(needed * 2.1) + 100

        u = np.random.uniform(0, b, size=n_try)
        v = np.random.uniform(0, 2/b, size=n_try)

        p_u = np.zeros_like(u)

        mask1 = (u <= a)
        mask2 = (u > a)

        # Calculate PDF values p(u) in a vector
        if a > 0:
            p_u[mask1] = 2 * u[mask1] / denom1
        if a < b:
            p_u[mask2] = 2 * (b - u[mask2]) / denom2

        # Get the accepted samples within the p(u)
        accepted_mask = (v <= p_u)
        new_samples = u[accepted_mask]

        samples = np.concatenate((samples, new_samples))

    # Return the number of samples requested
    return samples[:size]

# %% [markdown]
# Stick with the case where $b=20$, and sample $N=1000$ points from the distribution $p(x;a,b)$ for 10 values of $a\in[0,20]$.
# - **Question 16.** Compute and plot the mean squared error of the 4 estimators for $\hat a_\text{mean}, \hat a_\text{median}, \hat a_\text{ML}$ and $\hat a_\text{Jeff}$, as well as the Cramér-Rao lower bound. Which one is the best? [Hint: to have a good estimate of the mean squared error, you can repeat the sampling 300 times and compute the average of the squared error, for each value of $a$; be patient, this will take some time to compute]
#
#
# - **Q16 Answer**
#
#   - For **unbiased estimators**, as for example the maximum likelihood one, the CRB tells us that for each parameter $\lambda_i$ we have
#
#   $$MSE(\widehat{\lambda_i}_{ML};\lambda_i) \geq \{[I_N(\mathbf{\lambda})]^{-1}\}_{ii}$$
#
#   - where $I_N(\mathbf{\lambda})$ is the Fisher information.
#
#   $$\text{CRLB}=\frac{1}{I_n(a)}=\frac{a(b-a)}{n}$$
#
#
#   - Based on the graph, the **Maximum Likelihood Estimator ($\hat{a}_{\text{ML}}$)** and the **Jeffreys MAP estimator ($\hat{a}_{\text{Jeff}}$)** are tied for being the best. Their curves (the green star and red dotted line) are the lowest on the plot, meaning they consistently have the smallest Mean Squared Error (MSE) regardless of the true value of $a$.
#
#   - What makes them truly stand out is that their MSE lines almost perfectly trace the **Cramér-Rao Bound (CRLB)**, which is the dashed black line. The CRLB represents the theoretical *minimum possible error* any unbiased estimator can achieve. Since the MLE and Jeffreys estimators nearly reach this "perfect" performance limit, they are considered **statistically efficient**.
#
#   - In contrast, the other two methods are far worse. The Method of Moments estimator ($\hat{a}_{\text{mean}}$) has a significantly higher error, and the Median-based estimator ($\hat{a}_{\text{median}}$) performs the poorest by a large margin, especially when the true $a$ is near the boundaries (like $a=2.5$ or $a=17.5$). Since the distribution is heavily skewed in those situations, where the estimator value is pulled by the long tail.

# %%
# Vectorized function to calculate neg log, much faster than using for loop
def neg_log_likelihood(a: float, samples: np.array, b: float) -> float:

    epsilon = 1e-9
    if a <= epsilon or a >= b - epsilon:
        return np.inf

    # Split samples
    samples_le_a = samples[samples <= a]
    samples_gt_a = samples[samples > a]

    n1 = len(samples_le_a)
    n2 = len(samples_gt_a)

    # Calculate log-likelihood for each part, for x <= a and x>=a
    logL_1 = n1 * (np.log(2) - np.log(a) - np.log(b)) + \
             np.sum(np.log(samples_le_a + epsilon))

    logL_2 = n2 * (np.log(2) - np.log(b) - np.log(b - a)) + \
             np.sum(np.log(b - samples_gt_a + epsilon))

    return -(logL_1 + logL_2)

def neg_log_posterior_jeff(a: float, samples: np.array, b: float) -> float:
    # minimize negative Jeffreys prior equals to maximize Jeffreys prior
    epsilon = 1e-9
    if a <= epsilon or a >= b - epsilon:
        return np.inf

    nll = neg_log_likelihood(a, samples, b)

    # Add negative log-prior as before
    neg_log_prior = 0.5 * np.log(a) + 0.5 * np.log(b - a)

    return nll + neg_log_prior


def find_mle(samples: np.array, b: float) -> float: # by minimizing the negative log-likelihood
    res = minimize_scalar(
        neg_log_likelihood,
        args=(samples, b),
        bounds=(1e-6, b - 1e-6),
        method='bounded'
    )
    return res.x

def find_map_jeff(samples: np.array, b: float) -> float: # Jeffreys prior
    res = minimize_scalar(
        neg_log_posterior_jeff,
        args=(samples, b),
        bounds=(1e-6, b - 1e-6),
        method='bounded'
    )
    return res.x


# Simulation
b_fixed = 20.0
N_samples = 1000
M_repetitions = 300 # As per the hint

# Test 10 values
a_values = np.linspace(1, 19, 10)

# Arrays to store the Mean Squared Error (MSE) results
mse_mean = np.zeros_like(a_values)
mse_median = np.zeros_like(a_values)
mse_ml = np.zeros_like(a_values)
mse_jeff = np.zeros_like(a_values)
crlb_values = np.zeros_like(a_values)

# --- Run the Simulation ---
# Using tqdm for a progress bar, as this will take a few minutes
for i, a_true in enumerate(tqdm(a_values, desc='Simulating')):

    # Store squared errors for this 'a'
    sq_err_mean = []
    sq_err_median = []
    sq_err_ml = []
    sq_err_jeff = []

    # Calculate CRLB for this 'a'
    crlb_values[i] = (a_true * (b_fixed - a_true)) / N_samples

    for _ in range(M_repetitions):
        # 1. Get N samples
        samples = sample_optimized(a_true, b_fixed, size=N_samples)

        # 2. Calculate estimators
        # Estimator 1: Mean (MoM)
        x_bar = np.mean(samples)
        # a_hat_mean = 3 * x_bar - b_fixed
        a_hat_mean = est_a_mean(x_bar, b=b)

        # Estimator 2: Median
        m_s = np.median(samples)
        a_hat_median = est_a_median(m_s, b=b)

        # Estimator 3: ML
        a_hat_ml = find_mle(samples, b_fixed)
        # a_hat_ml = find_mle_with_minimize(samples, b_fixed)

        # Estimator 4: Jeffreys
        a_hat_jeff = find_map_jeff(samples, b_fixed)

        # Difference between ML and Jefferys
        # if i == 0:
        print(f"  Difference = {a_hat_mle - a_hat_jeff:.10f}")

        # Clip the MoM-based estimators, as they can go out of bounds
        a_hat_mean = np.clip(a_hat_mean, 0, b_fixed)
        a_hat_median = np.clip(a_hat_median, 0, b_fixed)

        # Store squared errors
        sq_err_mean.append((a_hat_mean - a_true)**2)
        sq_err_median.append((a_hat_median - a_true)**2)
        sq_err_ml.append((a_hat_ml - a_true)**2)
        sq_err_jeff.append((a_hat_jeff - a_true)**2)

    # Calculate average MSE for this certain 'a'
    mse_mean[i] = np.mean(sq_err_mean)
    mse_median[i] = np.mean(sq_err_median)
    mse_ml[i] = np.mean(sq_err_ml)
    mse_jeff[i] = np.mean(sq_err_jeff)

print("Simulation complete.")


# Plot the Results
plt.figure(figsize=(15, 8))

plt.plot(a_values, mse_mean, label=r'$\hat{a}_{\text{mean}}$ (MoM)', marker='o')
plt.plot(a_values, mse_median, label=r'$\hat{a}_{\text{median}}$ (Median)', marker='s')
plt.plot(a_values, mse_ml, label=r'$\hat{a}_{\text{ML}}$ (MLE)', marker='^', linestyle='-')
plt.plot(a_values, mse_jeff, label=r'$\hat{a}_{\text{Jeff}}$ (Jeffreys MAP)', marker='x', linestyle=':')
plt.plot(a_values, crlb_values, label='Cramér-Rao Bound (CRLB)', color='black', linestyle='--')

plt.title(f'Estimator Mean Squared Error (MSE) vs. True $a$ (N={N_samples}, M={M_repetitions})')
plt.xlabel('True parameter $a$')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.grid(True, linestyle=':')
plt.show()
# Out:
# Simulating:   0%|          | 0/10 [00:00<?, ?it/s]
#   Difference = 10.4505519644
#   Difference = 10.3264394419
#   Difference = 10.5885567562
#   Difference = 10.2520298507
#   Difference = 10.5490752710
#   Difference = 10.4257008662
#   Difference = 10.5117924496
#   Difference = 10.2489656541
#   Difference = 10.5262253851
#   Difference = 10.3854629222
#   Difference = 10.3238335248
#   Difference = 10.4928271200
#   Difference = 10.3144093582
#   Difference = 10.3282788802
#   Difference = 10.2411553750
#   Difference = 10.3870661433
#   Difference = 10.3308649616
#   Difference = 10.5520405106
#   Difference = 10.4028162532
#   Difference = 9.9886376027
#   Difference = 10.4611139321
#   Difference = 10.3142851247
#   Difference = 10.4050124030
#   Difference = 10.4510122083
#   Difference = 10.2434506708
#   Difference = 10.4107569364
#   Difference = 10.1686292170
#   Difference = 10.5693633403
#   Difference = 10.5859824288
#   Difference = 10.2634394921
#   Difference = 10.3886865794
#   Difference = 10.6094112358
#   Difference = 10.3782017093
#   Difference = 10.1547586356
#   Difference = 10.4230949185
#   Difference = 10.1252407909
#   Difference = 10.5747105051
#   Difference = 10.2403578417
#   Difference = 10.2064789370
#   Difference = 10.5469906693
#   Difference = 10.3114093846
#   Difference = 10.6053749253
#   Difference = 10.2321288786
#   Difference = 10.1961023544
#   Difference = 10.4445056258
#   Difference = 10.6695735924
#   Difference = 10.4555498563
#   Difference = 10.2478903240
#   Difference = 10.1847121894
#   Difference = 10.4349041004
#   Difference = 10.6703408203
#   Difference = 10.4628884460
#   Difference = 10.4140907519
#   Difference = 10.2581649033
#   Difference = 10.3307296661
#   Difference = 10.3532101050
#   Difference = 10.5830534964
#   Difference = 10.2702121613
#   Difference = 10.4449363808
#   Difference = 10.4230560601
#   Difference = 10.2611630451
#   Difference = 10.5257343800
#   Difference = 10.4901524335
#   Difference = 10.2424101572
#   Difference = 10.2401208904
#   Difference = 10.2814919920
#   Difference = 10.2092800821
#   Difference = 10.3445110892
#   Difference = 10.3043482809
#   Difference = 10.3396290281
#   Difference = 10.3090977828
#   Difference = 10.3466656940
#   Difference = 10.3193256369
#   Difference = 10.3261366672
#   Difference = 10.5945910379
#   Difference = 10.1337611904
#   Difference = 10.2499495513
#   Difference = 10.2163280665
#   Difference = 10.4632227884
#   Difference = 10.3597078707
#   Difference = 10.3838614159
#   Difference = 10.1892549704
#   Difference = 10.4474839386
#   Difference = 10.3076436971
#   Difference = 10.4612667097
#   Difference = 10.2276090510
#   Difference = 10.0481478401
#   Difference = 10.3727559712
#   Difference = 10.6838209685
#   Difference = 10.0474340401
#   Difference = 10.3300760669
#   Difference = 10.4620498635
#   Difference = 10.5476669506
#   Difference = 10.3877761744
#   Difference = 10.4065869176
#   Difference = 10.4264503726
#   Difference = 10.3466865320
#   Difference = 10.6763215563
#   Difference = 10.4442804936
#   Difference = 10.4428740499
#   Difference = 10.3723532009
#   Difference = 10.5459933138
#   Difference = 10.2132110552
#   Difference = 10.2682315605
#   Difference = 10.4339781819
#   Difference = 10.2734045915
#   Difference = 10.2600774870
#   Difference = 10.2510326099
#   Difference = 10.3813318499
#   Difference = 10.3345533579
#   Difference = 10.5027974809
#   Difference = 10.3316000513
#   Difference = 10.3673682461
#   Difference = 10.4233633177
#   Difference = 10.1879391527
#   Difference = 10.2818869601
#   Difference = 10.3265018553
#   Difference = 10.4486996037
#   Difference = 10.4643004582
#   Difference = 10.2358440554
#   Difference = 10.5655478266
#   Difference = 10.2971542861
#   Difference = 10.3529406725
#   Difference = 10.4882214744
#   Difference = 10.6209408466
#   Difference = 10.3150649761
#   Difference = 10.4370366125
#   Difference = 10.4269859530
#   Difference = 10.4257914618
#   Difference = 10.4883065425
#   Difference = 10.2757497964
#   Difference = 10.3078327290
#   Difference = 10.4132475450
#   Difference = 10.6310585262
#   Difference = 10.3712815586
#   Difference = 10.2494867726
#   Difference = 10.2376391198
#   Difference = 10.3864364801
#   Difference = 10.4229376026
#   Difference = 10.3675934487
#   Difference = 10.0081446783
#   Difference = 10.4055219363
#   Difference = 10.5032871076
#   Difference = 10.4527328095
#   Difference = 10.4796099671
#   Difference = 10.5458759660
#   Difference = 10.2768031535
#   Difference = 10.5143042108
#   Difference = 10.3219328991
#   Difference = 10.4166326410
#   Difference = 10.4345459648
#   Difference = 10.5728312470
#   Difference = 10.4793574293
#   Difference = 10.4092433912
#   Difference = 10.2609681995
#   Difference = 10.2900015353
#   Difference = 10.3337496587
#   Difference = 10.4652134798
#   Difference = 10.6016491938
#   Difference = 10.4046565915
#   Difference = 10.5028730488
#   Difference = 10.3701816908
#   Difference = 10.4496909376
#   Difference = 10.3543961697
#   Difference = 10.5046886565
#   Difference = 9.8063821414
#   Difference = 10.1869801307
#   Difference = 10.3613167546
#   Difference = 10.2746428673
#   Difference = 10.3303701686
#   Difference = 10.3542789164
#   Difference = 10.4853487410
#   Difference = 10.5506458798
#   Difference = 10.3234225138
#   Difference = 10.7077817611
#   Difference = 10.5891937551
#   Difference = 10.4463157960
#   Difference = 10.3833167685
#   Difference = 10.1007834784
#   Difference = 10.4807432831
#   Difference = 10.4453089532
#   Difference = 10.3146564214
#   Difference = 10.3873942555
#   Difference = 10.4851835518
#   Difference = 10.2135950705
#   Difference = 10.5080240011
#   Difference = 10.3538477676
#   Difference = 10.5633299408
#   Difference = 9.8968139087
#   Difference = 10.1518989001
#   Difference = 10.3350297811
#   Difference = 10.4050711268
#   Difference = 10.3995747662
#   Difference = 10.5045043934
#   Difference = 10.6082590046
#   Difference = 10.6110673941
#   Difference = 10.5123155759
#   Difference = 10.3059021986
#   Difference = 10.1131990939
#   Difference = 9.8158603673
#   Difference = 10.5510730126
#   Difference = 10.0478792592
#   Difference = 10.2766681806
#   Difference = 10.4718132245
#   Difference = 10.4205132096
#   Difference = 10.3268832132
#   Difference = 10.3686768353
#   Difference = 10.2926818628
#   Difference = 10.3521515092
#   Difference = 10.3130106753
#   Difference = 10.3105205614
#   Difference = 10.1666116188
#   Difference = 10.1827262636
#   Difference = 9.9375782627
#   Difference = 10.2126392865
#   Difference = 10.4137973545
#   Difference = 10.4947682541
#   Difference = 10.7095360374
#   Difference = 10.3400573022
#   Difference = 10.0124669490
#   Difference = 10.4331508388
#   Difference = 10.5659996847
#   Difference = 10.2670305401
#   Difference = 10.1849376382
#   Difference = 10.2029401261
#   Difference = 10.5307165800
#   Difference = 10.3280808663
#   Difference = 10.4348813182
#   Difference = 10.2311865784
#   Difference = 10.2107346397
#   Difference = 10.3825791505
#   Difference = 10.0669357414
#   Difference = 10.2884630989
#   Difference = 10.2725592283
#   Difference = 10.6913984008
#   Difference = 10.4105455083
#   Difference = 10.2671709970
#   Difference = 10.4932030571
#   Difference = 10.2335635304
#   Difference = 10.2478248919
#   Difference = 10.3120093243
#   Difference = 10.3105889546
#   Difference = 10.3707061558
#   Difference = 10.4229939397
#   Difference = 10.2248659223
#   Difference = 10.1245880576
#   Difference = 10.0329938857
#   Difference = 10.0092748626
#   Difference = 10.3782274041
#   Difference = 10.4430591622
#   Difference = 10.3520653752
#   Difference = 10.1536003703
#   Difference = 10.4033924504
#   Difference = 10.3932786693
#   Difference = 10.4725398691
#   Difference = 10.3703037973
#   Difference = 10.3073049722
#   Difference = 10.5676706394
#   Difference = 10.3122667812
#   Difference = 10.4720451354
#   Difference = 10.5758371816
#   Difference = 10.2672609400
#   Difference = 10.5121115658
#   Difference = 10.3247122957
#   Difference = 10.3259250465
#   Difference = 10.5883300754
#   Difference = 10.2712441260
#   Difference = 10.4511857945
#   Difference = 10.3710925591
#   Difference = 10.2194036596
#   Difference = 10.2316555752
#   Difference = 10.3518836795
#   Difference = 10.3836841947
#   Difference = 10.0866266525
#   Difference = 10.5056358460
#   Difference = 10.4115763584
#   Difference = 10.2521761131
#   Difference = 10.2572894894
#   Difference = 10.4771492433
#   Difference = 10.2047769873
#   Difference = 10.4622139625
#   Difference = 10.3405892271
#   Difference = 10.4271217133
#   Difference = 10.2037754433
#   Difference = 10.3270179045
#   Difference = 10.0544909522
#   Difference = 10.3265058370
#   Difference = 10.2061767282
#   Difference = 10.5668018465
#   Difference = 10.2685898527
#   Difference = 10.1215810034
#   Difference = 10.3095424394
#   Difference = 10.4373023561
#   Difference = 10.3488793960
#   Difference = 10.2958731029
#   Difference = 10.3409514689
#   Difference = 10.2667670572
#   Difference = 10.2220454158
#   Difference = 10.3657410202
#   Difference = 10.4073774045
#   Difference = 8.6130568977
#   Difference = 8.3136088676
#   Difference = 8.4362785508
#   Difference = 8.5893426970
#   Difference = 8.3662231915
#   Difference = 8.1278418107
#   Difference = 8.4836625936
#   Difference = 7.9562596727
#   Difference = 8.4341623060
#   Difference = 8.0490901963
#   Difference = 8.4473145412
#   Difference = 8.5465850667
#   Difference = 8.4726823470
#   Difference = 8.4070938538
#   Difference = 8.3256767378
#   Difference = 8.1358461065
#   Difference = 8.6340232632
#   Difference = 8.2093467540
#   Difference = 8.6362419229
#   Difference = 8.7482303034
#   Difference = 8.4853749793
#   Difference = 8.0440730526
#   Difference = 8.7117222571
#   Difference = 8.1102201286
#   Difference = 8.2934984573
#   Difference = 8.6282770376
#   Difference = 8.2707229913
#   Difference = 8.5053518298
#   Difference = 8.5259329888
#   Difference = 8.8115205938
#   Difference = 7.9111032371
#   Difference = 8.6289554152
#   Difference = 8.6062336481
#   Difference = 8.3325112371
#   Difference = 8.7336779388
#   Difference = 8.2914633779
#   Difference = 8.3580375106
#   Difference = 8.1055240577
#   Difference = 8.1729787753
#   Difference = 8.4847102328
#   Difference = 8.3267711240
#   Difference = 8.3697522476
#   Difference = 8.1509946548
#   Difference = 7.9128342941
#   Difference = 7.7943816966
#   Difference = 8.2320192505
#   Difference = 8.4063735937
#   Difference = 8.3275325376
#   Difference = 8.5172272644
#   Difference = 8.3691337457
#   Difference = 8.5491257516
#   Difference = 8.4977816494
#   Difference = 8.2330522331
#   Difference = 8.0254650358
#   Difference = 8.0868178096
#   Difference = 8.4887993638
#   Difference = 8.4814339895
#   Difference = 8.1238884801
#   Difference = 8.4679040890
#   Difference = 8.2297345397
#   Difference = 8.4706123536
#   Difference = 8.8159065865
#   Difference = 8.0476988323
#   Difference = 8.7247806349
#   Difference = 8.4294980390
#   Difference = 8.2075444134
#   Difference = 8.3339567716
#   Difference = 8.2385042732
#   Difference = 8.2915410845
#   Difference = 8.3910131882
#   Difference = 7.9563211888
#   Difference = 8.0861960162
#   Difference = 8.1285504977
#   Difference = 8.0254159347
#   Difference = 8.2588800318
#   Difference = 8.3344629209
#   Difference = 8.6543363853
#   Difference = 8.9040351373
#   Difference = 8.2933146615
#   Difference = 8.3064978399
#   Difference = 8.3239616097
#   Difference = 8.6909687711
#   Difference = 8.4150165420
#   Difference = 8.3199958255
#   Difference = 8.0894094350
#   Difference = 8.4294785161
#   Difference = 8.2306192275
#   Difference = 8.4557146920
#   Difference = 8.4248959265
#   Difference = 8.5155675295
#   Difference = 8.2664796868
#   Difference = 8.3318610969
#   Difference = 8.5500859216
#   Difference = 8.3246028287
#   Difference = 8.4493165795
#   Difference = 8.1960594882
#   Difference = 8.1533959760
#   Difference = 8.7808143379
#   Difference = 8.4877771956
#   Difference = 8.1415792788
#   Difference = 8.3130788355
#   Difference = 8.4737693310
#   Difference = 8.2882460322
#   Difference = 8.5568882552
#   Difference = 8.0555356869
#   Difference = 7.8074997161
#   Difference = 8.6551247239
#   Difference = 8.3463943728
#   Difference = 8.3440636529
#   Difference = 8.5095012870
#   Difference = 8.5878735133
#   Difference = 8.8416838288
#   Difference = 8.6220242350
#   Difference = 8.2694200728
#   Difference = 8.5149268202
#   Difference = 8.0114249923
#   Difference = 8.4867454296
#   Difference = 8.3818754705
#   Difference = 8.0979119149
#   Difference = 8.3543171878
#   Difference = 8.3660927843
#   Difference = 8.5088461857
#   Difference = 8.0488503142
#   Difference = 8.8124849946
#   Difference = 7.8971138592
#   Difference = 8.4333648606
#   Difference = 8.4768947782
#   Difference = 7.8247214925
#   Difference = 8.6241156512
#   Difference = 7.8035765564
#   Difference = 8.7631157356
#   Difference = 7.8729388648
#   Difference = 8.9568088182
#   Difference = 8.4907124540
#   Difference = 8.2334123408
#   Difference = 8.4752116952
#   Difference = 8.2315670276
#   Difference = 8.3550940427
#   Difference = 8.3373468190
#   Difference = 8.1467929382
#   Difference = 8.5932880997
#   Difference = 8.2268497946
#   Difference = 8.4504243410
#   Difference = 8.2929642500
#   Difference = 8.3418171252
#   Difference = 8.2514198059
#   Difference = 8.3418740793
#   Difference = 8.1933732798
#   Difference = 8.2711258376
#   Difference = 8.3823435385
#   Difference = 8.5654064771
#   Difference = 8.2992944257
#   Difference = 8.4160573883
#   Difference = 7.4458015120
#   Difference = 8.3713437189
#   Difference = 7.9729088178
#   Difference = 8.3837779933
#   Difference = 8.7552965348
#   Difference = 8.5250508440
#   Difference = 8.1758321496
#   Difference = 8.6076821259
#   Difference = 8.6766725117
#   Difference = 8.7712401111
#   Difference = 8.0419248168
#   Difference = 8.4418977083
#   Difference = 8.5652910810
#   Difference = 8.2114218983
#   Difference = 8.5749170970
#   Difference = 8.2120660585
#   Difference = 8.6842057771
#   Difference = 8.5151582858
#   Difference = 8.3448307870
#   Difference = 8.8588167482
#   Difference = 8.4759304829
#   Difference = 8.2774886472
#   Difference = 8.2319918480
#   Difference = 8.8758921937
#   Difference = 8.4084594105
#   Difference = 8.1168084537
#   Difference = 8.3042532050
#   Difference = 8.4943704934
#   Difference = 8.0109721612
#   Difference = 8.5490042202
#   Difference = 8.2695867559
#   Difference = 8.2081860940
#   Difference = 8.2676357144
#   Difference = 8.1501232871
#   Difference = 7.9097745862
#   Difference = 8.2940044417
#   Difference = 8.8791575564
#   Difference = 8.2822221381
#   Difference = 8.5660253855
#   Difference = 8.3878895224
#   Difference = 8.5898399079
#   Difference = 8.4841936567
#   Difference = 8.2662838822
#   Difference = 8.8587552830
#   Difference = 8.1261217278
#   Difference = 8.8273210496
#   Difference = 8.3283307995
#   Difference = 8.9313571267
#   Difference = 8.6509952294
#   Difference = 8.2909935464
#   Difference = 8.3951429794
#   Difference = 8.3587996372
#   Difference = 8.5645356111
#   Difference = 8.0787039756
#   Difference = 8.5515090601
#   Difference = 8.3372611354
#   Difference = 8.3675006738
#   Difference = 8.4075043099
#   Difference = 8.1934191144
#   Difference = 8.2702383642
#   Difference = 8.2059350730
#   Difference = 8.3886376197
#   Difference = 8.4110280594
#   Difference = 7.7456765043
#   Difference = 8.3574438654
#   Difference = 8.6641044434
#   Difference = 8.6280130588
#   Difference = 8.3259915833
#   Difference = 8.0280610329
#   Difference = 8.6923038543
#   Difference = 7.9656450513
#   Difference = 8.5019700303
#   Difference = 8.3524791874
#   Difference = 8.3268906732
#   Difference = 8.4195728430
#   Difference = 8.4141820819
#   Difference = 8.3458742042
#   Difference = 8.2480095501
#   Difference = 8.0428871011
#   Difference = 8.7287507209
#   Difference = 8.7074637324
#   Difference = 8.3342430918
#   Difference = 8.6572454916
#   Difference = 8.1535290110
#   Difference = 8.2117391725
#   Difference = 8.0782856196
#   Difference = 8.0531560993
#   Difference = 8.3089709423
#   Difference = 8.1388960233
#   Difference = 8.5913564645
#   Difference = 8.4039670535
#   Difference = 8.4690823140
#   Difference = 8.2396823362
#   Difference = 8.5848348399
#   Difference = 8.3160299660
#   Difference = 8.3499904680
#   Difference = 7.9909939946
#   Difference = 8.4468621412
#   Difference = 8.4896260150
#   Difference = 8.2972973030
#   Difference = 8.2120471790
#   Difference = 9.0280868641
#   Difference = 8.1547800963
#   Difference = 8.6854814019
#   Difference = 7.7900317511
#   Difference = 8.2725444604
#   Difference = 8.6751637828
#   Difference = 8.2481546491
#   Difference = 8.0642933826
#   Difference = 8.2223938346
#   Difference = 8.3168437253
#   Difference = 8.2120394700
#   Difference = 8.3679828860
#   Difference = 8.3095140507
#   Difference = 8.4330348286
#   Difference = 8.5052340534
#   Difference = 8.2349675531
#   Difference = 8.5277562752
#   Difference = 8.4379472392
#   Difference = 8.2913436043
#   Difference = 8.3748067835
#   Difference = 8.3449278630
#   Difference = 8.5173622254
#   Difference = 8.5631052589
#   Difference = 8.8266735726
#   Difference = 8.2179600330
#   Difference = 8.5137574074
#   Difference = 7.9163895999
#   Difference = 8.4869768442
#   Difference = 8.1255577169
#   Difference = 8.3224327148
#   Difference = 8.2057444219
#   Difference = 7.9513184412
#   Difference = 8.2560473064
#   Difference = 8.1163967192
#   Difference = 8.4188615496
#   Difference = 8.1964786688
#   Difference = 8.0997953908
#   Difference = 8.4095399333
#   Difference = 8.2629322492
#   Difference = 8.2454047116
#   Difference = 8.8948175150
#   Difference = 8.0485151073
#   Difference = 8.4056531787
#   Difference = 8.1225791158
#   Difference = 8.4130986923
#   Difference = 8.4560558419
#   Difference = 6.1674421783
#   Difference = 6.3468736882
#   Difference = 5.8088760234
#   Difference = 6.2508723589
#   Difference = 6.2900198586
#   Difference = 6.2899047350
#   Difference = 6.2319113417
#   Difference = 6.5456022776
#   Difference = 6.7954374455
#   Difference = 6.0052697880
#   Difference = 6.9585251580
#   Difference = 5.7541811337
#   Difference = 6.9155904477
#   Difference = 6.4131647210
#   Difference = 6.3148274376
#   Difference = 6.1363774502
#   Difference = 6.1320383407
#   Difference = 6.4338586590
#   Difference = 6.4867578134
#   Difference = 6.2253886442
#   Difference = 6.5972137517
#   Difference = 6.4420045673
#   Difference = 6.6094525356
#   Difference = 6.4093514892
#   Difference = 5.7057063425
#   Difference = 6.2574706466
#   Difference = 6.6290697351
#   Difference = 6.2811897753
#   Difference = 6.2964833335
#   Difference = 6.2806809547
#   Difference = 6.8531244260
#   Difference = 6.2135866767
#   Difference = 6.7716951962
#   Difference = 6.3068812540
#   Difference = 6.2157661344
#   Difference = 6.9870204559
#   Difference = 5.9379163689
#   Difference = 6.2933616723
#   Difference = 6.0474048889
#   Difference = 6.5869775295
#   Difference = 6.3692499927
#   Difference = 6.5745388755
#   Difference = 6.2206531924
#   Difference = 6.4313505663
#   Difference = 6.7156200101
#   Difference = 6.4280574991
#   Difference = 6.8070015590
#   Difference = 6.6663153361
#   Difference = 7.0954453234
#   Difference = 6.5493825514
#   Difference = 6.8557573231
#   Difference = 6.3515144598
#   Difference = 5.8941007782
#   Difference = 6.2327580598
#   Difference = 6.2163146077
#   Difference = 6.6817240137
#   Difference = 6.6054463146
#   Difference = 6.8322595201
#   Difference = 6.3093333142
#   Difference = 6.3320165574
#   Difference = 6.6616027438
#   Difference = 6.4462407820
#   Difference = 6.3648370398
#   Difference = 5.4548960246
#   Difference = 6.7239050242
#   Difference = 7.3111334890
#   Difference = 6.1874067127
#   Difference = 6.5556471955
#   Difference = 5.8963341355
#   Difference = 6.2774777937
#   Difference = 6.4295186161
#   Difference = 6.2803748725
#   Difference = 6.4722867930
#   Difference = 6.4652764412
#   Difference = 6.3060163812
#   Difference = 6.1124413166
#   Difference = 6.5496762020
#   Difference = 6.6251576612
#   Difference = 6.4698053132
#   Difference = 6.5676764760
#   Difference = 6.4862256462
#   Difference = 6.5523923098
#   Difference = 6.3905208862
#   Difference = 6.5938316139
#   Difference = 6.1924336465
#   Difference = 6.6274118213
#   Difference = 6.4140453203
#   Difference = 6.6211517040
#   Difference = 6.3697199578
#   Difference = 6.4160997036
#   Difference = 6.3376884159
#   Difference = 6.9734905914
#   Difference = 6.2508149375
#   Difference = 5.9920258331
#   Difference = 6.7835079977
#   Difference = 6.5105387688
#   Difference = 6.4197772296
#   Difference = 5.9086667713
#   Difference = 6.5455439469
#   Difference = 6.0849077840
#   Difference = 6.5663988078
#   Difference = 5.6953339271
#   Difference = 6.2199128449
#   Difference = 6.2132210452
#   Difference = 6.1308726126
#   Difference = 6.2194189245
#   Difference = 5.9076459016
#   Difference = 6.1663936282
#   Difference = 6.2297612931
#   Difference = 6.2082361429
#   Difference = 6.6273619735
#   Difference = 6.2098250411
#   Difference = 6.3925590506
#   Difference = 6.9299626094
#   Difference = 6.4684608921
#   Difference = 6.5987249425
#   Difference = 6.4902151396
#   Difference = 6.7287056218
#   Difference = 6.0702456226
#   Difference = 6.5149671718
#   Difference = 6.6672743788
#   Difference = 5.7550534553
#   Difference = 7.0728440688
#   Difference = 6.3011808027
#   Difference = 6.5120430453
#   Difference = 6.3728669770
#   Difference = 6.7108541356
#   Difference = 6.5935352812
#   Difference = 6.6978354064
#   Difference = 6.6177666001
#   Difference = 6.3936992096
#   Difference = 6.8815371984
#   Difference = 6.3069295000
#   Difference = 6.3898572921
#   Difference = 5.9652657282
#   Difference = 6.9337482529
#   Difference = 6.2439230485
#   Difference = 6.2148724365
#   Difference = 6.2660370188
#   Difference = 6.1925569988
#   Difference = 6.1362844281
#   Difference = 6.0067134960
#   Difference = 6.3046005430
#   Difference = 5.8549580145
#   Difference = 6.7671294213
#   Difference = 5.8940030464
#   Difference = 5.5200318641
#   Difference = 6.5026037000
#   Difference = 6.0539733343
#   Difference = 6.4304868256
#   Difference = 6.3943574673
#   Difference = 6.3880232090
#   Difference = 6.3321945098
#   Difference = 6.5515500467
#   Difference = 6.3079542948
#   Difference = 6.3697457536
#   Difference = 6.3927600301
#   Difference = 6.6485731211
#   Difference = 6.4725328646
#   Difference = 6.6373291741
#   Difference = 6.6332085477
#   Difference = 6.2195308559
#   Difference = 6.5179100791
#   Difference = 7.1292278912
#   Difference = 6.5121121826
#   Difference = 6.5700639724
#   Difference = 6.2147285897
#   Difference = 6.3186348487
#   Difference = 6.4932330617
#   Difference = 6.5098079607
#   Difference = 7.0514872670
#   Difference = 6.1882588381
#   Difference = 6.6726020480
#   Difference = 6.1944374202
#   Difference = 6.1683674724
#   Difference = 6.5042004111
#   Difference = 6.6203414614
#   Difference = 5.9647707876
#   Difference = 6.4691769064
#   Difference = 6.2589005406
#   Difference = 6.8707852022
#   Difference = 6.3986693796
#   Difference = 6.4928941499
#   Difference = 6.1743295133
#   Difference = 6.1801799887
#   Difference = 6.5962710790
#   Difference = 6.1329854687
#   Difference = 6.7441026824
#   Difference = 6.1136121998
#   Difference = 6.4570716090
#   Difference = 6.5234398215
#   Difference = 6.1402210259
#   Difference = 6.0468742215
#   Difference = 6.6346410881
#   Difference = 6.7292500146
#   Difference = 6.9441295288
#   Difference = 6.3516349109
#   Difference = 6.5479249913
#   Difference = 6.0612273709
#   Difference = 6.6082622839
#   Difference = 6.3362571397
#   Difference = 6.2039993310
#   Difference = 6.5103460268
#   Difference = 6.5259269357
#   Difference = 6.6271858884
#   Difference = 6.6346572456
#   Difference = 6.8156189974
#   Difference = 6.5484452943
#   Difference = 5.9878680910
#   Difference = 6.4083223142
#   Difference = 6.0193524724
#   Difference = 6.0015615653
#   Difference = 5.7600046650
#   Difference = 6.2935445002
#   Difference = 6.3593599190
#   Difference = 6.2921555780
#   Difference = 6.2142562751
#   Difference = 6.3737234986
#   Difference = 6.5362746909
#   Difference = 5.9320837998
#   Difference = 6.1070610724
#   Difference = 5.8334478708
#   Difference = 6.2798234143
#   Difference = 6.1130528228
#   Difference = 6.2374559222
#   Difference = 6.3893115790
#   Difference = 6.4379029284
#   Difference = 6.9544775385
#   Difference = 6.1449854178
#   Difference = 6.5146095545
#   Difference = 6.6116085467
#   Difference = 6.1743134554
#   Difference = 6.2648122751
#   Difference = 6.4504323238
#   Difference = 6.8907930869
#   Difference = 6.3924152562
#   Difference = 6.3499530216
#   Difference = 6.7677556729
#   Difference = 6.4502805621
#   Difference = 6.4075765254
#   Difference = 6.3550368977
#   Difference = 6.3347481242
#   Difference = 6.0569254319
#   Difference = 6.4056341024
#   Difference = 6.3049239360
#   Difference = 6.2796361499
#   Difference = 6.4126494010
#   Difference = 6.4384887804
#   Difference = 6.1569936044
#   Difference = 6.5963330970
#   Difference = 6.1752021763
#   Difference = 5.9489522068
#   Difference = 6.2954329309
#   Difference = 6.9091274915
#   Difference = 6.1151214669
#   Difference = 6.5122599403
#   Difference = 6.8577315391
#   Difference = 6.6630322994
#   Difference = 6.5489389584
#   Difference = 6.5117150695
#   Difference = 6.2242761162
#   Difference = 6.3439357657
#   Difference = 6.3214095437
#   Difference = 6.2455448525
#   Difference = 6.1706801909
#   Difference = 6.4067103520
#   Difference = 6.6483245209
#   Difference = 6.5188840030
#   Difference = 6.4832330996
#   Difference = 6.1569960113
#   Difference = 6.7804123590
#   Difference = 6.5560314394
#   Difference = 6.2324920795
#   Difference = 6.4456308107
#   Difference = 7.0283217777
#   Difference = 6.3802302535
#   Difference = 6.9570507771
#   Difference = 5.8521037559
#   Difference = 6.5448162902
#   Difference = 6.3728007301
#   Difference = 6.3220411373
#   Difference = 6.4106794144
#   Difference = 6.2525645573
#   Difference = 5.9672129468
#   Difference = 6.7347597423
#   Difference = 6.9564595016
#   Difference = 6.3972375975
#   Difference = 5.9726158941
#   Difference = 7.1748781674
#   Difference = 6.0156704449
#   Difference = 6.0399670833
#   Difference = 6.6354798286
#   Difference = 6.4234042603
#   Difference = 5.9725947532
#   Difference = 6.3956819039
#   Difference = 6.1113773880
#   Difference = 6.7679193150
#   Difference = 5.9578354436
#   Difference = 6.2005864627
#   Difference = 6.1966520278
#   Difference = 4.3371594107
#   Difference = 4.7495363883
#   Difference = 4.1083558881
#   Difference = 4.1909575060
#   Difference = 4.3597290816
#   Difference = 4.1565697651
#   Difference = 4.3781717957
#   Difference = 4.3967458539
#   Difference = 4.4963297571
#   Difference = 4.3583524552
#   Difference = 4.5947594825
#   Difference = 4.6783383542
#   Difference = 4.4324706720
#   Difference = 4.2880785090
#   Difference = 4.3986233791
#   Difference = 4.2261320111
#   Difference = 4.5743057820
#   Difference = 4.8981288483
#   Difference = 4.1117507660
#   Difference = 4.3146715963
#   Difference = 4.8276742181
#   Difference = 4.3929348509
#   Difference = 5.1911743916
#   Difference = 4.2517349357
#   Difference = 5.1502392455
#   Difference = 4.2928839910
#   Difference = 4.5814692246
#   Difference = 4.3328185951
#   Difference = 4.1168620467
#   Difference = 4.0806274540
#   Difference = 4.9924758335
#   Difference = 4.2363505142
#   Difference = 4.4500906494
#   Difference = 4.5350543062
#   Difference = 4.8976641674
#   Difference = 4.3862157248
#   Difference = 4.0138235729
#   Difference = 3.9790084630
#   Difference = 4.1927831607
#   Difference = 4.2616879752
#   Difference = 4.5145299293
#   Difference = 4.2349774812
#   Difference = 4.4336312055
#   Difference = 4.1299064710
#   Difference = 4.4597589602
#   Difference = 4.4504676100
#   Difference = 4.7951865317
#   Difference = 4.1701326951
#   Difference = 4.4149649304
#   Difference = 4.6201795647
#   Difference = 4.6990698153
#   Difference = 4.7113963651
#   Difference = 3.9088810623
#   Difference = 4.5411212625
#   Difference = 4.1786371024
#   Difference = 4.7321440217
#   Difference = 3.8688419503
#   Difference = 4.1615811549
#   Difference = 4.7475326758
#   Difference = 4.5859307635
#   Difference = 4.1570799417
#   Difference = 4.0680483666
#   Difference = 4.5379229467
#   Difference = 4.2363545362
#   Difference = 4.7119909054
#   Difference = 4.4508310819
#   Difference = 4.8505367633
#   Difference = 4.1989012946
#   Difference = 4.6203578735
#   Difference = 4.3462812988
#   Difference = 4.0559556581
#   Difference = 4.4134195183
#   Difference = 4.7928376881
#   Difference = 4.2491930310
#   Difference = 4.6356130571
#   Difference = 3.7000790581
#   Difference = 4.6673082251
#   Difference = 4.6270348456
#   Difference = 3.7176340022
#   Difference = 4.9107166405
#   Difference = 4.5402689644
#   Difference = 4.2020532691
#   Difference = 2.8375057358
#   Difference = 4.6147394021
#   Difference = 4.0675257151
#   Difference = 4.0938585854
#   Difference = 4.9601892027
#   Difference = 4.7402825145
#   Difference = 4.4795746841
#   Difference = 4.2534338186
#   Difference = 4.1905954780
#   Difference = 4.7569478562
#   Difference = 4.5663008742
#   Difference = 4.3214510609
#   Difference = 4.3502565728
#   Difference = 4.3204610023
#   Difference = 4.7141098587
#   Difference = 4.3199299240
#   Difference = 4.4548352764
#   Difference = 4.1622452052
#   Difference = 4.5782375059
#   Difference = 4.6534649318
#   Difference = 4.2019856305
#   Difference = 4.2140373353
#   Difference = 4.1764486165
#   Difference = 3.5342631473
#   Difference = 4.2906501281
#   Difference = 4.6872463058
#   Difference = 4.2715958570
#   Difference = 4.2955124811
#   Difference = 4.3076496337
#   Difference = 4.6500907197
#   Difference = 4.7888839983
#   Difference = 4.3960392296
#   Difference = 4.7772698632
#   Difference = 3.9409805339
#   Difference = 4.4737506903
#   Difference = 4.7141864913
#   Difference = 4.0120823115
#   Difference = 3.9201718539
#   Difference = 4.1414875151
#   Difference = 4.1937427548
#   Difference = 4.5183632763
#   Difference = 4.9429343165
#   Difference = 3.9641508053
#   Difference = 4.3745191563
#   Difference = 4.5124524709
#   Difference = 4.3091219956
#   Difference = 4.8692666961
#   Difference = 4.4170849915
#   Difference = 4.5164680907
#   Difference = 4.7392852214
#   Difference = 4.5920225808
#   Difference = 4.0903410353
#   Difference = 4.1355541857
#   Difference = 4.2928831304
#   Difference = 4.4336382888
#   Difference = 4.4816839407
#   Difference = 3.8546601634
#   Difference = 4.0195156737
#   Difference = 4.5001592421
#   Difference = 4.5914522042
#   Difference = 4.5698505553
#   Difference = 4.3631473622
#   Difference = 3.9715802835
#   Difference = 4.5398923095
#   Difference = 4.7298908549
#   Difference = 4.2954116676
#   Difference = 4.4887857542
#   Difference = 4.3719111527
#   Difference = 4.3266923442
#   Difference = 3.8922630241
#   Difference = 4.2537159411
#   Difference = 4.2100285841
#   Difference = 4.3940395553
#   Difference = 4.7546206592
#   Difference = 4.8494228083
#   Difference = 3.8462200158
#   Difference = 4.6589012613
#   Difference = 4.5150956839
#   Difference = 4.1417511790
#   Difference = 4.9583662133
#   Difference = 4.3275006466
#   Difference = 4.1724213127
#   Difference = 4.1732577463
#   Difference = 4.1382315539
#   Difference = 4.6876277452
#   Difference = 4.0894251491
#   Difference = 4.1349480768
#   Difference = 4.7477274721
#   Difference = 4.2678031555
#   Difference = 4.7108826113
#   Difference = 3.9475218326
#   Difference = 4.3793237968
#   Difference = 4.0206493574
#   Difference = 3.9752648502
#   Difference = 4.4116208179
#   Difference = 4.3498464517
#   Difference = 4.2372943216
#   Difference = 4.6197406069
#   Difference = 4.5257658759
#   Difference = 4.6995677351
#   Difference = 3.7885222905
#   Difference = 4.5597960414
#   Difference = 4.0535466524
#   Difference = 4.2135410634
#   Difference = 4.0274820603
#   Difference = 4.4363160903
#   Difference = 4.5747624708
#   Difference = 4.2413643020
#   Difference = 4.3814096303
#   Difference = 4.4297077620
#   Difference = 4.0558933084
#   Difference = 4.3527391779
#   Difference = 4.8673302580
#   Difference = 4.9318794062
#   Difference = 4.1422056944
#   Difference = 4.7145050798
#   Difference = 4.4474412564
#   Difference = 3.6757142939
#   Difference = 4.2930920155
#   Difference = 4.1519149267
#   Difference = 4.3169184985
#   Difference = 4.8333317495
#   Difference = 4.3983200662
#   Difference = 4.6394787371
#   Difference = 4.0363530818
#   Difference = 3.8489578090
#   Difference = 4.3929583675
#   Difference = 3.8748632906
#   Difference = 4.4775302173
#   Difference = 4.3695064270
#   Difference = 4.3714133132
#   Difference = 3.8303798788
#   Difference = 4.6022310187
#   Difference = 4.4166708622
#   Difference = 4.1960810432
#   Difference = 4.1385715290
#   Difference = 4.3508500459
#   Difference = 4.4577421528
#   Difference = 4.5327896899
#   Difference = 4.6698824437
#   Difference = 4.4108998966
#   Difference = 4.2461468402
#   Difference = 4.6209484591
#   Difference = 3.1553077550
#   Difference = 5.0307176098
#   Difference = 4.0754184614
#   Difference = 4.5562745403
#   Difference = 4.6520847304
#   Difference = 4.0122200817
#   Difference = 4.0322402678
#   Difference = 4.7819067851
#   Difference = 4.2026568360
#   Difference = 3.8917434774
#   Difference = 4.0416654720
#   Difference = 4.0168118603
#   Difference = 4.1971014749
#   Difference = 4.3322172993
#   Difference = 4.3937615740
#   Difference = 4.1444251199
#   Difference = 4.3284107357
#   Difference = 4.3810746396
#   Difference = 4.5882790858
#   Difference = 4.1620924564
#   Difference = 4.2547413785
#   Difference = 4.0215205392
#   Difference = 4.4775715054
#   Difference = 3.7091402019
#   Difference = 4.3700587816
#   Difference = 4.0319287105
#   Difference = 4.4783456177
#   Difference = 4.2966213686
#   Difference = 4.5654886002
#   Difference = 3.9871964207
#   Difference = 4.5825231046
#   Difference = 4.3751394721
#   Difference = 4.5696473358
#   Difference = 4.6261631323
#   Difference = 4.2153230222
#   Difference = 4.6575436046
#   Difference = 4.1921750917
#   Difference = 4.3922288746
#   Difference = 3.8370952045
#   Difference = 4.3277109435
#   Difference = 4.7169217899
#   Difference = 4.1367785973
#   Difference = 4.3943788206
#   Difference = 3.5374780063
#   Difference = 4.2574458794
#   Difference = 4.2275301740
#   Difference = 4.1405303553
#   Difference = 4.6382563894
#   Difference = 3.8924527282
#   Difference = 4.8971646053
#   Difference = 4.3194725204
#   Difference = 4.1782249600
#   Difference = 4.0310370113
#   Difference = 4.2208148789
#   Difference = 4.3359503331
#   Difference = 4.7810113486
#   Difference = 4.2117058517
#   Difference = 4.6979083639
#   Difference = 4.6295783209
#   Difference = 4.3740448834
#   Difference = 4.4208730124
#   Difference = 3.7401204626
#   Difference = 4.4784626236
#   Difference = 4.9530096359
#   Difference = 4.4580534377
#   Difference = 4.3746717696
#   Difference = 4.2837036415
#   Difference = 4.4497326176
#   Difference = 4.5400639982
#   Difference = 4.3684302916
#   Difference = 4.0405829974
#   Difference = 4.5280452140
#   Difference = 4.3514702442
#   Difference = 4.0112120411
#   Difference = 4.4813454231
#   Difference = 2.5564570375
#   Difference = 1.8544545353
#   Difference = 2.6181642943
#   Difference = 2.1797327902
#   Difference = 2.0446844709
#   Difference = 2.7004577858
#   Difference = 2.4975960966
#   Difference = 2.6268509811
#   Difference = 2.3787016326
#   Difference = 2.3093921077
#   Difference = 2.9558122972
#   Difference = 2.8963803984
#   Difference = 2.8999244890
#   Difference = 2.1611441473
#   Difference = 2.7115018552
#   Difference = 2.1271956417
#   Difference = 1.8417209484
#   Difference = 2.6342891128
#   Difference = 2.6556158714
#   Difference = 1.5843606251
#   Difference = 2.7586527566
#   Difference = 2.4564245061
#   Difference = 2.6210558564
#   Difference = 2.1900024070
#   Difference = 1.8579133121
#   Difference = 2.5637309862
#   Difference = 2.7159384747
#   Difference = 2.1523876094
#   Difference = 2.4076994076
#   Difference = 2.5519157330
#   Difference = 2.5278344952
#   Difference = 1.7202569649
#   Difference = 2.1307511528
#   Difference = 2.0821792005
#   Difference = 2.8357649360
#   Difference = 2.9336405009
#   Difference = 2.4844480590
#   Difference = 2.3869016089
#   Difference = 1.9598700282
#   Difference = 2.4112887632
#   Difference = 2.4490489300
#   Difference = 2.2384219695
#   Difference = 2.9230840327
#   Difference = 2.0511189629
#   Difference = 2.2167045440
#   Difference = 2.4993954463
#   Difference = 2.7237019815
#   Difference = 2.7995361468
#   Difference = 2.5733963516
#   Difference = 2.6786503636
#   Difference = 2.0539882528
#   Difference = 2.3344780034
#   Difference = 2.1155704144
#   Difference = 2.5475448403
#   Difference = 2.1992097404
#   Difference = 2.7585487369
#   Difference = 2.0478257931
#   Difference = 2.1340130717
#   Difference = 2.4185119135
#   Difference = 2.7680678906
#   Difference = 2.3727810241
#   Difference = 2.2169547902
#   Difference = 2.2398308779
#   Difference = 1.9530034849
#   Difference = 2.7314269400
#   Difference = 2.1519204468
#   Difference = 2.4654109536
#   Difference = 2.6304168270
#   Difference = 2.6960462697
#   Difference = 2.0994915907
#   Difference = 3.0155476494
#   Difference = 1.4141594114
#   Difference = 2.4914148895
#   Difference = 2.6233051885
#   Difference = 2.7005613343
#   Difference = 2.6024980411
#   Difference = 3.3163614002
#   Difference = 2.3792403784
#   Difference = 2.4890594406
#   Difference = 2.4404696988
#   Difference = 2.4642276607
#   Difference = 2.9883474779
#   Difference = 2.1112212724
#   Difference = 2.0722877608
#   Difference = 1.9913616294
#   Difference = 1.5799360702
#   Difference = 1.6150101626
#   Difference = 2.4848695701
#   Difference = 2.5497265993
#   Difference = 2.5144462058
#   Difference = 2.3761857401
#   Difference = 2.1770624111
#   Difference = 2.3800185959
#   Difference = 2.1109315896
#   Difference = 3.1734683799
#   Difference = 2.5306276981
#   Difference = 2.3778862739
#   Difference = 1.9802872175
#   Difference = 2.2691195415
#   Difference = 2.1885583232
#   Difference = 1.8791609201
#   Difference = 2.6917263038
#   Difference = 1.9589862692
#   Difference = 2.3003409754
#   Difference = 2.4361936570
#   Difference = 2.1206908894
#   Difference = 1.3342845354
#   Difference = 2.0589809181
#   Difference = 2.5566582800
#   Difference = 2.5003627929
#   Difference = 2.4615343126
#   Difference = 2.5149280902
#   Difference = 2.3993965024
#   Difference = 1.6822280943
#   Difference = 2.5754061075
#   Difference = 2.7360119266
#   Difference = 2.0976220917
#   Difference = 2.4553707711
#   Difference = 2.4978141094
#   Difference = 2.1196602272
#   Difference = 2.7570984876
#   Difference = 2.0893186222
#   Difference = 2.5610369842
#   Difference = 2.5744101386
#   Difference = 2.2059016871
#   Difference = 2.7389515396
#   Difference = 2.0240039156
#   Difference = 2.3943876244
#   Difference = 2.7223406539
#   Difference = 2.0657351867
#   Difference = 2.1209361944
#   Difference = 2.1854528719
#   Difference = 1.9701076033
#   Difference = 2.4219826353
#   Difference = 2.5406689651
#   Difference = 2.6105781923
#   Difference = 2.3414701305
#   Difference = 2.2606201849
#   Difference = 2.0682196734
#   Difference = 3.0758998630
#   Difference = 2.6586939936
#   Difference = 2.5205708004
#   Difference = 2.7195613567
#   Difference = 2.7394206284
#   Difference = 2.0478973546
#   Difference = 1.9723803301
#   Difference = 2.6095826657
#   Difference = 2.4799027373
#   Difference = 2.2415174081
#   Difference = 1.9929761926
#   Difference = 2.4602855754
#   Difference = 2.8749870850
#   Difference = 2.6021046507
#   Difference = 2.4797957736
#   Difference = 2.2498228980
#   Difference = 2.6715906792
#   Difference = 2.2384810786
#   Difference = 2.4934421361
#   Difference = 2.1224873861
#   Difference = 2.5810296130
#   Difference = 2.6053538472
#   Difference = 2.3435423025
#   Difference = 2.3321022121
#   Difference = 2.6093147921
#   Difference = 2.2107478903
#   Difference = 2.4564762314
#   Difference = 2.7688463592
#   Difference = 2.0155980027
#   Difference = 3.1224359183
#   Difference = 2.3921231713
#   Difference = 2.9415334816
#   Difference = 2.1561503852
#   Difference = 2.1657832140
#   Difference = 2.1760792266
#   Difference = 2.4715288832
#   Difference = 2.1378467679
#   Difference = 1.8307332986
#   Difference = 2.9000845520
#   Difference = 2.6533381098
#   Difference = 1.9180373873
#   Difference = 1.9741291469
#   Difference = 1.6994090895
#   Difference = 2.2295440796
#   Difference = 2.4825724192
#   Difference = 2.0795724785
#   Difference = 2.5582122691
#   Difference = 1.9347002312
#   Difference = 2.5250231003
#   Difference = 2.3949116448
#   Difference = 2.2485879159
#   Difference = 2.6388250136
#   Difference = 2.2136834586
#   Difference = 2.4555781602
#   Difference = 2.3295122720
#   Difference = 2.6493777677
#   Difference = 2.9999600989
#   Difference = 1.8532193764
#   Difference = 1.9999871005
#   Difference = 2.6354317580
#   Difference = 2.4788930773
#   Difference = 2.5781273334
#   Difference = 1.8366093072
#   Difference = 2.4878336999
#   Difference = 2.3854626929
#   Difference = 2.7607499353
#   Difference = 2.1004880375
#   Difference = 2.2649827883
#   Difference = 2.6379249999
#   Difference = 2.4710243614
#   Difference = 2.2754173689
#   Difference = 2.2595358561
#   Difference = 2.5573837764
#   Difference = 2.7192325195
#   Difference = 2.4302518313
#   Difference = 2.6746870188
#   Difference = 1.7520589961
#   Difference = 2.2452029805
#   Difference = 2.2845608516
#   Difference = 2.1980174753
#   Difference = 2.3950825180
#   Difference = 1.9429472584
#   Difference = 2.3843939146
#   Difference = 2.4698439712
#   Difference = 1.6126961627
#   Difference = 2.2191160397
#   Difference = 2.8179382174
#   Difference = 2.4190593782
#   Difference = 1.9324428949
#   Difference = 2.1420021450
#   Difference = 2.5161496023
#   Difference = 1.9251010707
#   Difference = 1.7643808534
#   Difference = 2.2753674852
#   Difference = 2.6653719053
#   Difference = 2.5509154231
#   Difference = 2.0835005166
#   Difference = 2.5179640643
#   Difference = 2.8771121038
#   Difference = 2.6432325058
#   Difference = 2.3592140400
#   Difference = 3.1379789385
#   Difference = 2.2193218306
#   Difference = 1.8719885436
#   Difference = 2.2582038301
#   Difference = 2.5932642697
#   Difference = 1.7031885433
#   Difference = 2.3735323208
#   Difference = 2.4168892922
#   Difference = 2.3692066415
#   Difference = 2.5468770505
#   Difference = 2.3889891522
#   Difference = 1.9319528219
#   Difference = 2.3429005285
#   Difference = 2.1750711550
#   Difference = 2.3585848320
#   Difference = 2.4152743198
#   Difference = 2.3831957233
#   Difference = 1.9793983014
#   Difference = 2.2209959829
#   Difference = 2.8893881760
#   Difference = 2.4913630410
#   Difference = 2.8426603431
#   Difference = 2.0826766766
#   Difference = 2.3448205814
#   Difference = 2.0045059996
#   Difference = 2.4125216650
#   Difference = 2.5031714243
#   Difference = 2.8386986958
#   Difference = 2.0562856651
#   Difference = 2.3695241143
#   Difference = 2.3378554782
#   Difference = 2.3274590047
#   Difference = 2.8197954435
#   Difference = 2.0959392185
#   Difference = 2.8158589078
#   Difference = 3.1298125628
#   Difference = 2.6198746826
#   Difference = 2.0922090216
#   Difference = 1.9530460962
#   Difference = 3.2187334581
#   Difference = 2.5311714690
#   Difference = 2.4194645543
#   Difference = 2.0914274557
#   Difference = 2.0959773186
#   Difference = 2.4623931741
#   Difference = 2.2918967377
#   Difference = 3.1481737848
#   Difference = 2.8589860400
#   Difference = 2.1829122823
#   Difference = 2.5438653329
#   Difference = 2.5761416933
#   Difference = 2.1020790211
#   Difference = 2.8363798847
#   Difference = 2.5750198293
#   Difference = 1.9796287376
#   Difference = 2.6350835845
#   Difference = 2.0565071746
#   Difference = 2.6927129754
#   Difference = 1.8403273066
#   Difference = 2.8921400209
#   Difference = 0.3409823204
#   Difference = 0.8028551461
#   Difference = 0.7233065963
#   Difference = 0.3598161895
#   Difference = -0.3545454053
#   Difference = 0.6051753030
#   Difference = 0.6383828946
#   Difference = 0.3464535966
#   Difference = 0.3015455112
#   Difference = 0.2979104090
#   Difference = 0.4909966397
#   Difference = -0.1731430036
#   Difference = 0.2550069756
#   Difference = 0.8634297240
#   Difference = 0.0737258670
#   Difference = 0.5000208431
#   Difference = 0.9309885542
#   Difference = 0.4321403811
#   Difference = 0.3219075043
#   Difference = 0.0211762120
#   Difference = 0.3874845482
#   Difference = 0.3428497182
#   Difference = 0.6144601084
#   Difference = -0.0016768253
#   Difference = 0.3369500394
#   Difference = 0.4162667713
#   Difference = 0.4259494145
#   Difference = 0.4334262907
#   Difference = 0.8200496266
#   Difference = 0.4598922637
#   Difference = -0.0281380075
#   Difference = 0.4537596762
#   Difference = 0.2408841031
#   Difference = 0.7175981250
#   Difference = 0.3937497712
#   Difference = 0.4041016428
#   Difference = -0.2768372631
#   Difference = 0.1187896462
#   Difference = 0.2350449869
#   Difference = 0.6207490426
#   Difference = 0.2714736850
#   Difference = 0.1743911389
#   Difference = 0.8955567391
#   Difference = 0.0340218844
#   Difference = 0.6131502071
#   Difference = 0.6393587224
#   Difference = 0.1990301630
#   Difference = 0.7544402751
#   Difference = 0.8214466922
#   Difference = 0.6196074245
#   Difference = 0.4119692956
#   Difference = -0.3819066435
#   Difference = 1.1222316118
#   Difference = -0.5333004003
#   Difference = 0.9327419035
#   Difference = 0.6777652439
#   Difference = 0.9806818335
#   Difference = 0.2776571092
#   Difference = 0.7970205566
#   Difference = 0.6700460273
#   Difference = 0.7597236433
#   Difference = 0.6988822633
#   Difference = 0.0963547198
#   Difference = 0.7003656188
#   Difference = 0.2375393792
#   Difference = 0.4546291824
#   Difference = 0.5369001692
#   Difference = 0.7642939323
#   Difference = 0.2574783176
#   Difference = 0.6415076586
#   Difference = 0.8262125663
#   Difference = -0.0054739818
#   Difference = -0.0831897829
#   Difference = 0.2817548764
#   Difference = 0.1920853444
#   Difference = -0.3621485196
#   Difference = 0.4587218925
#   Difference = 0.9200535829
#   Difference = 0.4173679761
#   Difference = 0.3817707434
#   Difference = 0.2023956450
#   Difference = 0.7582614138
#   Difference = 0.5800761870
#   Difference = 0.7971232749
#   Difference = 0.1015993797
#   Difference = 0.2926139987
#   Difference = 0.5369926080
#   Difference = 0.1005449997
#   Difference = -0.0184003715
#   Difference = -0.0244758985
#   Difference = -0.2362315929
#   Difference = 0.8602317728
#   Difference = 0.4124098639
#   Difference = 0.3013913017
#   Difference = 0.3329825651
#   Difference = 0.4937700699
#   Difference = 0.9463895687
#   Difference = 0.1593277064
#   Difference = 0.6436999952
#   Difference = 0.4988076732
#   Difference = 0.8985990245
#   Difference = -0.1228604265
#   Difference = -0.0667674689
#   Difference = 0.3402301360
#   Difference = 0.6042073510
#   Difference = 1.2010782328
#   Difference = 0.7573830008
#   Difference = 0.4127001039
#   Difference = 0.3372886662
#   Difference = 0.2514414920
#   Difference = -0.3814769091
#   Difference = 0.7999773906
#   Difference = 0.6171265026
#   Difference = 0.3814561099
#   Difference = 0.4637092618
#   Difference = 0.2582822296
#   Difference = 0.1142819121
#   Difference = 0.3315340854
#   Difference = 0.4541227029
#   Difference = 0.3732808272
#   Difference = 0.3755248405
#   Difference = -0.2624400216
#   Difference = 0.7975358666
#   Difference = 0.1343084612
#   Difference = 0.1835904708
#   Difference = 0.4456046137
#   Difference = 0.3951763344
#   Difference = 0.3159761492
#   Difference = 0.3726400148
#   Difference = 0.4191731223
#   Difference = 0.1247760817
#   Difference = 0.3265650817
#   Difference = 0.6755940113
#   Difference = 0.1012600509
#   Difference = -0.0217810667
#   Difference = 0.2016907913
#   Difference = 0.3393574812
#   Difference = 0.1806421028
#   Difference = 0.9234794600
#   Difference = -0.0778320135
#   Difference = 0.0009576579
#   Difference = 0.4164552162
#   Difference = 0.1126236519
#   Difference = 0.4123026116
#   Difference = -0.0996282423
#   Difference = 0.5139967472
#   Difference = -0.3198468953
#   Difference = -0.3192922443
#   Difference = 0.6739097086
#   Difference = 0.5330551845
#   Difference = 0.5564103779
#   Difference = 0.4430607650
#   Difference = -0.2018637803
#   Difference = -0.2043545552
#   Difference = 0.0811037183
#   Difference = 0.2182598259
#   Difference = 0.0115987461
#   Difference = 0.5646220961
#   Difference = -0.4821653860
#   Difference = -0.1053224343
#   Difference = 0.4581689623
#   Difference = 0.7254646675
#   Difference = 0.2774730330
#   Difference = -0.1587864267
#   Difference = 0.4185943525
#   Difference = 0.5916381349
#   Difference = 0.6402959955
#   Difference = 0.0044524509
#   Difference = 0.6911363753
#   Difference = 0.5755070326
#   Difference = 1.4771372887
#   Difference = 1.1445700605
#   Difference = 0.1569308082
#   Difference = -0.2372922574
#   Difference = 0.4345760030
#   Difference = 0.6157982433
#   Difference = 0.2451777654
#   Difference = 0.0831546934
#   Difference = 0.2158636971
#   Difference = 0.0161871506
#   Difference = 0.6153349585
#   Difference = 0.0013086271
#   Difference = 0.3798954091
#   Difference = 0.6118195164
#   Difference = -0.2364633441
#   Difference = -0.0812114740
#   Difference = 0.3128050609
#   Difference = 0.1345253073
#   Difference = 0.6396530655
#   Difference = 0.5618664162
#   Difference = 0.2668021299
#   Difference = 0.5004341530
#   Difference = 0.4576085769
#   Difference = 0.1709988006
#   Difference = 1.0239577696
#   Difference = 0.2252214274
#   Difference = 0.6765148963
#   Difference = 0.5416892668
#   Difference = 0.2438696871
#   Difference = 1.2640941185
# ...
#   Difference = -5.9011859461
#   Difference = -5.6700543201
#   Difference = -5.7091826069
#   Difference = -5.5923300377
#   Difference = -6.2182890925
#   Difference = -5.5157513227
#   Difference = -6.0617622144
#   Difference = -5.8715182208
#   Difference = -5.3936058035
#   Difference = -5.4751070534
#   Difference = -5.4604032358
#   Difference = -5.6975742499
#   Difference = -5.6548560151
#   Difference = -5.2540594925
#   Difference = -5.4310618796
#   Difference = -6.0336849410
#   Difference = -5.5581423043
#   Difference = -5.5639705304
#   Difference = -5.4209027774
#   Difference = -5.7983109771
#   Difference = -5.7153358089
#   Difference = -5.6157128438
#   Difference = -5.4146547191
#   Difference = -5.7756082837
#   Difference = -5.6605444557
#   Difference = -5.7756005572
#   Difference = -5.3960559690
#   Difference = -5.7148986746
#   Difference = -5.1540501526
#   Difference = -5.8945307712
#   Difference = -5.5822626885
#   Difference = -5.8308796552
#   Difference = -5.2542354906
#   Difference = -5.5824133898
#   Difference = -5.8109071718
#   Difference = -5.6369384777
#   Difference = -5.5364417262
#   Difference = -5.3506043602
#   Difference = -5.3227031654
#   Difference = -5.5604634026
#   Difference = -5.4497821201
#   Difference = -5.2125970773
#   Difference = -5.8595362568
#   Difference = -5.6776629355
#   Difference = -5.4926774081
#   Difference = -5.4958731098
#   Difference = -5.6972265035
#   Difference = -5.4517410589
#   Difference = -5.5183864973
#   Difference = -5.3940026581
#   Difference = -6.0260811928
#   Difference = -5.3569342471
#   Difference = -5.3358264666
#   Difference = -5.7686937520
#   Difference = -5.3192428944
#   Difference = -5.7808792839
#   Difference = -5.5194853932
#   Difference = -6.1766376426
#   Difference = -5.4956218944
#   Difference = -5.9348372773
#   Difference = -5.7129679469
#   Difference = -5.5123992303
#   Difference = -5.7849487852
#   Difference = -5.7195128334
#   Difference = -5.7394058135
#   Difference = -5.8418660261
#   Difference = -5.6960540425
#   Difference = -5.4508679791
#   Difference = -6.3199136123
#   Difference = -5.6359967981
#   Difference = -5.6624243117
#   Difference = -5.9928687645
#   Difference = -5.6174014410
#   Difference = -5.5928168864
#   Difference = -5.8107362880
#   Difference = -5.5725656352
#   Difference = -5.6524941316
#   Difference = -5.0974389714
#   Difference = -6.1324223837
#   Difference = -6.1133755253
#   Difference = -5.6164374419
#   Difference = -5.1606910521
#   Difference = -5.3751522912
#   Difference = -5.7343575116
#   Difference = -5.8602367528
#   Difference = -5.3964181326
#   Difference = -5.4194894428
#   Difference = -5.7823296595
#   Difference = -5.8794358007
#   Difference = -5.4074675153
#   Difference = -5.4989576968
#   Difference = -5.5701357497
#   Difference = -5.7933937846
#   Difference = -5.5805060004
#   Difference = -6.0201288462
#   Difference = -5.6577932967
#   Difference = -5.6353718119
#   Difference = -5.8589285912
#   Difference = -5.8122578713
#   Difference = -5.7427864637
#   Difference = -5.8909522949
#   Difference = -5.4166647081
#   Difference = -5.7535170828
#   Difference = -5.7299528809
#   Difference = -5.8967424345
#   Difference = -5.3308896737
#   Difference = -5.3530387195
#   Difference = -5.4754124566
#   Difference = -5.4969077500
#   Difference = -5.4869879209
#   Difference = -5.6197076627
#   Difference = -6.0332329166
#   Difference = -5.3618189872
#   Difference = -6.0163434369
#   Difference = -6.0207032646
#   Difference = -5.8300737648
#   Difference = -5.2691176139
#   Difference = -5.7422340877
#   Difference = -5.9720896010
#   Difference = -5.5420526695
#   Difference = -6.1133453106
#   Difference = -5.7364377217
#   Difference = -5.5144715027
#   Difference = -5.6177016957
#   Difference = -5.8504850682
#   Difference = -5.6951239678
#   Difference = -5.2736624678
#   Difference = -5.3835971940
#   Difference = -5.7593307743
#   Difference = -5.6520844167
#   Difference = -5.7183882018
#   Difference = -5.8283200177
#   Difference = -5.9707185875
#   Difference = -5.6699909890
#   Difference = -5.9191371093
#   Difference = -5.6587831587
#   Difference = -5.1131516162
#   Difference = -5.7645390603
#   Difference = -5.8881802424
#   Difference = -5.6556416700
#   Difference = -5.5756696014
#   Difference = -6.2129886911
#   Difference = -5.6580066402
#   Difference = -5.5682494853
#   Difference = -5.5726577536
#   Difference = -6.0214149157
#   Difference = -5.5185850086
#   Difference = -5.5150529985
#   Difference = -5.7396986411
#   Difference = -5.7588440030
#   Difference = -5.1904053244
#   Difference = -5.4518950315
#   Difference = -5.3108311129
#   Difference = -5.7415556250
#   Difference = -5.6411838336
#   Difference = -5.5024619768
#   Difference = -5.4708572272
#   Difference = -5.6317302980
#   Difference = -5.5814334744
#   Difference = -5.8582504560
#   Difference = -5.6590444568
#   Difference = -5.7596244675
#   Difference = -5.9007086225
#   Difference = -5.5395964299
#   Difference = -5.7498505210
#   Difference = -5.6557792362
#   Difference = -5.7899790757
#   Difference = -5.3766995371
#   Difference = -5.3871285768
#   Difference = -5.4541415134
#   Difference = -5.7366196950
#   Difference = -5.7399417455
#   Difference = -5.7093306793
#   Difference = -6.1906963505
#   Difference = -5.7414979214
#   Difference = -5.6786597121
#   Difference = -5.7179760106
#   Difference = -5.7107948917
#   Difference = -5.1598624731
#   Difference = -5.5147790882
#   Difference = -5.3767354106
#   Difference = -5.2925266862
#   Difference = -5.7573427879
#   Difference = -5.7175005136
#   Difference = -5.7801388211
#   Difference = -5.9566524345
#   Difference = -5.6618292945
#   Difference = -5.9384281740
#   Difference = -5.9718490620
#   Difference = -5.6829706000
#   Difference = -5.7377969277
#   Difference = -5.3569524073
#   Difference = -5.5561095025
#   Difference = -5.6342320654
#   Difference = -5.5744399050
#   Difference = -5.5876761457
#   Difference = -5.8961562543
#   Difference = -5.5200854598
#   Difference = -6.0371788304
#   Difference = -5.5710003265
#   Difference = -5.5732124462
#   Difference = -5.6921353726
#   Difference = -5.4790688767
#   Difference = -5.5613289305
#   Difference = -5.7192333984
#   Difference = -5.3430637775
#   Difference = -5.5398869864
#   Difference = -5.9941827629
#   Difference = -5.5144398353
#   Difference = -5.6992937785
#   Difference = -5.4776458531
#   Difference = -5.7879710762
#   Difference = -5.3532279309
#   Difference = -5.7477662471
#   Difference = -5.3511333405
#   Difference = -5.7176224909
#   Difference = -5.7119456515
#   Difference = -5.6992391947
#   Difference = -5.6928411940
#   Difference = -5.6104268607
#   Difference = -5.4228480994
#   Difference = -6.1433008311
#   Difference = -5.6952187389
#   Difference = -5.6574126271
#   Difference = -5.2545533576
#   Difference = -5.7142143953
#   Difference = -5.3584704489
#   Difference = -5.7346972462
#   Difference = -5.8104412996
#   Difference = -5.5192239104
#   Difference = -5.4956882872
#   Difference = -5.6362638133
#   Difference = -5.6444405414
#   Difference = -5.7396419907
#   Difference = -5.6925453405
#   Difference = -5.6695406175
#   Difference = -5.2768570994
#   Difference = -5.6864285705
#   Difference = -5.1806302666
#   Difference = -5.5915979397
#   Difference = -5.6761064409
#   Difference = -5.2523903794
#   Difference = -5.6746790048
#   Difference = -5.6931382953
#   Difference = -5.7187431445
#   Difference = -5.5955121964
#   Difference = -5.5091889935
#   Difference = -5.7427905797
#   Difference = -5.6042932308
#   Difference = -5.7899565883
#   Difference = -6.0290281465
#   Difference = -7.6486212050
#   Difference = -7.7120358790
#   Difference = -7.5992309490
#   Difference = -7.7345771228
#   Difference = -7.5137101156
#   Difference = -7.7738842590
#   Difference = -7.7796552322
#   Difference = -7.6507650955
#   Difference = -7.4858767216
#   Difference = -7.7912278217
#   Difference = -7.4704895729
#   Difference = -7.6903599315
#   Difference = -7.1347480457
#   Difference = -7.7691651782
#   Difference = -7.8361635964
#   Difference = -7.7220326979
#   Difference = -7.7491114873
#   Difference = -7.6212889352
#   Difference = -7.8103113387
#   Difference = -7.7165512281
#   Difference = -7.7094313847
#   Difference = -7.8367304824
#   Difference = -7.8344117799
#   Difference = -7.6783821685
#   Difference = -7.5792766040
#   Difference = -7.7588620643
#   Difference = -7.7517870064
#   Difference = -7.7479175772
#   Difference = -7.7375918945
#   Difference = -7.3091974640
#   Difference = -7.7712687827
#   Difference = -7.6663878162
#   Difference = -7.7755409273
#   Difference = -7.6386347403
#   Difference = -7.9259919862
#   Difference = -7.7738618083
#   Difference = -7.7210889986
#   Difference = -7.5581803217
#   Difference = -7.4136193220
#   Difference = -7.5901855569
#   Difference = -7.3962230544
#   Difference = -7.8118501747
#   Difference = -7.3965947763
#   Difference = -7.9272764230
#   Difference = -7.6325914522
#   Difference = -7.6148931071
#   Difference = -7.4717544285
#   Difference = -7.5915863604
#   Difference = -7.5730778489
#   Difference = -7.6005355627
#   Difference = -7.7213060890
#   Difference = -7.6268096493
#   Difference = -8.1944161740
#   Difference = -7.3193710573
#   Difference = -7.5383065700
#   Difference = -7.7443287860
#   Difference = -7.5941644731
#   Difference = -7.5101520704
#   Difference = -7.5164318897
#   Difference = -7.9179518778
#   Difference = -7.6827956874
#   Difference = -7.6407187221
#   Difference = -7.2937927416
#   Difference = -7.7903900966
#   Difference = -7.7975832067
#   Difference = -7.6866831760
#   Difference = -7.7262660601
#   Difference = -7.4304201393
#   Difference = -7.7766144359
#   Difference = -7.7398406697
#   Difference = -7.6784032186
#   Difference = -7.8155668334
#   Difference = -7.8527079456
#   Difference = -7.7795601568
#   Difference = -7.7280391772
#   Difference = -7.4009305717
#   Difference = -7.8067625220
#   Difference = -7.7524354044
#   Difference = -7.7320471780
#   Difference = -7.7263641588
#   Difference = -7.6951464824
#   Difference = -7.6880124381
#   Difference = -7.7113597078
#   Difference = -7.5717630528
#   Difference = -7.9328449228
#   Difference = -7.6171791538
#   Difference = -7.7200076038
#   Difference = -7.7051760992
#   Difference = -7.8768639108
#   Difference = -7.7968157083
#   Difference = -7.6527897946
#   Difference = -7.5882246003
#   Difference = -7.6694402480
#   Difference = -7.6059225763
#   Difference = -7.8187082097
#   Difference = -7.5158302319
#   Difference = -7.5823648208
#   Difference = -7.5584921705
#   Difference = -7.8400021709
#   Difference = -7.4506305629
#   Difference = -7.6462902129
#   Difference = -7.5316963279
#   Difference = -7.9003630780
#   Difference = -7.7408105023
#   Difference = -7.5277695281
#   Difference = -7.6576625629
#   Difference = -7.3480417129
#   Difference = -7.2392317945
#   Difference = -7.8411986461
#   Difference = -7.2797930556
#   Difference = -7.6344774708
#   Difference = -7.9269205114
#   Difference = -7.9593527509
#   Difference = -7.5944276209
#   Difference = -7.6358817046
#   Difference = -7.7791093337
#   Difference = -7.7114449546
#   Difference = -7.6504802660
#   Difference = -7.8133596504
#   Difference = -7.6088170983
#   Difference = -7.2218930350
#   Difference = -7.6857731223
#   Difference = -7.7283494978
#   Difference = -7.5883171467
#   Difference = -7.6577690676
#   Difference = -7.5538548629
#   Difference = -7.4121691791
#   Difference = -7.7127511842
#   Difference = -7.6044065116
#   Difference = -7.5748877549
#   Difference = -7.8182613046
#   Difference = -7.7343119883
#   Difference = -7.7462364088
#   Difference = -7.4996575576
#   Difference = -7.6912866848
#   Difference = -7.6712443629
#   Difference = -7.4364704381
#   Difference = -7.6521077002
#   Difference = -7.6018068413
#   Difference = -7.5528673777
#   Difference = -8.0547271140
#   Difference = -7.6210454326
#   Difference = -7.6285875452
#   Difference = -7.7683349670
#   Difference = -7.7088880428
#   Difference = -7.7356892441
#   Difference = -7.6159264422
#   Difference = -7.7121506580
#   Difference = -7.6482450431
#   Difference = -7.6377944404
#   Difference = -7.5916425012
#   Difference = -7.8180974638
#   Difference = -7.6552953759
#   Difference = -7.5688916642
#   Difference = -7.8879449057
#   Difference = -7.5864762893
#   Difference = -7.4542119504
#   Difference = -7.7472837675
#   Difference = -7.5169646815
#   Difference = -7.6207470580
#   Difference = -7.5115992012
#   Difference = -7.6173001692
#   Difference = -7.6302181851
#   Difference = -7.8072599821
#   Difference = -7.7312681289
#   Difference = -7.2304501317
#   Difference = -7.8653957191
#   Difference = -7.4080719285
#   Difference = -7.8733245671
#   Difference = -7.3536056717
#   Difference = -7.4727048579
#   Difference = -7.6136372626
#   Difference = -7.7481711874
#   Difference = -7.5957611053
#   Difference = -7.3173137715
#   Difference = -7.2200256345
#   Difference = -7.5079826467
#   Difference = -7.5792905451
#   Difference = -7.6731596011
#   Difference = -7.6052419010
#   Difference = -7.4526362441
#   Difference = -7.5935245204
#   Difference = -7.8133716369
#   Difference = -7.4777874720
#   Difference = -7.3073001114
#   Difference = -7.6287022716
#   Difference = -7.7734257527
#   Difference = -7.6980535552
#   Difference = -7.4767651366
#   Difference = -7.6702580244
#   Difference = -7.5595122374
#   Difference = -7.5199761007
#   Difference = -7.7389884119
#   Difference = -7.6390943212
#   Difference = -7.6158909240
#   Difference = -7.5894454175
#   Difference = -7.2951576144
#   Difference = -7.7157383389
#   Difference = -7.6611683726
#   Difference = -7.5695594355
#   Difference = -7.4158199223
#   Difference = -7.6697572276
#   Difference = -7.6088123728
#   Difference = -7.5901975274
#   Difference = -7.7307970609
#   Difference = -7.6660954735
#   Difference = -7.7198385697
#   Difference = -7.7105500133
#   Difference = -7.6792610842
#   Difference = -7.7735222047
#   Difference = -7.6018667640
#   Difference = -7.6802834902
#   Difference = -7.4089292147
#   Difference = -7.6309356565
#   Difference = -7.4851530934
#   Difference = -7.6741135142
#   Difference = -7.9120019629
#   Difference = -7.6734444043
#   Difference = -7.7014408710
#   Difference = -7.3314903766
#   Difference = -7.2913938736
#   Difference = -7.4425416418
#   Difference = -7.5088041557
#   Difference = -7.6800575524
#   Difference = -7.7756766920
#   Difference = -7.7170415501
#   Difference = -7.5679154710
#   Difference = -7.6649654239
#   Difference = -7.8664006085
#   Difference = -7.4296391266
#   Difference = -7.6266139023
#   Difference = -7.3740423987
#   Difference = -7.6545458970
#   Difference = -7.5502871987
#   Difference = -7.7458588282
#   Difference = -7.5368361621
#   Difference = -7.6877067286
#   Difference = -7.5675648227
#   Difference = -7.6177735422
#   Difference = -7.5574852254
#   Difference = -7.6684089248
#   Difference = -7.3418221800
#   Difference = -7.6392465626
#   Difference = -7.5779916129
#   Difference = -7.7410708321
#   Difference = -7.5524400551
#   Difference = -7.6783564317
#   Difference = -7.5014754337
#   Difference = -7.7356356075
#   Difference = -7.7273761591
#   Difference = -7.6671642518
#   Difference = -7.5677983677
#   Difference = -7.8933770165
#   Difference = -7.4878569266
#   Difference = -7.4891896241
#   Difference = -7.4550045404
#   Difference = -7.8085203041
#   Difference = -7.5013164221
#   Difference = -7.5813307103
#   Difference = -7.5889196918
#   Difference = -7.8925510861
#   Difference = -7.6925773836
#   Difference = -7.5776621692
#   Difference = -7.5685406336
#   Difference = -7.6768272305
#   Difference = -7.5124063476
#   Difference = -7.5280441587
#   Difference = -7.6448904811
#   Difference = -7.7524367753
#   Difference = -7.5330627032
#   Difference = -7.5007614742
#   Difference = -7.4066617225
#   Difference = -7.5492807824
#   Difference = -7.6914298068
#   Difference = -7.5343866365
#   Difference = -7.6527304733
#   Difference = -7.3577062616
#   Difference = -7.6552031742
#   Difference = -7.7907519275
#   Difference = -7.8201682846
#   Difference = -7.5796542355
#   Difference = -7.4159652205
#   Difference = -7.7135001426
#   Difference = -7.5857792187
#   Difference = -7.4504941417
#   Difference = -7.5561927848
#   Difference = -7.3692395275
#   Difference = -7.7345294719
#   Difference = -7.7751313348
#   Difference = -7.6464673792
#   Difference = -7.6308302251
#   Difference = -7.5595237489
#   Difference = -7.7193905967
#   Difference = -7.5766449765
#   Difference = -7.7206267789
#   Difference = -7.6738618266
#   Difference = -7.5667611183
#   Difference = -7.4583510915
#   Difference = -7.7333505600
#   Difference = -7.8083233557
# Simulation complete.

# %% [markdown]
# - **Bonus Question 2.** Why is the Jeffrey's prior estimator so bad? Can you provide a better bound for the variance of the estimator? [Hint: you might need `np.gradient` to solve this question, and increase the number of different values of $a$ to get a finer plot]
#
# - **BQ2 Answer**
#
#   - $\hat{a}_{\text{Jeff}}$ performs so badly because it is a biased estimator. The prior is $P(a) \propto \frac{1}{\sqrt{a(b-a)}}$, which is a Beta(1/2, 1/2) distribution, also known as the Arcsine distribution.
#
#   - $\hat{a}_{\text{Jeff}}$ is the MAP estimator that tries to maximize $\mathcal{L}(a) \cdot P(a)$. This U-shaped prior $P(a)$ strongly pulls the peak toward 0 and 20.
#
#   - In the plot, $\hat{a}_{\text{ML}}$ and $\hat{a}_{\text{Jeff}}$ overlap. This shows that with $N=1000$ data points, the likelihood completely overwhelms the prior's influence. If we used $N=10$ or $N=20$, the MSE curve for $\hat{a}_{\text{Jeff}}$ would become very poor, similar to $\hat{a}_{\text{median}}$.
#
#   - For a biased estimator $\hat{a}$ with bias $b(a) = \mathbb{E}[\hat{a}] - a$, a tighter bound which can be used(generalization of CRLB) is:
# $$\text{Var}(\hat{a}) \ge \frac{\left( \frac{d}{da} \mathbb{E}[\hat{a}] \right)^2}{I_n(a)} = \frac{(1 + b'(a))^2}{I_n(a)}$$

# %% [markdown]
# ### Joint estimation case
# You finally managed to get the file `full.npy` with the samples of the distribution $p(x;a,b)$ your friend Alex stored in the computer. You don't know the value of $b$, and you need to estimate both $a^\star$ and $b^\star$. (BE CAREFUL: $a^\star$ is different from the previous case).

# %% [markdown]
# - **Question 17.** How many sample points are there in the file? Let us call this number $n$ and plot an histogram of the data.

# %%
import numpy as np
import matplotlib.pyplot as plt
import requests
import io

b = 20

url = 'https://raw.githubusercontent.com/Jerry0209/FundamentalLearningEPFL/main/HW1/full.npy'

try:
    response = requests.get(url)
    response.raise_for_status()
    data_full = np.load(io.BytesIO(response.content))
    n_full = len(data_full)

    print(f"full.py successfully loaded！")
    # print(f"Data Shape: {data.shape}")

    print(f"There are n = {n_full} sample points in the file.")

    # Plot the histogram
    plt.figure(figsize=(10, 6))
    plt.hist(data_full, bins='auto', density=True, alpha=0.7, label='Data Histogram')
    plt.title('Histogram of full.npy (Both a and b unknown)')
    plt.xlabel('x value')
    plt.ylabel('Density')
    plt.grid(True, linestyle='--')
    plt.legend()
    plt.show()

except Exception as e:
    print(f"Error：{e}")
    data = np.array([])
# Out:
# Successfully loaded！
# Data Shape: (10000,)
# There are n = 10000 sample points in the file.

# %% [markdown]
# - **Question 18.** Compute the maximum likelihood estimators $\hat a_\text{ML}$ and $\hat b_\text{ML}$ for the data in the file `full.npy`.
#
# - **Q18 Answer**
#
#
#   - The `pdf(x, a, b)` function computes the probability density for given values of $x$, $a$, and $b$. It uses masks to identify which data points fall in the left piece ($0 \le x \le a$) where $p(x) = H \cdot \frac{x}{a}$, and the right piece ($a < x \le b$) where $p(x) = H \cdot \frac{b-x}{b-a}$.
#
#
#   - The `log_likelihood_joint` function computes the joint log-likelihood like before.
#
#   - `scipy.optimize.minimize` is used to find the values of $a$ and $b$ that maximize the log-likelihood (or minimize the negative log-likelihood). The initial guess sets $b$ slightly above the maximum data point and $a$ at about one-third of $b$.

# %%
from scipy.optimize import minimize
import numpy as np

# Re-define pdf because there are two varibles a and b, the pdf is piecewise as before
def pdf(x, a, b):
    x = np.asarray(x)
    p = np.zeros_like(x, dtype=float)


    if not (0 < a < b and b > 0): # a must be strictly between 0 and b
        return p # Return 0 for invalid parameters

    H = 2.0 / b

    # Left
    mask_left = (x >= 0) & (x <= a)
    if a > 0: # Avoid division by zero if a were 0
        p[mask_left] = H * (x[mask_left] / a)

    # Right
    mask_right = (x > a) & (x <= b)
    if b - a > 0: # Avoid division by zero if a were b
        p[mask_right] = H * ((b - x[mask_right]) / (b - a))

    return p


# Joint Log
def log_likelihood_joint(params, data):
    a, b = params

    # a must be between 0 and b
    if not (0 < a < b):
        return -np.inf

    if b <= np.max(data):
        return -np.inf

    logl = 0.0
    for x_i in data:
        p_i = pdf(x_i, a, b)


        if p_i <= 0: # catch potential float errors
            return -np.inf

        logl += np.log(p_i)
    return logl

# neg log likelihood
def negative_log_likelihood_joint(params, data):
    return -log_likelihood_joint(params, data)


# Initialize simulation (use minimizer)
initial_guess_b = np.max(data_full) * 1.05
initial_guess_a = initial_guess_b / 3 # randomly choose at 1/3
initial_params = [initial_guess_a, initial_guess_b]

# Boundary
epsilon = 1e-6
bounds = [
    (epsilon, initial_guess_b - epsilon),
    (np.max(data_full) + epsilon, None)
]

print(f"Starting optimization for a and b...")
print(f"Initial guess for [a, b]: {initial_params}")

result = minimize(
    negative_log_likelihood_joint,
    x0=initial_params,
    args=(data_full,),
    bounds=bounds,
    method='L-BFGS-B'
)

if result.success:
    a_hat_ml_optimized, b_hat_ml_optimized = result.x
    print("\nOptimization successful!")
    print(f"Maximum Likelihood Estimators:")
    print(f"  a_hat_ml = {a_hat_ml_optimized:.4f}")
    print(f"  b_hat_ml = {b_hat_ml_optimized:.4f}")
else:
    print("\nOptimization failed!")
    print(result.message)

# Plot
plt.figure(figsize=(10, 6))
plt.hist(data_full, bins='auto', density=True, alpha=0.7, label='Data Histogram')
x_plot = np.linspace(0, b_hat_ml_optimized * 1.05, 400) # Extend plot slightly beyond b
plt.plot(x_plot, pdf(x_plot, a_hat_ml_optimized, b_hat_ml_optimized), 'r-', lw=2,
         label=f'Fitted MLE PDF (a={a_hat_ml_optimized:.2f}, b={b_hat_ml_optimized:.2f})')
plt.axvline(a_hat_ml_optimized, color='r', linestyle='--', label=f'a_hat_ml = {a_hat_ml_optimized:.2f}')
plt.axvline(b_hat_ml_optimized, color='k', linestyle='--', label=f'b_hat_ml = {b_hat_ml_optimized:.2f}')
plt.title('Data Histogram with Joint Fitted MLE PDF')
plt.xlabel('x')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# Starting optimization for a and b...
# Initial guess for [a, b]: [np.float64(29.953151333669595), np.float64(89.85945400100879)]
#
# Optimization successful!
# Maximum Likelihood Estimators:
#   a_hat_ml = 62.9929
#   b_hat_ml = 85.8962

# %% [markdown]
# - **Question 19.** Can you provide the confidence intervals for the estimators? Can you guess the secret code of your friend?
#
# - **Q19 Answer**
#
#
#   - The 95% confidence interval is computed using percentiles of the bootstrap distribution.
#     - For $a$: CI = [62.4007, 63.8068]
#     - For $b$: CI = [85.6308, 86.1042]
#
#
#   - The point estimates from Q18 were $\hat{a}_{\text{ML}} = 62.9929$ and $\hat{b}_{\text{ML}} = 85.8962$. The narrow confidence intervals indicate high precision in these estimates. This makes sense because we have 1000 data points, which provides a lot of information.
#
#   - To guess the secret code, the MLE estimates are rounded to the nearest integers: $a = 63$ and $b = 86$. Then it's checked that if these integers fall within the 95% confidence intervals. Since both 63 and 86 are comfortably within their respective CIs, it's highly confident these are the true parameter values.
#
#   - The phone code is simply the concatenation of these two digits: **6386**.

# %%
import time

n_bootstraps = 300
boot_a_ml = []
boot_b_ml = []

# Use the result from Q18 as a smart initial guess for all iterations
initial_guess_from_q18 = [a_hat_ml_optimized, b_hat_ml_optimized]

print(f"Starting Bootstrap")
print(f"Running {n_bootstraps} iterations. ")
start_time = time.time()

for i in range(n_bootstraps):
    # Resampled dataset
    resample = np.random.choice(data_full, size=n_full, replace=True)


    max_resample = np.max(resample)
    epsilon = 1e-9

    bounds_boot = [
        (epsilon, None),                # Bound for a
        (max_resample + epsilon, None)  # Bound for b
    ]

    # Re-run the optimization
    res_boot = minimize(
        negative_log_likelihood_joint,
        x0=initial_guess_from_q18,
        args=(resample,),
        bounds=bounds_boot,
        method='L-BFGS-B'
    )

    # Store the result
    if res_boot.success:
        boot_a_ml.append(res_boot.x[0])
        boot_b_ml.append(res_boot.x[1])

    # Print progress
    if (i + 1) % 50 == 0:
        print(f"  ... completed {i+1} / {n_bootstraps} iterations")

end_time = time.time()
print(f"Bootstrap complete in {end_time - start_time:.2f} seconds.")

# Compute the 95% Confidence Intervals
ci_a = np.percentile(boot_a_ml, [2.5, 97.5])
ci_b = np.percentile(boot_b_ml, [2.5, 97.5])

print(f"\n--- 95% Confidence Intervals (Bootstrap) ---")
print(f"a_hat_ml: {a_hat_ml_optimized:.4f},  95% CI: [{ci_a[0]:.4f}, {ci_a[1]:.4f}]")
print(f"b_hat_ml: {b_hat_ml_optimized:.4f},  95% CI: [{ci_b[0]:.4f}, {ci_b[1]:.4f}]")


# Guessing
print("\n--- Guessing the Secret Code ---")

# Round to Integer
a_guess = round(a_hat_ml_optimized)
b_guess = round(b_hat_ml_optimized)

print(f"The MLE estimates rounded to the nearest integer are: a = {a_guess}, b = {b_guess}")
a_in_ci = (ci_a[0] <= a_guess <= ci_a[1])
b_in_ci = (ci_b[0] <= b_guess <= ci_b[1])

print(f"Is the integer {a_guess} within the 95% CI for 'a'?  {a_in_ci}")
print(f"Is the integer {b_guess} within the 95% CI for 'b'?  {b_in_ci}")

if a_in_ci and b_in_ci:
    print("\nConclusion: The integer estimates fall within the CIs.")
    print(f"There is a highly confident that the secret code is a={a_guess}, b={b_guess}.")
    print(f"The phone code guessed is: {a_guess}{b_guess}")
else:
    print("\nWarning: The integer estimates are outside the CIs.")
    print("The guess is less certain.")
# Out:
# --- Starting Bootstrap for Q19 ---
# Running 300 iterations. This will be SLOW (est. 2-5 mins)...
#   ... completed 50 / 300 iterations
#   ... completed 100 / 300 iterations
#   ... completed 150 / 300 iterations
#   ... completed 200 / 300 iterations
#   ... completed 250 / 300 iterations
#   ... completed 300 / 300 iterations
# Bootstrap complete in 2499.05 seconds.
#
# --- 95% Confidence Intervals (Bootstrap) ---
# a_hat_ml (from Q18): 62.9929,  95% CI: [62.4007, 63.8068]
# b_hat_ml (from Q18): 85.8962,  95% CI: [85.6308, 86.1042]
#
# --- Guessing the Secret Code ---
# The MLE estimates rounded to the nearest integer are: a = 63, b = 86
# Is the integer 63 within the 95% CI for 'a'?  True
# Is the integer 86 within the 95% CI for 'b'?  True
#
# Conclusion: The integer estimates fall comfortably within the CIs.
# We are highly confident that Alex's secret code is a=63, b=86.
# The phone code is: 6386

# %% [markdown]
# - **Bonus Question 3.** Can you find some estimators for $a$ and $b$ that are based on mean and median? Do you expect them to work well? Why?
#
# - **BQ3 Answer**
#
#
#   - We can use the Method of Moments to find estimators for $a$ and $b$. Since we have two unknown parameters, we need two moment equations. A standard approach is to use the first two power moments: $\mathbb{E}[X]$ (mean) and $\mathbb{E}[X^2]$ (second moment).
#
#   - For the first moment (mean), we know from Q2 that $\mu = \mathbb{E}[X] = \frac{a+b}{3}$. Setting this equal to the sample mean $\bar{x}$ gives us:
#   $$\hat{a} + \hat{b} = 3\bar{x} \implies \hat{b} = 3\bar{x} - \hat{a}$$
#
#   - For the second moment, we can show that $\mathbb{E}[X^2] = \frac{a^2 + b^2 + ab}{6}$. Setting this equal to the empirical second moment $\overline{x^2} = \frac{1}{n}\sum x_i^2$ gives:
#   $$6\overline{x^2} = \hat{a}^2 + \hat{b}^2 + \hat{a}\hat{b}$$
#
#   - Substituting the first equation into the second and simplifying yields a quadratic equation in $\hat{a}$:
#   $$\hat{a}^2 - (3\bar{x})\hat{a} + (9\bar{x}^2 - 6\overline{x^2}) = 0$$
#
#   - We can solve this using the quadratic formula to get $\hat{a}$, then find $\hat{b} = 3\bar{x} - \hat{a}$.
#
#   - Working performance: poor
#
#     - It's expected that these estimators to perform poorly for two reasons.
#
#     - First, moment-based estimators are statistically inefficient. As we saw in Q16, estimators based on moments (like mean and median) have much higher MSE than the CRLB and MLE. They don't fully utilize all the information in the data.
#
#     - Second, and more fundamentally, they lose critical information. For estimating $b$, the most informative data point is $\max(x_i)$ - the maximum value in the sample. The MLE cleverly uses this fact, making $\hat{b}_{\text{ML}}$ essentially equal to $\max(x_i)$. But MoM completely discards this information by averaging $\max(x_i)$ together with all other $N-1$ data points when computing $\bar{x}$ and $\overline{x^2}$. This averaging makes the estimate of $b$ much less accurate.
